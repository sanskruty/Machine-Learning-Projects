# %% [markdown]
# **Download if necessary**

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sansk\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### **Step 1: Import the libraries**

# %%
import nltk  
import numpy as np  
import random  
import string

import bs4 as bs  
import urllib.request  
import re

# %% [markdown]
# ### Step 2: Grab articles from wikipedia

# %%
import ssl
gcontext = ssl.SSLContext()
raw_html = urllib.request.urlopen('https://en.wikipedia.org/wiki/Natural_language_processing', context=gcontext)  
raw_html = raw_html.read()

article_html = bs.BeautifulSoup(raw_html, 'lxml')

article_paragraphs = article_html.find_all('p')

article_text = ''

for para in article_paragraphs:  
    article_text += para.text

# %%
article_text
# Out:
# 'Natural language processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence concerned with the interactions between computers and human language, in particular how to program computers to process and analyze large amounts of natural language data.  The goal is a computer capable of "understanding" the contents of documents, including the contextual nuances of the language within them. The technology can then accurately extract information and insights contained in the documents as well as categorize and organize the documents themselves.\nChallenges in natural language processing frequently involve speech recognition, natural language understanding, and natural language generation.\nNatural language processing has its roots in the 1950s. Already in 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence, though at the time that was not articulated as a problem separate from artificial intelligence. The proposed test includes a task that involves the automated interpretation and generation of natural language.\nThe premise of symbolic NLP is well-summarized by John Searle\'s Chinese room experiment: Given a collection of rules (e.g., a Chinese phrasebook, with questions and matching answers), the computer emulates natural language understanding (or other NLP tasks) by applying those rules to the data it confronts.\nUp to the 1980s, most natural language processing systems were based on complex sets of hand-written rules.  Starting in the late 1980s, however, there was a revolution in natural language processing with the introduction of machine learning algorithms for language processing.  This was due to both the steady increase in computational power (see Moore\'s law) and the gradual lessening of the dominance of Chomskyan theories of linguistics (e.g. transformational grammar), whose theoretical underpinnings discouraged the sort of corpus linguistics that underlies the machine-learning approach to language processing.[6]\nIn the 2010s, representation learning and deep neural network-style machine learning methods became widespread in natural language processing. That popularity was due partly to a flurry of results showing that such techniques[7][8] can achieve state-of-the-art results in many natural language tasks, e.g., in language modeling[9] and parsing.[10][11] This is increasingly important in medicine and healthcare, where NLP helps analyze notes and text in electronic health records that would otherwise be inaccessible for study when seeking to improve care.[12]\nIn the early days, many language-processing systems were designed by symbolic methods, i.e., the hand-coding of a set of rules, coupled with a dictionary lookup:[13][14] such as by writing grammars or devising heuristic rules for stemming.\nMore recent systems based on machine-learning algorithms have many advantages over hand-produced rules: \nDespite the popularity of machine learning in NLP research, symbolic methods are still (2020) commonly used:\nSince the so-called "statistical revolution"[15][16] in the late 1980s and mid-1990s, much natural language processing research has relied heavily on machine learning. The machine-learning paradigm calls instead for using statistical inference to automatically learn such rules through the analysis of large corpora (the plural form of corpus, is a set of documents, possibly with human or computer annotations) of typical real-world examples.\nMany different classes of machine-learning algorithms have been applied to natural-language-processing tasks. These algorithms take as input a large set of "features" that are generated from the input data. Increasingly, however, research has focused on statistical models, which make soft, probabilistic decisions based on attaching real-valued weights to each input feature (complex-valued embeddings,[17] and neural networks in ge ...

# %% [markdown]
# ### Step 4: N-Grams = 3

# %%
ngrams = {}
words = 3

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])

ngrams
# Out:
# Natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) is
# ) is a
# is a subfield
# a subfield of
# subfield of linguistics
# of linguistics ,
# linguistics , computer
# , computer science
# computer science ,
# science , and
# , and artificial
# and artificial intelligence
# artificial intelligence concerned
# intelligence concerned with
# concerned with the
# with the interactions
# the interactions between
# interactions between computers
# between computers and
# computers and human
# and human language
# human language ,
# language , in
# , in particular
# in particular how
# particular how to
# how to program
# to program computers
# program computers to
# computers to process
# to process and
# process and analyze
# and analyze large
# analyze large amounts
# large amounts of
# amounts of natural
# of natural language
# natural language data
# language data .
# data . The
# . The goal
# The goal is
# goal is a
# is a computer
# a computer capable
# computer capable of
# capable of ``
# of `` understanding
# `` understanding ''
# understanding '' the
# '' the contents
# the contents of
# contents of documents
# of documents ,
# documents , including
# , including the
# including the contextual
# the contextual nuances
# contextual nuances of
# nuances of the
# of the language
# the language within
# language within them
# within them .
# them . The
# . The technology
# The technology can
# technology can then
# can then accurately
# then accurately extract
# accurately extract information
# extract information and
# information and insights
# and insights contained
# insights contained in
# contained in the
# in the documents
# the documents as
# documents as well
# as well as
# well as categorize
# as categorize and
# categorize and organize
# and organize the
# organize the documents
# the documents themselves
# documents themselves .
# themselves . Challenges
# . Challenges in
# Challenges in natural
# in natural language
# natural language processing
# language processing frequently
# processing frequently involve
# frequently involve speech
# involve speech recognition
# speech recognition ,
# recognition , natural
# , natural language
# natural language understanding
# language understanding ,
# understanding , and
# , and natural
# and natural language
# natural language generation
# language generation .
# generation . Natural
# . Natural language
# Natural language processing
# language processing has
# processing has its
# has its roots
# its roots in
# roots in the
# in the 1950s
# the 1950s .
# 1950s . Already
# . Already in
# Already in 1950
# in 1950 ,
# 1950 , Alan
# , Alan Turing
# Alan Turing published
# Turing published an
# published an article
# an article titled
# article titled ``
# titled `` Computing
# `` Computing Machinery
# Computing Machinery and
# Machinery and Intelligence
# and Intelligence ''
# Intelligence '' which
# '' which proposed
# which proposed what
# proposed what is
# what is now
# is now called
# now called the
# called the Turing
# the Turing test
# Turing test as
# test as a
# as a criterion
# a criterion of
# criterion of intelligence
# of intelligence ,
# intelligence , though
# , though at
# though at the
# at the time
# the time that
# time that was
# that was not
# was not articulated
# not articulated as
# articulated as a
# as a problem
# a problem separate
# problem separate from
# separate from artificial
# from artificial intelligence
# artificial intelligence .
# intelligence . The
# . The proposed
# The proposed test
# proposed test includes
# test includes a
# includes a task
# a task that
# task that involves
# that involves the
# involves the automated
# the automated interpretation
# automated interpretation and
# interpretation and generation
# and generation of
# generation of natural
# of natural language
# natural language .
# language . The
# . The premise
# The premise of
# premise of symbolic
# of symbolic NLP
# symbolic NLP is
# NLP is well-summarized
# is well-summarized by
# well-summarized by John
# by John Searle
# John Searle 's
# Searle 's Chinese
# 's Chinese room
# Chinese room experiment
# room experiment :
# experiment : Given
# : Given a
# Given a collection
# a collection of
# collection of rules
# of rules (
# rules ( e.g.
# ( e.g. ,
# e.g. , a
# , a Chinese
# a Chinese phrasebook
# Chinese phrasebook ,
# phrasebook , with
# , with questions
# with questions and
# questions and matching
# and matching answers
# matching answers )
# answers ) ,
# ) , the
# , the computer
# the computer emulates
# computer emulates natural
# emulates natural language
# natural language understanding
# language understanding (
# understanding ( or
# ( or other
# or other NLP
# other NLP tasks
# NLP tasks )
# tasks ) by
# ) by applying
# by applying those
# applying those rules
# those rules to
# rules to the
# to the data
# the data it
# data it confronts
# it confronts .
# confronts . Up
# . Up to
# Up to the
# to the 1980s
# the 1980s ,
# 1980s , most
# , most natural
# most natural language
# natural language processing
# language processing systems
# processing systems were
# systems were based
# were based on
# based on complex
# on complex sets
# complex sets of
# sets of hand-written
# of hand-written rules
# hand-written rules .
# rules . Starting
# . Starting in
# Starting in the
# in the late
# the late 1980s
# late 1980s ,
# 1980s , however
# , however ,
# however , there
# , there was
# there was a
# was a revolution
# a revolution in
# revolution in natural
# in natural language
# natural language processing
# language processing with
# processing with the
# with the introduction
# the introduction of
# introduction of machine
# of machine learning
# machine learning algorithms
# learning algorithms for
# algorithms for language
# for language processing
# language processing .
# processing . This
# . This was
# This was due
# was due to
# due to both
# to both the
# both the steady
# the steady increase
# steady increase in
# increase in computational
# in computational power
# computational power (
# power ( see
# ( see Moore
# see Moore 's
# Moore 's law
# 's law )
# law ) and
# ) and the
# and the gradual
# the gradual lessening
# gradual lessening of
# lessening of the
# of the dominance
# the dominance of
# dominance of Chomskyan
# of Chomskyan theories
# Chomskyan theories of
# theories of linguistics
# of linguistics (
# linguistics ( e.g
# ( e.g .
# e.g . transformational
# . transformational grammar
# transformational grammar )
# grammar ) ,
# ) , whose
# , whose theoretical
# whose theoretical underpinnings
# theoretical underpinnings discouraged
# underpinnings discouraged the
# discouraged the sort
# the sort of
# sort of corpus
# of corpus linguistics
# corpus linguistics that
# linguistics that underlies
# that underlies the
# underlies the machine-learning
# the machine-learning approach
# machine-learning approach to
# approach to language
# to language processing
# language processing .
# processing . [
# . [ 6
# [ 6 ]
# 6 ] In
# ] In the
# In the 2010s
# the 2010s ,
# 2010s , representation
# , representation learning
# representation learning and
# learning and deep
# and deep neural
# deep neural network-style
# neural network-style machine
# network-style machine learning
# machine learning methods
# learning methods became
# methods became widespread
# became widespread in
# widespread in natural
# in natural language
# natural language processing
# language processing .
# processing . That
# . That popularity
# That popularity was
# popularity was due
# was due partly
# due partly to
# partly to a
# to a flurry
# a flurry of
# flurry of results
# of results showing
# results showing that
# showing that such
# that such techniques
# such techniques [
# techniques [ 7
# [ 7 ]
# 7 ] [
# ] [ 8
# [ 8 ]
# 8 ] can
# ] can achieve
# can achieve state-of-the-art
# achieve state-of-the-art results
# state-of-the-art results in
# results in many
# in many natural
# many natural language
# natural language tasks
# language tasks ,
# tasks , e.g.
# , e.g. ,
# e.g. , in
# , in language
# in language modeling
# language modeling [
# modeling [ 9
# [ 9 ]
# 9 ] and
# ] and parsing
# and parsing .
# parsing . [
# . [ 10
# [ 10 ]
# 10 ] [
# ] [ 11
# [ 11 ]
# 11 ] This
# ] This is
# This is increasingly
# is increasingly important
# increasingly important in
# important in medicine
# in medicine and
# medicine and healthcare
# and healthcare ,
# healthcare , where
# , where NLP
# where NLP helps
# NLP helps analyze
# helps analyze notes
# analyze notes and
# notes and text
# and text in
# text in electronic
# in electronic health
# electronic health records
# health records that
# records that would
# that would otherwise
# would otherwise be
# otherwise be inaccessible
# be inaccessible for
# inaccessible for study
# for study when
# study when seeking
# when seeking to
# seeking to improve
# to improve care
# improve care .
# care . [
# . [ 12
# [ 12 ]
# 12 ] In
# ] In the
# In the early
# the early days
# early days ,
# days , many
# , many language-processing
# many language-processing systems
# language-processing systems were
# systems were designed
# were designed by
# designed by symbolic
# by symbolic methods
# symbolic methods ,
# methods , i.e.
# , i.e. ,
# i.e. , the
# , the hand-coding
# the hand-coding of
# hand-coding of a
# of a set
# a set of
# set of rules
# of rules ,
# rules , coupled
# , coupled with
# coupled with a
# with a dictionary
# a dictionary lookup
# dictionary lookup :
# lookup : [
# : [ 13
# [ 13 ]
# 13 ] [
# ] [ 14
# [ 14 ]
# 14 ] such
# ] such as
# such as by
# as by writing
# by writing grammars
# writing grammars or
# grammars or devising
# or devising heuristic
# devising heuristic rules
# heuristic rules for
# rules for stemming
# for stemming .
# stemming . More
# . More recent
# More recent systems
# recent systems based
# systems based on
# based on machine-learning
# on machine-learning algorithms
# machine-learning algorithms have
# algorithms have many
# have many advantages
# many advantages over
# advantages over hand-produced
# over hand-produced rules
# hand-produced rules :
# rules : Despite
# : Despite the
# Despite the popularity
# the popularity of
# popularity of machine
# of machine learning
# machine learning in
# learning in NLP
# in NLP research
# NLP research ,
# research , symbolic
# , symbolic methods
# symbolic methods are
# methods are still
# are still (
# still ( 2020
# ( 2020 )
# 2020 ) commonly
# ) commonly used
# commonly used :
# used : Since
# : Since the
# Since the so-called
# the so-called ``
# so-called `` statistical
# `` statistical revolution
# statistical revolution ''
# revolution '' [
# '' [ 15
# [ 15 ]
# 15 ] [
# ] [ 16
# [ 16 ]
# 16 ] in
# ] in the
# in the late
# the late 1980s
# late 1980s and
# 1980s and mid-1990s
# and mid-1990s ,
# mid-1990s , much
# , much natural
# much natural language
# natural language processing
# language processing research
# processing research has
# research has relied
# has relied heavily
# relied heavily on
# heavily on machine
# on machine learning
# machine learning .
# learning . The
# . The machine-learning
# The machine-learning paradigm
# machine-learning paradigm calls
# paradigm calls instead
# calls instead for
# instead for using
# for using statistical
# using statistical inference
# statistical inference to
# inference to automatically
# to automatically learn
# automatically learn such
# learn such rules
# such rules through
# rules through the
# through the analysis
# the analysis of
# analysis of large
# of large corpora
# large corpora (
# corpora ( the
# ( the plural
# the plural form
# plural form of
# form of corpus
# of corpus ,
# corpus , is
# , is a
# is a set
# a set of
# set of documents
# of documents ,
# documents , possibly
# , possibly with
# possibly with human
# with human or
# human or computer
# or computer annotations
# computer annotations )
# annotations ) of
# ) of typical
# of typical real-world
# typical real-world examples
# real-world examples .
# examples . Many
# . Many different
# Many different classes
# different classes of
# classes of machine-learning
# of machine-learning algorithms
# machine-learning algorithms have
# algorithms have been
# have been applied
# been applied to
# applied to natural-language-processing
# to natural-language-processing tasks
# natural-language-processing tasks .
# tasks . These
# . These algorithms
# These algorithms take
# algorithms take as
# take as input
# as input a
# input a large
# a large set
# large set of
# set of ``
# of `` features
# `` features ''
# features '' that
# '' that are
# that are generated
# are generated from
# generated from the
# from the input
# the input data
# input data .
# data . Increasingly
# . Increasingly ,
# Increasingly , however
# , however ,
# however , research
# , research has
# research has focused
# has focused on
# focused on statistical
# on statistical models
# statistical models ,
# models , which
# , which make
# which make soft
# make soft ,
# soft , probabilistic
# , probabilistic decisions
# probabilistic decisions based
# decisions based on
# based on attaching
# on attaching real-valued
# attaching real-valued weights
# real-valued weights to
# weights to each
# to each input
# each input feature
# input feature (
# feature ( complex-valued
# ( complex-valued embeddings
# complex-valued embeddings ,
# embeddings , [
# , [ 17
# [ 17 ]
# 17 ] and
# ] and neural
# and neural networks
# neural networks in
# networks in general
# in general have
# general have also
# have also been
# also been proposed
# been proposed ,
# proposed , for
# , for e.g
# for e.g .
# e.g . speech
# . speech [
# speech [ 18
# [ 18 ]
# 18 ] )
# ] ) .
# ) . Such
# . Such models
# Such models have
# models have the
# have the advantage
# the advantage that
# advantage that they
# that they can
# they can express
# can express the
# express the relative
# the relative certainty
# relative certainty of
# certainty of many
# of many different
# many different possible
# different possible answers
# possible answers rather
# answers rather than
# rather than only
# than only one
# only one ,
# one , producing
# , producing more
# producing more reliable
# more reliable results
# reliable results when
# results when such
# when such a
# such a model
# a model is
# model is included
# is included as
# included as a
# as a component
# a component of
# component of a
# of a larger
# a larger system
# larger system .
# system . Some
# . Some of
# Some of the
# of the earliest-used
# the earliest-used machine
# earliest-used machine learning
# machine learning algorithms
# learning algorithms ,
# algorithms , such
# , such as
# such as decision
# as decision trees
# decision trees ,
# trees , produced
# , produced systems
# produced systems of
# systems of hard
# of hard if-then
# hard if-then rules
# if-then rules similar
# rules similar to
# similar to existing
# to existing hand-written
# existing hand-written rules
# hand-written rules .
# rules . However
# . However ,
# However , part-of-speech
# , part-of-speech tagging
# part-of-speech tagging introduced
# tagging introduced the
# introduced the use
# the use of
# use of hidden
# of hidden Markov
# hidden Markov models
# Markov models to
# models to natural
# to natural language
# natural language processing
# language processing ,
# processing , and
# , and increasingly
# and increasingly ,
# increasingly , research
# , research has
# research has focused
# has focused on
# focused on statistical
# on statistical models
# statistical models ,
# models , which
# , which make
# which make soft
# make soft ,
# soft , probabilistic
# , probabilistic decisions
# probabilistic decisions based
# decisions based on
# based on attaching
# on attaching real-valued
# attaching real-valued weights
# real-valued weights to
# weights to the
# to the features
# the features making
# features making up
# making up the
# up the input
# the input data
# input data .
# data . The
# . The cache
# The cache language
# cache language models
# language models upon
# models upon which
# upon which many
# which many speech
# many speech recognition
# speech recognition systems
# recognition systems now
# systems now rely
# now rely are
# rely are examples
# are examples of
# examples of such
# of such statistical
# such statistical models
# statistical models .
# models . Such
# . Such models
# Such models are
# models are generally
# are generally more
# generally more robust
# more robust when
# robust when given
# when given unfamiliar
# given unfamiliar input
# unfamiliar input ,
# input , especially
# , especially input
# especially input that
# input that contains
# that contains errors
# contains errors (
# errors ( as
# ( as is
# as is very
# is very common
# very common for
# common for real-world
# for real-world data
# real-world data )
# data ) ,
# ) , and
# , and produce
# and produce more
# produce more reliable
# more reliable results
# reliable results when
# results when integrated
# when integrated into
# integrated into a
# into a larger
# a larger system
# larger system comprising
# system comprising multiple
# comprising multiple subtasks
# multiple subtasks .
# subtasks . Since
# . Since the
# Since the neural
# the neural turn
# neural turn ,
# turn , statistical
# , statistical methods
# statistical methods in
# methods in NLP
# in NLP research
# NLP research have
# research have been
# have been largely
# been largely replaced
# largely replaced by
# replaced by neural
# by neural networks
# neural networks .
# networks . However
# . However ,
# However , they
# , they continue
# they continue to
# continue to be
# to be relevant
# be relevant for
# relevant for contexts
# for contexts in
# contexts in which
# in which statistical
# which statistical interpretability
# statistical interpretability and
# interpretability and transparency
# and transparency is
# transparency is required
# is required .
# required . A
# . A major
# A major drawback
# major drawback of
# drawback of statistical
# of statistical methods
# statistical methods is
# methods is that
# is that they
# that they require
# they require elaborate
# require elaborate feature
# elaborate feature engineering
# feature engineering .
# engineering . Since
# . Since 2015
# Since 2015 ,
# 2015 , [
# , [ 19
# [ 19 ]
# 19 ] the
# ] the field
# the field has
# field has thus
# has thus largely
# thus largely abandoned
# largely abandoned statistical
# abandoned statistical methods
# statistical methods and
# methods and shifted
# and shifted to
# shifted to neural
# to neural networks
# neural networks for
# networks for machine
# for machine learning
# machine learning .
# learning . Popular
# . Popular techniques
# Popular techniques include
# techniques include the
# include the use
# the use of
# use of word
# of word embeddings
# word embeddings to
# embeddings to capture
# to capture semantic
# capture semantic properties
# semantic properties of
# properties of words
# of words ,
# words , and
# , and an
# and an increase
# an increase in
# increase in end-to-end
# in end-to-end learning
# end-to-end learning of
# learning of a
# of a higher-level
# a higher-level task
# higher-level task (
# task ( e.g.
# ( e.g. ,
# e.g. , question
# , question answering
# question answering )
# answering ) instead
# ) instead of
# instead of relying
# of relying on
# relying on a
# on a pipeline
# a pipeline of
# pipeline of separate
# of separate intermediate
# separate intermediate tasks
# intermediate tasks (
# tasks ( e.g.
# ( e.g. ,
# e.g. , part-of-speech
# , part-of-speech tagging
# part-of-speech tagging and
# tagging and dependency
# and dependency parsing
# dependency parsing )
# parsing ) .
# ) . In
# . In some
# In some areas
# some areas ,
# areas , this
# , this shift
# this shift has
# shift has entailed
# has entailed substantial
# entailed substantial changes
# substantial changes in
# changes in how
# in how NLP
# how NLP systems
# NLP systems are
# systems are designed
# are designed ,
# designed , such
# , such that
# such that deep
# that deep neural
# deep neural network-based
# neural network-based approaches
# network-based approaches may
# approaches may be
# may be viewed
# be viewed as
# viewed as a
# as a new
# a new paradigm
# new paradigm distinct
# paradigm distinct from
# distinct from statistical
# from statistical natural
# statistical natural language
# natural language processing
# language processing .
# processing . For
# . For instance
# For instance ,
# instance , the
# , the term
# the term neural
# term neural machine
# neural machine translation
# machine translation (
# translation ( NMT
# ( NMT )
# NMT ) emphasizes
# ) emphasizes the
# emphasizes the fact
# the fact that
# fact that deep
# that deep learning-based
# deep learning-based approaches
# learning-based approaches to
# approaches to machine
# to machine translation
# machine translation directly
# translation directly learn
# directly learn sequence-to-sequence
# learn sequence-to-sequence transformations
# sequence-to-sequence transformations ,
# transformations , obviating
# , obviating the
# obviating the need
# the need for
# need for intermediate
# for intermediate steps
# intermediate steps such
# steps such as
# such as word
# as word alignment
# word alignment and
# alignment and language
# and language modeling
# language modeling that
# modeling that was
# that was used
# was used in
# used in statistical
# in statistical machine
# statistical machine translation
# machine translation (
# translation ( SMT
# ( SMT )
# SMT ) .
# ) . Latest
# . Latest works
# Latest works tend
# works tend to
# tend to use
# to use non-technical
# use non-technical structure
# non-technical structure of
# structure of a
# of a given
# a given task
# given task to
# task to build
# to build proper
# build proper neural
# proper neural network
# neural network .
# network . [
# . [ 20
# [ 20 ]
# 20 ] The
# ] The following
# The following is
# following is a
# is a list
# a list of
# list of some
# of some of
# some of the
# of the most
# the most commonly
# most commonly researched
# commonly researched tasks
# researched tasks in
# tasks in natural
# in natural language
# natural language processing
# language processing .
# processing . Some
# . Some of
# Some of these
# of these tasks
# these tasks have
# tasks have direct
# have direct real-world
# direct real-world applications
# real-world applications ,
# applications , while
# , while others
# while others more
# others more commonly
# more commonly serve
# commonly serve as
# serve as subtasks
# as subtasks that
# subtasks that are
# that are used
# are used to
# used to aid
# to aid in
# aid in solving
# in solving larger
# solving larger tasks
# larger tasks .
# tasks . Though
# . Though natural
# Though natural language
# natural language processing
# language processing tasks
# processing tasks are
# tasks are closely
# are closely intertwined
# closely intertwined ,
# intertwined , they
# , they can
# they can be
# can be subdivided
# be subdivided into
# subdivided into categories
# into categories for
# categories for convenience
# for convenience .
# convenience . A
# . A coarse
# A coarse division
# coarse division is
# division is given
# is given below
# given below .
# below . Based
# . Based on
# Based on long-standing
# on long-standing trends
# long-standing trends in
# trends in the
# in the field
# the field ,
# field , it
# , it is
# it is possible
# is possible to
# possible to extrapolate
# to extrapolate future
# extrapolate future directions
# future directions of
# directions of NLP
# of NLP .
# NLP . As
# . As of
# As of 2020
# of 2020 ,
# 2020 , three
# , three trends
# three trends among
# trends among the
# among the topics
# the topics of
# topics of the
# of the long-standing
# the long-standing series
# long-standing series of
# series of CoNLL
# of CoNLL Shared
# CoNLL Shared Tasks
# Shared Tasks can
# Tasks can be
# can be observed
# be observed :
# observed : [
# : [ 36
# [ 36 ]
# 36 ] Most
# ] Most higher-level
# Most higher-level NLP
# higher-level NLP applications
# NLP applications involve
# applications involve aspects
# involve aspects that
# aspects that emulate
# that emulate intelligent
# emulate intelligent behaviour
# intelligent behaviour and
# behaviour and apparent
# and apparent comprehension
# apparent comprehension of
# comprehension of natural
# of natural language
# natural language .
# language . More
# . More broadly
# More broadly speaking
# broadly speaking ,
# speaking , the
# , the technical
# the technical operationalization
# technical operationalization of
# operationalization of increasingly
# of increasingly advanced
# increasingly advanced aspects
# advanced aspects of
# aspects of cognitive
# of cognitive behaviour
# cognitive behaviour represents
# behaviour represents one
# represents one of
# one of the
# of the developmental
# the developmental trajectories
# developmental trajectories of
# trajectories of NLP
# of NLP (
# NLP ( see
# ( see trends
# see trends among
# trends among CoNLL
# among CoNLL shared
# CoNLL shared tasks
# shared tasks above
# tasks above )
# above ) .
# ) . Cognition
# . Cognition refers
# Cognition refers to
# refers to ``
# to `` the
# `` the mental
# the mental action
# mental action or
# action or process
# or process of
# process of acquiring
# of acquiring knowledge
# acquiring knowledge and
# knowledge and understanding
# and understanding through
# understanding through thought
# through thought ,
# thought , experience
# , experience ,
# experience , and
# , and the
# and the senses
# the senses .
# senses . ``
# . `` [
# `` [ 37
# [ 37 ]
# 37 ] Cognitive
# ] Cognitive science
# Cognitive science is
# science is the
# is the interdisciplinary
# the interdisciplinary ,
# interdisciplinary , scientific
# , scientific study
# scientific study of
# study of the
# of the mind
# the mind and
# mind and its
# and its processes
# its processes .
# processes . [
# . [ 38
# [ 38 ]
# 38 ] Cognitive
# ] Cognitive linguistics
# Cognitive linguistics is
# linguistics is an
# is an interdisciplinary
# an interdisciplinary branch
# interdisciplinary branch of
# branch of linguistics
# of linguistics ,
# linguistics , combining
# , combining knowledge
# combining knowledge and
# knowledge and research
# and research from
# research from both
# from both psychology
# both psychology and
# psychology and linguistics
# and linguistics .
# linguistics . [
# . [ 39
# [ 39 ]
# 39 ] Especially
# ] Especially during
# Especially during the
# during the age
# the age of
# age of symbolic
# of symbolic NLP
# symbolic NLP ,
# NLP , the
# , the area
# the area of
# area of computational
# of computational linguistics
# computational linguistics maintained
# linguistics maintained strong
# maintained strong ties
# strong ties with
# ties with cognitive
# with cognitive studies
# cognitive studies .
# studies . As
# . As an
# As an example
# an example ,
# example , George
# , George Lakoff
# George Lakoff offers
# Lakoff offers a
# offers a methodology
# a methodology to
# methodology to build
# to build natural
# build natural language
# natural language processing
# language processing (
# processing ( NLP
# ( NLP )
# NLP ) algorithms
# ) algorithms through
# algorithms through the
# through the perspective
# the perspective of
# perspective of cognitive
# of cognitive science
# cognitive science ,
# science , along
# , along with
# along with the
# with the findings
# the findings of
# findings of cognitive
# of cognitive linguistics
# cognitive linguistics ,
# linguistics , [
# , [ 40
# [ 40 ]
# 40 ] with
# ] with two
# with two defining
# two defining aspects
# defining aspects :
# aspects : Ties
# : Ties with
# Ties with cognitive
# with cognitive linguistics
# cognitive linguistics are
# linguistics are part
# are part of
# part of the
# of the historical
# the historical heritage
# historical heritage of
# heritage of NLP
# of NLP ,
# NLP , but
# , but they
# but they have
# they have been
# have been less
# been less frequently
# less frequently addressed
# frequently addressed since
# addressed since the
# since the statistical
# the statistical turn
# statistical turn during
# turn during the
# during the 1990s
# the 1990s .
# 1990s . Nevertheless
# . Nevertheless ,
# Nevertheless , approaches
# , approaches to
# approaches to develop
# to develop cognitive
# develop cognitive models
# cognitive models towards
# models towards technically
# towards technically operationalizable
# technically operationalizable frameworks
# operationalizable frameworks have
# frameworks have been
# have been pursued
# been pursued in
# pursued in the
# in the context
# the context of
# context of various
# of various frameworks
# various frameworks ,
# frameworks , e.g.
# , e.g. ,
# e.g. , of
# , of cognitive
# of cognitive grammar
# cognitive grammar ,
# grammar , [
# , [ 42
# [ 42 ]
# 42 ] functional
# ] functional grammar
# functional grammar ,
# grammar , [
# , [ 43
# [ 43 ]
# 43 ] construction
# ] construction grammar
# construction grammar ,
# grammar , [
# , [ 44
# [ 44 ]
# 44 ] computational
# ] computational psycholinguistics
# computational psycholinguistics and
# psycholinguistics and cognitive
# and cognitive neuroscience
# cognitive neuroscience (
# neuroscience ( e.g.
# ( e.g. ,
# e.g. , ACT-R
# , ACT-R )
# ACT-R ) ,
# ) , however
# , however ,
# however , with
# , with limited
# with limited uptake
# limited uptake in
# uptake in mainstream
# in mainstream NLP
# mainstream NLP (
# NLP ( as
# ( as measured
# as measured by
# measured by presence
# by presence on
# presence on major
# on major conferences
# major conferences [
# conferences [ 45
# [ 45 ]
# 45 ] of
# ] of the
# of the ACL
# the ACL )
# ACL ) .
# ) . More
# . More recently
# More recently ,
# recently , ideas
# , ideas of
# ideas of cognitive
# of cognitive NLP
# cognitive NLP have
# NLP have been
# have been revived
# been revived as
# revived as an
# as an approach
# an approach to
# approach to achieve
# to achieve explainability
# achieve explainability ,
# explainability , e.g.
# , e.g. ,
# e.g. , under
# , under the
# under the notion
# the notion of
# notion of ``
# of `` cognitive
# `` cognitive AI
# cognitive AI ''
# AI '' .
# '' . [
# . [ 46
# [ 46 ]
# 46 ] Likewise
# ] Likewise ,
# Likewise , ideas
# , ideas of
# ideas of cognitive
# of cognitive NLP
# cognitive NLP are
# NLP are inherent
# are inherent to
# inherent to neural
# to neural models
# neural models multimodal
# models multimodal NLP
# multimodal NLP (
# NLP ( although
# ( although rarely
# although rarely made
# rarely made explicit
# made explicit )
# explicit ) .
# ) . [
# . [ 47
# {'Natural language processing': ['(', 'has'],
#  'language processing (': ['NLP', 'NLP'],
#  'processing ( NLP': [')', ')'],
#  '( NLP )': ['is', 'algorithms'],
#  'NLP ) is': ['a'],
#  ') is a': ['subfield'],
#  'is a subfield': ['of'],
#  'a subfield of': ['linguistics'],
#  'subfield of linguistics': [','],
#  'of linguistics ,': ['computer', 'combining'],
#  'linguistics , computer': ['science'],
#  ', computer science': [','],
#  'computer science ,': ['and'],
#  'science , and': ['artificial'],
#  ', and artificial': ['intelligence'],
#  'and artificial intelligence': ['concerned'],
#  'artificial intelligence concerned': ['with'],
#  'intelligence concerned with': ['the'],
#  'concerned with the': ['interactions'],
#  'with the interactions': ['between'],
#  'the interactions between': ['computers'],
#  'interactions between computers': ['and'],
#  'between computers and': ['human'],
#  'computers and human': ['language'],
#  'and human language': [','],
#  'human language ,': ['in'],
#  'language , in': ['particular'],
#  ', in particular': ['how'],
#  'in particular how': ['to'],
#  'particular how to': ['program'],
#  'how to program': ['computers'],
#  'to program computers': ['to'],
#  'program computers to': ['process'],
#  'computers to process': ['and'],
#  'to process and': ['analyze'],
#  'process and analyze': ['large'],
#  'and analyze large': ['amounts'],
#  'analyze large amounts': ['of'],
#  'large amounts of': ['natural'],
#  'amounts of natural': ['language'],
#  'of natural language': ['data', '.', '.'],
#  'natural language data': ['.'],
#  'language data .': ['The'],
#  'data . The': ['goal', 'cache'],
#  '. The goal': ['is'],
#  'The goal is': ['a'],
#  'goal is a': ['computer'],
#  'is a computer': ['capable'],
#  'a computer capable': ['of'],
#  'computer capable of': ['``'],
#  'capable of ``': ['understanding'],
#  'of `` understanding': ["''"],
#  "`` understanding ''": ['the'],
#  "understanding '' the": ['contents'],
#  "'' the contents": ['of'],
#  'the contents of': ['documents'],
#  'contents of documents': [','],
#  'of documents ,': ['including', 'possibly'],
#  'documents , including': ['the'],
#  ', including the': ['contextual'],
#  'including the contextual': ['nuances'],
#  'the contextual nuances': ['of'],
#  'contextual nuances of': ['the'],
#  'nuances of the': ['language'],
#  'of the language': ['within'],
#  'the language within': ['them'],
#  'language within them': ['.'],
#  'within them .': ['The'],
#  'them . The': ['technology'],
#  '. The technology': ['can'],
#  'The technology can': ['then'],
#  'technology can then': ['accurately'],
#  'can then accurately': ['extract'],
#  'then accurately extract': ['information'],
#  'accurately extract information': ['and'],
#  'extract information and': ['insights'],
#  'information and insights': ['contained'],
#  'and insights contained': ['in'],
#  'insights contained in': ['the'],
#  'contained in the': ['documents'],
#  'in the documents': ['as'],
#  'the documents as': ['well'],
#  'documents as well': ['as'],
#  'as well as': ['categorize'],
#  'well as categorize': ['and'],
#  'as categorize and': ['organize'],
#  'categorize and organize': ['the'],
#  'and organize the': ['documents'],
#  'organize the documents': ['themselves'],
#  'the documents themselves': ['.'],
#  'documents themselves .': ['Challenges'],
#  'themselves . Challenges': ['in'],
#  '. Challenges in': ['natural'],
#  'Challenges in natural': ['language'],
#  'in natural language': ['processing',
#   'processing',
#   'processing',
#   'processing'],
#  'natural language processing': ['frequently',
#   'systems',
#   'with',
#   '.',
#   'research',
#   ',',
#   '.',
#   '.',
#   'tasks',
#   '('],
#  'language processing frequently': ['involve'],
#  'processing frequently involve': ['speech'],
#  'frequently involve speech': ['recognition'],
#  'involve speech recognition': [','],
#  'speech recognition ,': ['natural'],
#  'recognition , natural': ['language'],
#  ', natural language': ['understanding'],
#  'natural language understanding': [',', '('],
#  'language understanding ,': ['and'],
#  'understanding , and': ['natural'],
#  ', and natural': ['language'],
#  'and natural language': ['generation'],
#  'natural language generation': ['.'],
#  'language generation .': ['Natural'],
#  'generation . Natural': ['language'],
#  '. Natural language': ['processing'],
#  'language processing has': ['its'],
#  'processing has its': ['roots'],
#  'has its roots': ['in'],
#  'its roots in': ['the'],
#  'roots in the': ['1950s'],
#  'in the 1950s': ['.'],
#  'the 1950s .': ['Already'],
#  '1950s . Already': ['in'],
#  '. Already in': ['1950'],
#  'Already in 1950': [','],
#  'in 1950 ,': ['Alan'],
#  '1950 , Alan': ['Turing'],
#  ', Alan Turing': ['published'],
#  'Alan Turing published': ['an'],
#  'Turing published an': ['article'],
#  'published an article': ['titled'],
#  'an article titled': ['``'],
#  'article titled ``': ['Computing'],
#  'titled `` Computing': ['Machinery'],
#  '`` Computing Machinery': ['and'],
#  'Computing Machinery and': ['Intelligence'],
#  'Machinery and Intelligence': ["''"],
#  "and Intelligence ''": ['which'],
#  "Intelligence '' which": ['proposed'],
#  "'' which proposed": ['what'],
#  'which proposed what': ['is'],
#  'proposed what is': ['now'],
#  'what is now': ['called'],
#  'is now called': ['the'],
#  'now called the': ['Turing'],
#  'called the Turing': ['test'],
#  'the Turing test': ['as'],
#  'Turing test as': ['a'],
#  'test as a': ['criterion'],
#  'as a criterion': ['of'],
#  'a criterion of': ['intelligence'],
#  'criterion of intelligence': [','],
#  'of intelligence ,': ['though'],
#  'intelligence , though': ['at'],
#  ', though at': ['the'],
#  'though at the': ['time'],
#  'at the time': ['that'],
#  'the time that': ['was'],
#  'time that was': ['not'],
#  'that was not': ['articulated'],
#  'was not articulated': ['as'],
#  'not articulated as': ['a'],
#  'articulated as a': ['problem'],
#  'as a problem': ['separate'],
#  'a problem separate': ['from'],
#  'problem separate from': ['artificial'],
#  'separate from artificial': ['intelligence'],
#  'from artificial intelligence': ['.'],
#  'artificial intelligence .': ['The'],
#  'intelligence . The': ['proposed'],
#  '. The proposed': ['test'],
#  'The proposed test': ['includes'],
#  'proposed test includes': ['a'],
#  'test includes a': ['task'],
#  'includes a task': ['that'],
#  'a task that': ['involves'],
#  'task that involves': ['the'],
#  'that involves the': ['automated'],
#  'involves the automated': ['interpretation'],
#  'the automated interpretation': ['and'],
#  'automated interpretation and': ['generation'],
#  'interpretation and generation': ['of'],
#  'and generation of': ['natural'],
#  'generation of natural': ['language'],
#  'natural language .': ['The', 'More'],
#  'language . The': ['premise'],
#  '. The premise': ['of'],
#  'The premise of': ['symbolic'],
#  'premise of symbolic': ['NLP'],
#  'of symbolic NLP': ['is', ','],
#  'symbolic NLP is': ['well-summarized'],
#  'NLP is well-summarized': ['by'],
#  'is well-summarized by': ['John'],
#  'well-summarized by John': ['Searle'],
#  'by John Searle': ["'s"],
#  "John Searle 's": ['Chinese'],
#  "Searle 's Chinese": ['room'],
#  "'s Chinese room": ['experiment'],
#  'Chinese room experiment': [':'],
#  'room experiment :': ['Given'],
#  'experiment : Given': ['a'],
#  ': Given a': ['collection'],
#  'Given a collection': ['of'],
#  'a collection of': ['rules'],
#  'collection of rules': ['('],
#  'of rules (': ['e.g.'],
#  'rules ( e.g.': [','],
#  '( e.g. ,': ['a', 'question', 'part-of-speech', 'ACT-R'],
#  'e.g. , a': ['Chinese'],
#  ', a Chinese': ['phrasebook'],
#  'a Chinese phrasebook': [','],
#  'Chinese phrasebook ,': ['with'],
#  'phrasebook , with': ['questions'],
#  ', with questions': ['and'],
#  'with questions and': ['matching'],
#  'questions and matching': ['answers'],
#  'and matching answers': [')'],
#  'matching answers )': [','],
#  'answers ) ,': ['the'],
#  ') , the': ['computer'],
#  ', the computer': ['emulates'],
#  'the computer emulates': ['natural'],
#  'computer emulates natural': ['language'],
#  'emulates natural language': ['understanding'],
#  'language understanding (': ['or'],
#  'understanding ( or': ['other'],
#  '( or other': ['NLP'],
#  'or other NLP': ['tasks'],
#  'other NLP tasks': [')'],
#  'NLP tasks )': ['by'],
#  'tasks ) by': ['applying'],
#  ') by applying': ['those'],
#  'by applying those': ['rules'],
#  'applying those rules': ['to'],
#  'those rules to': ['the'],
#  'rules to the': ['data'],
#  'to the data': ['it'],
#  'the data it': ['confronts'],
#  'data it confronts': ['.'],
#  'it confronts .': ['Up'],
#  'confronts . Up': ['to'],
#  '. Up to': ['the'],
#  'Up to the': ['1980s'],
#  'to the 1980s': [','],
#  'the 1980s ,': ['most'],
#  '1980s , most': ['natural'],
#  ', most natural': ['language'],
#  'most natural language': ['processing'],
#  'language processing systems': ['were'],
#  'processing systems were': ['based'],
#  'systems were based': ['on'],
#  'were based on': ['complex'],
#  'based on complex': ['sets'],
#  'on complex sets': ['of'],
#  'complex sets of': ['hand-written'],
#  'sets of hand-written': ['rules'],
#  'of hand-written rules': ['.'],
#  'hand-written rules .': ['Starting', 'However'],
#  'rules . Starting': ['in'],
#  '. Starting in': ['the'],
#  'Starting in the': ['late'],
#  'in the late': ['1980s', '1980s'],
#  'the late 1980s': [',', 'and'],
#  'late 1980s ,': ['however'],
#  '1980s , however': [','],
#  ', however ,': ['there', 'research', 'with'],
#  'however , there': ['was'],
#  ', there was': ['a'],
#  'there was a': ['revolution'],
#  'was a revolution': ['in'],
#  'a revolution in': ['natural'],
#  'revolution in natural': ['language'],
#  'language processing with': ['the'],
#  'processing with the': ['introduction'],
#  'with the introduction': ['of'],
#  'the introduction of': ['machine'],
#  'introduction of machine': ['learning'],
#  'of machine learning': ['algorithms', 'in'],
#  'machine learning algorithms': ['for', ','],
#  'learning algorithms for': ['language'],
#  'algorithms for language': ['processing'],
#  'for language processing': ['.'],
#  'language processing .': ['This', '[', 'That', 'For', 'Some'],
#  'processing . This': ['was'],
#  '. This was': ['due'],
#  'This was due': ['to'],
#  'was due to': ['both'],
#  'due to both': ['the'],
#  'to both the': ['steady'],
#  'both the steady': ['increase'],
#  'the steady increase': ['in'],
#  'steady increase in': ['computational'],
#  'increase in computational': ['power'],
#  'in computational power': ['('],
#  'computational power (': ['see'],
#  'power ( see': ['Moore'],
#  '( see Moore': ["'s"],
#  "see Moore 's": ['law'],
#  "Moore 's law": [')'],
#  "'s law )": ['and'],
#  'law ) and': ['the'],
#  ') and the': ['gradual'],
#  'and the gradual': ['lessening'],
#  'the gradual lessening': ['of'],
#  'gradual lessening of': ['the'],
#  'lessening of the': ['dominance'],
#  'of the dominance': ['of'],
#  'the dominance of': ['Chomskyan'],
#  'dominance of Chomskyan': ['theories'],
#  'of Chomskyan theories': ['of'],
#  'Chomskyan theories of': ['linguistics'],
#  'theories of linguistics': ['('],
#  'of linguistics (': ['e.g'],
#  'linguistics ( e.g': ['.'],
#  '( e.g .': ['transformational'],
#  'e.g . transformational': ['grammar'],
#  '. transformational grammar': [')'],
#  'transformational grammar )': [','],
#  'grammar ) ,': ['whose'],
#  ') , whose': ['theoretical'],
#  ', whose theoretical': ['underpinnings'],
#  'whose theoretical underpinnings': ['discouraged'],
#  'theoretical underpinnings discouraged': ['the'],
#  'underpinnings discouraged the': ['sort'],
#  'discouraged the sort': ['of'],
#  'the sort of': ['corpus'],
#  'sort of corpus': ['linguistics'],
#  'of corpus linguistics': ['that'],
#  'corpus linguistics that': ['underlies'],
#  'linguistics that underlies': ['the'],
#  'that underlies the': ['machine-learning'],
#  'underlies the machine-learning': ['approach'],
#  'the machine-learning approach': ['to'],
#  'machine-learning approach to': ['language'],
#  'approach to language': ['processing'],
#  'to language processing': ['.'],
#  'processing . [': ['6'],
#  '. [ 6': [']'],
#  '[ 6 ]': ['In'],
#  '6 ] In': ['the'],
#  '] In the': ['2010s', 'early'],
#  'In the 2010s': [','],
#  'the 2010s ,': ['representation'],
#  '2010s , representation': ['learning'],
#  ', representation learning': ['and'],
#  'representation learning and': ['deep'],
#  'learning and deep': ['neural'],
#  'and deep neural': ['network-style'],
#  'deep neural network-style': ['machine'],
#  'neural network-style machine': ['learning'],
#  'network-style machine learning': ['methods'],
#  'machine learning methods': ['became'],
#  'learning methods became': ['widespread'],
#  'methods became widespread': ['in'],
#  'became widespread in': ['natural'],
#  'widespread in natural': ['language'],
#  'processing . That': ['popularity'],
#  '. That popularity': ['was'],
#  'That popularity was': ['due'],
#  'popularity was due': ['partly'],
#  'was due partly': ['to'],
#  'due partly to': ['a'],
#  'partly to a': ['flurry'],
#  'to a flurry': ['of'],
#  'a flurry of': ['results'],
#  'flurry of results': ['showing'],
#  'of results showing': ['that'],
#  'results showing that': ['such'],
#  'showing that such': ['techniques'],
#  'that such techniques': ['['],
#  'such techniques [': ['7'],
#  'techniques [ 7': [']'],
#  '[ 7 ]': ['['],
#  '7 ] [': ['8'],
#  '] [ 8': [']'],
#  '[ 8 ]': ['can'],
#  '8 ] can': ['achieve'],
#  '] can achieve': ['state-of-the-art'],
#  'can achieve state-of-the-art': ['results'],
#  'achieve state-of-the-art results': ['in'],
#  'state-of-the-art results in': ['many'],
#  'results in many': ['natural'],
#  'in many natural': ['language'],
#  'many natural language': ['tasks'],
#  'natural language tasks': [','],
#  'language tasks ,': ['e.g.'],
#  'tasks , e.g.': [','],
#  ', e.g. ,': ['in', 'of', 'under'],
#  'e.g. , in': ['language'],
#  ', in language': ['modeling'],
#  'in language modeling': ['['],
#  'language modeling [': ['9'],
#  'modeling [ 9': [']'],
#  '[ 9 ]': ['and'],
#  '9 ] and': ['parsing'],
#  '] and parsing': ['.'],
#  'and parsing .': ['['],
#  'parsing . [': ['10'],
#  '. [ 10': [']'],
#  '[ 10 ]': ['['],
#  '10 ] [': ['11'],
#  '] [ 11': [']'],
#  '[ 11 ]': ['This'],
#  '11 ] This': ['is'],
#  '] This is': ['increasingly'],
#  'This is increasingly': ['important'],
#  'is increasingly important': ['in'],
#  'increasingly important in': ['medicine'],
#  'important in medicine': ['and'],
#  'in medicine and': ['healthcare'],
#  'medicine and healthcare': [','],
#  'and healthcare ,': ['where'],
#  'healthcare , where': ['NLP'],
#  ', where NLP': ['helps'],
#  'where NLP helps': ['analyze'],
#  'NLP helps analyze': ['notes'],
#  'helps analyze notes': ['and'],
#  'analyze notes and': ['text'],
#  'notes and text': ['in'],
#  'and text in': ['electronic'],
#  'text in electronic': ['health'],
#  'in electronic health': ['records'],
#  'electronic health records': ['that'],
#  'health records that': ['would'],
#  'records that would': ['otherwise'],
#  'that would otherwise': ['be'],
#  'would otherwise be': ['inaccessible'],
#  'otherwise be inaccessible': ['for'],
#  'be inaccessible for': ['study'],
#  'inaccessible for study': ['when'],
#  'for study when': ['seeking'],
#  'study when seeking': ['to'],
#  'when seeking to': ['improve'],
#  'seeking to improve': ['care'],
#  'to improve care': ['.'],
#  'improve care .': ['['],
#  'care . [': ['12'],
#  '. [ 12': [']'],
#  '[ 12 ]': ['In'],
#  '12 ] In': ['the'],
#  'In the early': ['days'],
#  'the early days': [','],
#  'early days ,': ['many'],
#  'days , many': ['language-processing'],
#  ', many language-processing': ['systems'],
#  'many language-processing systems': ['were'],
#  'language-processing systems were': ['designed'],
#  'systems were designed': ['by'],
#  'were designed by': ['symbolic'],
#  'designed by symbolic': ['methods'],
#  'by symbolic methods': [','],
#  'symbolic methods ,': ['i.e.'],
#  'methods , i.e.': [','],
#  ', i.e. ,': ['the'],
#  'i.e. , the': ['hand-coding'],
#  ', the hand-coding': ['of'],
#  'the hand-coding of': ['a'],
#  'hand-coding of a': ['set'],
#  'of a set': ['of'],
#  'a set of': ['rules', 'documents'],
#  'set of rules': [','],
#  'of rules ,': ['coupled'],
#  'rules , coupled': ['with'],
#  ', coupled with': ['a'],
#  'coupled with a': ['dictionary'],
#  'with a dictionary': ['lookup'],
#  'a dictionary lookup': [':'],
#  'dictionary lookup :': ['['],
#  'lookup : [': ['13'],
#  ': [ 13': [']'],
#  '[ 13 ]': ['['],
#  '13 ] [': ['14'],
#  '] [ 14': [']'],
#  '[ 14 ]': ['such'],
#  '14 ] such': ['as'],
#  '] such as': ['by'],
#  'such as by': ['writing'],
#  'as by writing': ['grammars'],
#  'by writing grammars': ['or'],
#  'writing grammars or': ['devising'],
#  'grammars or devising': ['heuristic'],
#  'or devising heuristic': ['rules'],
#  'devising heuristic rules': ['for'],
#  'heuristic rules for': ['stemming'],
#  'rules for stemming': ['.'],
#  'for stemming .': ['More'],
#  'stemming . More': ['recent'],
#  '. More recent': ['systems'],
#  'More recent systems': ['based'],
#  'recent systems based': ['on'],
#  'systems based on': ['machine-learning'],
#  'based on machine-learning': ['algorithms'],
#  'on machine-learning algorithms': ['have'],
#  'machine-learning algorithms have': ['many', 'been'],
#  'algorithms have many': ['advantages'],
#  'have many advantages': ['over'],
#  'many advantages over': ['hand-produced'],
#  'advantages over hand-produced': ['rules'],
#  'over hand-produced rules': [':'],
#  'hand-produced rules :': ['Despite'],
#  'rules : Despite': ['the'],
#  ': Despite the': ['popularity'],
#  'Despite the popularity': ['of'],
#  'the popularity of': ['machine'],
#  'popularity of machine': ['learning'],
#  'machine learning in': ['NLP'],
#  'learning in NLP': ['research'],
#  'in NLP research': [',', 'have'],
#  'NLP research ,': ['symbolic'],
#  'research , symbolic': ['methods'],
#  ', symbolic methods': ['are'],
#  'symbolic methods are': ['still'],
#  'methods are still': ['('],
#  'are still (': ['2020'],
#  'still ( 2020': [')'],
#  '( 2020 )': ['commonly'],
#  '2020 ) commonly': ['used'],
#  ') commonly used': [':'],
#  'commonly used :': ['Since'],
#  'used : Since': ['the'],
#  ': Since the': ['so-called'],
#  'Since the so-called': ['``'],
#  'the so-called ``': ['statistical'],
#  'so-called `` statistical': ['revolution'],
#  '`` statistical revolution': ["''"],
#  "statistical revolution ''": ['['],
#  "revolution '' [": ['15'],
#  "'' [ 15": [']'],
#  '[ 15 ]': ['['],
#  '15 ] [': ['16'],
#  '] [ 16': [']'],
#  '[ 16 ]': ['in'],
#  '16 ] in': ['the'],
#  '] in the': ['late'],
#  'late 1980s and': ['mid-1990s'],
#  '1980s and mid-1990s': [','],
#  'and mid-1990s ,': ['much'],
#  'mid-1990s , much': ['natural'],
#  ', much natural': ['language'],
#  'much natural language': ['processing'],
#  'language processing research': ['has'],
#  'processing research has': ['relied'],
#  'research has relied': ['heavily'],
#  'has relied heavily': ['on'],
#  'relied heavily on': ['machine'],
#  'heavily on machine': ['learning'],
#  'on machine learning': ['.'],
#  'machine learning .': ['The', 'Popular'],
#  'learning . The': ['machine-learning'],
#  '. The machine-learning': ['paradigm'],
#  'The machine-learning paradigm': ['calls'],
#  'machine-learning paradigm calls': ['instead'],
#  'paradigm calls instead': ['for'],
#  'calls instead for': ['using'],
#  'instead for using': ['statistical'],
#  'for using statistical': ['inference'],
#  'using statistical inference': ['to'],
#  'statistical inference to': ['automatically'],
#  'inference to automatically': ['learn'],
#  'to automatically learn': ['such'],
#  'automatically learn such': ['rules'],
#  'learn such rules': ['through'],
#  'such rules through': ['the'],
#  'rules through the': ['analysis'],
#  'through the analysis': ['of'],
#  'the analysis of': ['large'],
#  'analysis of large': ['corpora'],
#  'of large corpora': ['('],
#  'large corpora (': ['the'],
#  'corpora ( the': ['plural'],
#  '( the plural': ['form'],
#  'the plural form': ['of'],
#  'plural form of': ['corpus'],
#  'form of corpus': [','],
#  'of corpus ,': ['is'],
#  'corpus , is': ['a'],
#  ', is a': ['set'],
#  'is a set': ['of'],
#  'set of documents': [','],
#  'documents , possibly': ['with'],
#  ', possibly with': ['human'],
#  'possibly with human': ['or'],
#  'with human or': ['computer'],
#  'human or computer': ['annotations'],
#  'or computer annotations': [')'],
#  'computer annotations )': ['of'],
#  'annotations ) of': ['typical'],
#  ') of typical': ['real-world'],
#  'of typical real-world': ['examples'],
#  'typical real-world examples': ['.'],
#  'real-world examples .': ['Many'],
#  'examples . Many': ['different'],
#  '. Many different': ['classes'],
#  'Many different classes': ['of'],
#  'different classes of': ['machine-learning'],
#  'classes of machine-learning': ['algorithms'],
#  'of machine-learning algorithms': ['have'],
#  'algorithms have been': ['applied'],
#  'have been applied': ['to'],
#  'been applied to': ['natural-language-processing'],
#  'applied to natural-language-processing': ['tasks'],
#  'to natural-language-processing tasks': ['.'],
#  'natural-language-processing tasks .': ['These'],
#  'tasks . These': ['algorithms'],
#  '. These algorithms': ['take'],
#  'These algorithms take': ['as'],
#  'algorithms take as': ['input'],
#  'take as input': ['a'],
#  'as input a': ['large'],
#  'input a large': ['set'],
#  'a large set': ['of'],
#  'large set of': ['``'],
#  'set of ``': ['features'],
#  'of `` features': ["''"],
#  "`` features ''": ['that'],
#  "features '' that": ['are'],
#  "'' that are": ['generated'],
#  'that are generated': ['from'],
#  'are generated from': ['the'],
#  'generated from the': ['input'],
#  'from the input': ['data'],
#  'the input data': ['.', '.'],
#  'input data .': ['Increasingly', 'The'],
#  'data . Increasingly': [','],
#  '. Increasingly ,': ['however'],
#  'Increasingly , however': [','],
#  'however , research': ['has'],
#  ', research has': ['focused', 'focused'],
#  'research has focused': ['on', 'on'],
#  'has focused on': ['statistical', 'statistical'],
#  'focused on statistical': ['models', 'models'],
#  'on statistical models': [',', ','],
#  'statistical models ,': ['which', 'which'],
#  'models , which': ['make', 'make'],
#  ', which make': ['soft', 'soft'],
#  'which make soft': [',', ','],
#  'make soft ,': ['probabilistic', 'probabilistic'],
#  'soft , probabilistic': ['decisions', 'decisions'],
#  ', probabilistic decisions': ['based', 'based'],
#  'probabilistic decisions based': ['on', 'on'],
#  'decisions based on': ['attaching', 'attaching'],
#  'based on attaching': ['real-valued', 'real-valued'],
#  'on attaching real-valued': ['weights', 'weights'],
#  'attaching real-valued weights': ['to', 'to'],
#  'real-valued weights to': ['each', 'the'],
#  'weights to each': ['input'],
#  'to each input': ['feature'],
#  'each input feature': ['('],
#  'input feature (': ['complex-valued'],
#  'feature ( complex-valued': ['embeddings'],
#  '( complex-valued embeddings': [','],
#  'complex-valued embeddings ,': ['['],
#  'embeddings , [': ['17'],
#  ', [ 17': [']'],
#  '[ 17 ]': ['and'],
#  '17 ] and': ['neural'],
#  '] and neural': ['networks'],
#  'and neural networks': ['in'],
#  'neural networks in': ['general'],
#  'networks in general': ['have'],
#  'in general have': ['also'],
#  'general have also': ['been'],
#  'have also been': ['proposed'],
#  'also been proposed': [','],
#  'been proposed ,': ['for'],
#  'proposed , for': ['e.g'],
#  ', for e.g': ['.'],
#  'for e.g .': ['speech'],
#  'e.g . speech': ['['],
#  '. speech [': ['18'],
#  'speech [ 18': [']'],
#  '[ 18 ]': [')'],
#  '18 ] )': ['.'],
#  '] ) .': ['Such'],
#  ') . Such': ['models'],
#  '. Such models': ['have', 'are'],
#  'Such models have': ['the'],
#  'models have the': ['advantage'],
#  'have the advantage': ['that'],
#  'the advantage that': ['they'],
#  'advantage that they': ['can'],
#  'that they can': ['express'],
#  'they can express': ['the'],
#  'can express the': ['relative'],
#  'express the relative': ['certainty'],
#  'the relative certainty': ['of'],
#  'relative certainty of': ['many'],
#  'certainty of many': ['different'],
#  'of many different': ['possible'],
#  'many different possible': ['answers'],
#  'different possible answers': ['rather'],
#  'possible answers rather': ['than'],
#  'answers rather than': ['only'],
#  'rather than only': ['one'],
#  'than only one': [','],
#  'only one ,': ['producing'],
#  'one , producing': ['more'],
#  ', producing more': ['reliable'],
#  'producing more reliable': ['results'],
#  'more reliable results': ['when', 'when'],
#  'reliable results when': ['such', 'integrated'],
#  'results when such': ['a'],
#  'when such a': ['model'],
#  'such a model': ['is'],
#  'a model is': ['included'],
#  'model is included': ['as'],
#  'is included as': ['a'],
#  'included as a': ['component'],
#  'as a component': ['of'],
#  'a component of': ['a'],
#  'component of a': ['larger'],
#  'of a larger': ['system'],
#  'a larger system': ['.', 'comprising'],
#  'larger system .': ['Some'],
#  'system . Some': ['of'],
#  '. Some of': ['the', 'these'],
#  'Some of the': ['earliest-used'],
#  'of the earliest-used': ['machine'],
#  'the earliest-used machine': ['learning'],
#  'earliest-used machine learning': ['algorithms'],
#  'learning algorithms ,': ['such'],
#  'algorithms , such': ['as'],
#  ', such as': ['decision'],
#  'such as decision': ['trees'],
#  'as decision trees': [','],
#  'decision trees ,': ['produced'],
#  'trees , produced': ['systems'],
#  ', produced systems': ['of'],
#  'produced systems of': ['hard'],
#  'systems of hard': ['if-then'],
#  'of hard if-then': ['rules'],
#  'hard if-then rules': ['similar'],
#  'if-then rules similar': ['to'],
#  'rules similar to': ['existing'],
#  'similar to existing': ['hand-written'],
#  'to existing hand-written': ['rules'],
#  'existing hand-written rules': ['.'],
#  'rules . However': [','],
#  '. However ,': ['part-of-speech', 'they'],
#  'However , part-of-speech': ['tagging'],
#  ', part-of-speech tagging': ['introduced', 'and'],
#  'part-of-speech tagging introduced': ['the'],
#  'tagging introduced the': ['use'],
#  'introduced the use': ['of'],
#  'the use of': ['hidden', 'word'],
#  'use of hidden': ['Markov'],
#  'of hidden Markov': ['models'],
#  'hidden Markov models': ['to'],
#  'Markov models to': ['natural'],
#  'models to natural': ['language'],
#  'to natural language': ['processing'],
#  'language processing ,': ['and'],
#  'processing , and': ['increasingly'],
#  ', and increasingly': [','],
#  'and increasingly ,': ['research'],
#  'increasingly , research': ['has'],
#  'weights to the': ['features'],
#  'to the features': ['making'],
#  'the features making': ['up'],
#  'features making up': ['the'],
#  'making up the': ['input'],
#  'up the input': ['data'],
#  '. The cache': ['language'],
#  'The cache language': ['models'],
#  'cache language models': ['upon'],
#  'language models upon': ['which'],
#  'models upon which': ['many'],
#  'upon which many': ['speech'],
#  'which many speech': ['recognition'],
#  'many speech recognition': ['systems'],
#  'speech recognition systems': ['now'],
#  'recognition systems now': ['rely'],
#  'systems now rely': ['are'],
#  'now rely are': ['examples'],
#  'rely are examples': ['of'],
#  'are examples of': ['such'],
#  'examples of such': ['statistical'],
#  'of such statistical': ['models'],
#  'such statistical models': ['.'],
#  'statistical models .': ['Such'],
#  'models . Such': ['models'],
#  'Such models are': ['generally'],
#  'models are generally': ['more'],
#  'are generally more': ['robust'],
#  'generally more robust': ['when'],
#  'more robust when': ['given'],
#  'robust when given': ['unfamiliar'],
#  'when given unfamiliar': ['input'],
#  'given unfamiliar input': [','],
#  'unfamiliar input ,': ['especially'],
#  'input , especially': ['input'],
#  ', especially input': ['that'],
#  'especially input that': ['contains'],
#  'input that contains': ['errors'],
#  'that contains errors': ['('],
#  'contains errors (': ['as'],
#  'errors ( as': ['is'],
#  '( as is': ['very'],
#  'as is very': ['common'],
#  'is very common': ['for'],
#  'very common for': ['real-world'],
#  'common for real-world': ['data'],
#  'for real-world data': [')'],
#  'real-world data )': [','],
#  'data ) ,': ['and'],
#  ') , and': ['produce'],
#  ', and produce': ['more'],
#  'and produce more': ['reliable'],
#  'produce more reliable': ['results'],
#  'results when integrated': ['into'],
#  'when integrated into': ['a'],
#  'integrated into a': ['larger'],
#  'into a larger': ['system'],
#  'larger system comprising': ['multiple'],
#  'system comprising multiple': ['subtasks'],
#  'comprising multiple subtasks': ['.'],
#  'multiple subtasks .': ['Since'],
#  'subtasks . Since': ['the'],
#  '. Since the': ['neural'],
#  'Since the neural': ['turn'],
#  'the neural turn': [','],
#  'neural turn ,': ['statistical'],
#  'turn , statistical': ['methods'],
#  ', statistical methods': ['in'],
#  'statistical methods in': ['NLP'],
#  'methods in NLP': ['research'],
#  'NLP research have': ['been'],
#  'research have been': ['largely'],
#  'have been largely': ['replaced'],
#  'been largely replaced': ['by'],
#  'largely replaced by': ['neural'],
#  'replaced by neural': ['networks'],
#  'by neural networks': ['.'],
#  'neural networks .': ['However'],
#  'networks . However': [','],
#  'However , they': ['continue'],
#  ', they continue': ['to'],
#  'they continue to': ['be'],
#  'continue to be': ['relevant'],
#  'to be relevant': ['for'],
#  'be relevant for': ['contexts'],
#  'relevant for contexts': ['in'],
#  'for contexts in': ['which'],
#  'contexts in which': ['statistical'],
#  'in which statistical': ['interpretability'],
#  'which statistical interpretability': ['and'],
#  'statistical interpretability and': ['transparency'],
#  'interpretability and transparency': ['is'],
#  'and transparency is': ['required'],
#  'transparency is required': ['.'],
#  'is required .': ['A'],
#  'required . A': ['major'],
#  '. A major': ['drawback'],
#  'A major drawback': ['of'],
#  'major drawback of': ['statistical'],
#  'drawback of statistical': ['methods'],
#  'of statistical methods': ['is'],
#  'statistical methods is': ['that'],
#  'methods is that': ['they'],
#  'is that they': ['require'],
#  'that they require': ['elaborate'],
#  'they require elaborate': ['feature'],
#  'require elaborate feature': ['engineering'],
#  'elaborate feature engineering': ['.'],
#  'feature engineering .': ['Since'],
#  'engineering . Since': ['2015'],
#  '. Since 2015': [','],
#  'Since 2015 ,': ['['],
#  '2015 , [': ['19'],
#  ', [ 19': [']'],
#  '[ 19 ]': ['the'],
#  '19 ] the': ['field'],
#  '] the field': ['has'],
#  'the field has': ['thus'],
#  'field has thus': ['largely'],
#  'has thus largely': ['abandoned'],
#  'thus largely abandoned': ['statistical'],
#  'largely abandoned statistical': ['methods'],
#  'abandoned statistical methods': ['and'],
#  'statistical methods and': ['shifted'],
#  'methods and shifted': ['to'],
#  'and shifted to': ['neural'],
#  'shifted to neural': ['networks'],
#  'to neural networks': ['for'],
#  'neural networks for': ['machine'],
#  'networks for machine': ['learning'],
#  'for machine learning': ['.'],
#  'learning . Popular': ['techniques'],
#  '. Popular techniques': ['include'],
#  'Popular techniques include': ['the'],
#  'techniques include the': ['use'],
#  'include the use': ['of'],
#  'use of word': ['embeddings'],
#  'of word embeddings': ['to'],
#  'word embeddings to': ['capture'],
#  'embeddings to capture': ['semantic'],
#  'to capture semantic': ['properties'],
#  'capture semantic properties': ['of'],
#  'semantic properties of': ['words'],
#  'properties of words': [','],
#  'of words ,': ['and'],
#  'words , and': ['an'],
#  ', and an': ['increase'],
#  'and an increase': ['in'],
#  'an increase in': ['end-to-end'],
#  'increase in end-to-end': ['learning'],
#  'in end-to-end learning': ['of'],
#  'end-to-end learning of': ['a'],
#  'learning of a': ['higher-level'],
#  'of a higher-level': ['task'],
#  'a higher-level task': ['('],
#  'higher-level task (': ['e.g.'],
#  'task ( e.g.': [','],
#  'e.g. , question': ['answering'],
#  ', question answering': [')'],
#  'question answering )': ['instead'],
#  'answering ) instead': ['of'],
#  ') instead of': ['relying'],
#  'instead of relying': ['on'],
#  'of relying on': ['a'],
#  'relying on a': ['pipeline'],
#  'on a pipeline': ['of'],
#  'a pipeline of': ['separate'],
#  'pipeline of separate': ['intermediate'],
#  'of separate intermediate': ['tasks'],
#  'separate intermediate tasks': ['('],
#  'intermediate tasks (': ['e.g.'],
#  'tasks ( e.g.': [','],
#  'e.g. , part-of-speech': ['tagging'],
#  'part-of-speech tagging and': ['dependency'],
#  'tagging and dependency': ['parsing'],
#  'and dependency parsing': [')'],
#  'dependency parsing )': ['.'],
#  'parsing ) .': ['In'],
#  ') . In': ['some'],
#  '. In some': ['areas'],
#  'In some areas': [','],
#  'some areas ,': ['this'],
#  'areas , this': ['shift'],
#  ', this shift': ['has'],
#  'this shift has': ['entailed'],
#  'shift has entailed': ['substantial'],
#  'has entailed substantial': ['changes'],
#  'entailed substantial changes': ['in'],
#  'substantial changes in': ['how'],
#  'changes in how': ['NLP'],
#  'in how NLP': ['systems'],
#  'how NLP systems': ['are'],
#  'NLP systems are': ['designed'],
#  'systems are designed': [','],
#  'are designed ,': ['such'],
#  'designed , such': ['that'],
#  ', such that': ['deep'],
#  'such that deep': ['neural'],
#  'that deep neural': ['network-based'],
#  'deep neural network-based': ['approaches'],
#  'neural network-based approaches': ['may'],
#  'network-based approaches may': ['be'],
#  'approaches may be': ['viewed'],
#  'may be viewed': ['as'],
#  'be viewed as': ['a'],
#  'viewed as a': ['new'],
#  'as a new': ['paradigm'],
#  'a new paradigm': ['distinct'],
#  'new paradigm distinct': ['from'],
#  'paradigm distinct from': ['statistical'],
#  'distinct from statistical': ['natural'],
#  'from statistical natural': ['language'],
#  'statistical natural language': ['processing'],
#  'processing . For': ['instance'],
#  '. For instance': [','],
#  'For instance ,': ['the'],
#  'instance , the': ['term'],
#  ', the term': ['neural'],
#  'the term neural': ['machine'],
#  'term neural machine': ['translation'],
#  'neural machine translation': ['('],
#  'machine translation (': ['NMT', 'SMT'],
#  'translation ( NMT': [')'],
#  '( NMT )': ['emphasizes'],
#  'NMT ) emphasizes': ['the'],
#  ') emphasizes the': ['fact'],
#  'emphasizes the fact': ['that'],
#  'the fact that': ['deep'],
#  'fact that deep': ['learning-based'],
#  'that deep learning-based': ['approaches'],
#  'deep learning-based approaches': ['to'],
#  'learning-based approaches to': ['machine'],
#  'approaches to machine': ['translation'],
#  'to machine translation': ['directly'],
#  'machine translation directly': ['learn'],
#  'translation directly learn': ['sequence-to-sequence'],
#  'directly learn sequence-to-sequence': ['transformations'],
#  'learn sequence-to-sequence transformations': [','],
#  'sequence-to-sequence transformations ,': ['obviating'],
#  'transformations , obviating': ['the'],
#  ', obviating the': ['need'],
#  'obviating the need': ['for'],
#  'the need for': ['intermediate'],
#  'need for intermediate': ['steps'],
#  'for intermediate steps': ['such'],
#  'intermediate steps such': ['as'],
#  'steps such as': ['word'],
#  ...}

# %% [markdown]
# ### Step 5: Testing the N-Grams by generating a sequence

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) is a subfield of linguistics , computer science , and artificial intelligence concerned with the interactions between computers and human language , in particular how to program computers to process and analyze large amounts of natural language data . The goal is a computer capable of `` understanding

# %% [markdown]
# ### Building a N-Grams Model with **N-Grams = 4**

# %%
ngrams = {}
words = 4

words_tokens = nltk.word_tokenize(article_text)
for i in range(len(words_tokens)-words):
    seq = ' '.join(words_tokens[i:i+words])
    print(seq)
    if  seq not in ngrams.keys():
        ngrams[seq] = []
    ngrams[seq].append(words_tokens[i+words])

ngrams
# Out:
# Natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) is
# NLP ) is a
# ) is a subfield
# is a subfield of
# a subfield of linguistics
# subfield of linguistics ,
# of linguistics , computer
# linguistics , computer science
# , computer science ,
# computer science , and
# science , and artificial
# , and artificial intelligence
# and artificial intelligence concerned
# artificial intelligence concerned with
# intelligence concerned with the
# concerned with the interactions
# with the interactions between
# the interactions between computers
# interactions between computers and
# between computers and human
# computers and human language
# and human language ,
# human language , in
# language , in particular
# , in particular how
# in particular how to
# particular how to program
# how to program computers
# to program computers to
# program computers to process
# computers to process and
# to process and analyze
# process and analyze large
# and analyze large amounts
# analyze large amounts of
# large amounts of natural
# amounts of natural language
# of natural language data
# natural language data .
# language data . The
# data . The goal
# . The goal is
# The goal is a
# goal is a computer
# is a computer capable
# a computer capable of
# computer capable of ``
# capable of `` understanding
# of `` understanding ''
# `` understanding '' the
# understanding '' the contents
# '' the contents of
# the contents of documents
# contents of documents ,
# of documents , including
# documents , including the
# , including the contextual
# including the contextual nuances
# the contextual nuances of
# contextual nuances of the
# nuances of the language
# of the language within
# the language within them
# language within them .
# within them . The
# them . The technology
# . The technology can
# The technology can then
# technology can then accurately
# can then accurately extract
# then accurately extract information
# accurately extract information and
# extract information and insights
# information and insights contained
# and insights contained in
# insights contained in the
# contained in the documents
# in the documents as
# the documents as well
# documents as well as
# as well as categorize
# well as categorize and
# as categorize and organize
# categorize and organize the
# and organize the documents
# organize the documents themselves
# the documents themselves .
# documents themselves . Challenges
# themselves . Challenges in
# . Challenges in natural
# Challenges in natural language
# in natural language processing
# natural language processing frequently
# language processing frequently involve
# processing frequently involve speech
# frequently involve speech recognition
# involve speech recognition ,
# speech recognition , natural
# recognition , natural language
# , natural language understanding
# natural language understanding ,
# language understanding , and
# understanding , and natural
# , and natural language
# and natural language generation
# natural language generation .
# language generation . Natural
# generation . Natural language
# . Natural language processing
# Natural language processing has
# language processing has its
# processing has its roots
# has its roots in
# its roots in the
# roots in the 1950s
# in the 1950s .
# the 1950s . Already
# 1950s . Already in
# . Already in 1950
# Already in 1950 ,
# in 1950 , Alan
# 1950 , Alan Turing
# , Alan Turing published
# Alan Turing published an
# Turing published an article
# published an article titled
# an article titled ``
# article titled `` Computing
# titled `` Computing Machinery
# `` Computing Machinery and
# Computing Machinery and Intelligence
# Machinery and Intelligence ''
# and Intelligence '' which
# Intelligence '' which proposed
# '' which proposed what
# which proposed what is
# proposed what is now
# what is now called
# is now called the
# now called the Turing
# called the Turing test
# the Turing test as
# Turing test as a
# test as a criterion
# as a criterion of
# a criterion of intelligence
# criterion of intelligence ,
# of intelligence , though
# intelligence , though at
# , though at the
# though at the time
# at the time that
# the time that was
# time that was not
# that was not articulated
# was not articulated as
# not articulated as a
# articulated as a problem
# as a problem separate
# a problem separate from
# problem separate from artificial
# separate from artificial intelligence
# from artificial intelligence .
# artificial intelligence . The
# intelligence . The proposed
# . The proposed test
# The proposed test includes
# proposed test includes a
# test includes a task
# includes a task that
# a task that involves
# task that involves the
# that involves the automated
# involves the automated interpretation
# the automated interpretation and
# automated interpretation and generation
# interpretation and generation of
# and generation of natural
# generation of natural language
# of natural language .
# natural language . The
# language . The premise
# . The premise of
# The premise of symbolic
# premise of symbolic NLP
# of symbolic NLP is
# symbolic NLP is well-summarized
# NLP is well-summarized by
# is well-summarized by John
# well-summarized by John Searle
# by John Searle 's
# John Searle 's Chinese
# Searle 's Chinese room
# 's Chinese room experiment
# Chinese room experiment :
# room experiment : Given
# experiment : Given a
# : Given a collection
# Given a collection of
# a collection of rules
# collection of rules (
# of rules ( e.g.
# rules ( e.g. ,
# ( e.g. , a
# e.g. , a Chinese
# , a Chinese phrasebook
# a Chinese phrasebook ,
# Chinese phrasebook , with
# phrasebook , with questions
# , with questions and
# with questions and matching
# questions and matching answers
# and matching answers )
# matching answers ) ,
# answers ) , the
# ) , the computer
# , the computer emulates
# the computer emulates natural
# computer emulates natural language
# emulates natural language understanding
# natural language understanding (
# language understanding ( or
# understanding ( or other
# ( or other NLP
# or other NLP tasks
# other NLP tasks )
# NLP tasks ) by
# tasks ) by applying
# ) by applying those
# by applying those rules
# applying those rules to
# those rules to the
# rules to the data
# to the data it
# the data it confronts
# data it confronts .
# it confronts . Up
# confronts . Up to
# . Up to the
# Up to the 1980s
# to the 1980s ,
# the 1980s , most
# 1980s , most natural
# , most natural language
# most natural language processing
# natural language processing systems
# language processing systems were
# processing systems were based
# systems were based on
# were based on complex
# based on complex sets
# on complex sets of
# complex sets of hand-written
# sets of hand-written rules
# of hand-written rules .
# hand-written rules . Starting
# rules . Starting in
# . Starting in the
# Starting in the late
# in the late 1980s
# the late 1980s ,
# late 1980s , however
# 1980s , however ,
# , however , there
# however , there was
# , there was a
# there was a revolution
# was a revolution in
# a revolution in natural
# revolution in natural language
# in natural language processing
# natural language processing with
# language processing with the
# processing with the introduction
# with the introduction of
# the introduction of machine
# introduction of machine learning
# of machine learning algorithms
# machine learning algorithms for
# learning algorithms for language
# algorithms for language processing
# for language processing .
# language processing . This
# processing . This was
# . This was due
# This was due to
# was due to both
# due to both the
# to both the steady
# both the steady increase
# the steady increase in
# steady increase in computational
# increase in computational power
# in computational power (
# computational power ( see
# power ( see Moore
# ( see Moore 's
# see Moore 's law
# Moore 's law )
# 's law ) and
# law ) and the
# ) and the gradual
# and the gradual lessening
# the gradual lessening of
# gradual lessening of the
# lessening of the dominance
# of the dominance of
# the dominance of Chomskyan
# dominance of Chomskyan theories
# of Chomskyan theories of
# Chomskyan theories of linguistics
# theories of linguistics (
# of linguistics ( e.g
# linguistics ( e.g .
# ( e.g . transformational
# e.g . transformational grammar
# . transformational grammar )
# transformational grammar ) ,
# grammar ) , whose
# ) , whose theoretical
# , whose theoretical underpinnings
# whose theoretical underpinnings discouraged
# theoretical underpinnings discouraged the
# underpinnings discouraged the sort
# discouraged the sort of
# the sort of corpus
# sort of corpus linguistics
# of corpus linguistics that
# corpus linguistics that underlies
# linguistics that underlies the
# that underlies the machine-learning
# underlies the machine-learning approach
# the machine-learning approach to
# machine-learning approach to language
# approach to language processing
# to language processing .
# language processing . [
# processing . [ 6
# . [ 6 ]
# [ 6 ] In
# 6 ] In the
# ] In the 2010s
# In the 2010s ,
# the 2010s , representation
# 2010s , representation learning
# , representation learning and
# representation learning and deep
# learning and deep neural
# and deep neural network-style
# deep neural network-style machine
# neural network-style machine learning
# network-style machine learning methods
# machine learning methods became
# learning methods became widespread
# methods became widespread in
# became widespread in natural
# widespread in natural language
# in natural language processing
# natural language processing .
# language processing . That
# processing . That popularity
# . That popularity was
# That popularity was due
# popularity was due partly
# was due partly to
# due partly to a
# partly to a flurry
# to a flurry of
# a flurry of results
# flurry of results showing
# of results showing that
# results showing that such
# showing that such techniques
# that such techniques [
# such techniques [ 7
# techniques [ 7 ]
# [ 7 ] [
# 7 ] [ 8
# ] [ 8 ]
# [ 8 ] can
# 8 ] can achieve
# ] can achieve state-of-the-art
# can achieve state-of-the-art results
# achieve state-of-the-art results in
# state-of-the-art results in many
# results in many natural
# in many natural language
# many natural language tasks
# natural language tasks ,
# language tasks , e.g.
# tasks , e.g. ,
# , e.g. , in
# e.g. , in language
# , in language modeling
# in language modeling [
# language modeling [ 9
# modeling [ 9 ]
# [ 9 ] and
# 9 ] and parsing
# ] and parsing .
# and parsing . [
# parsing . [ 10
# . [ 10 ]
# [ 10 ] [
# 10 ] [ 11
# ] [ 11 ]
# [ 11 ] This
# 11 ] This is
# ] This is increasingly
# This is increasingly important
# is increasingly important in
# increasingly important in medicine
# important in medicine and
# in medicine and healthcare
# medicine and healthcare ,
# and healthcare , where
# healthcare , where NLP
# , where NLP helps
# where NLP helps analyze
# NLP helps analyze notes
# helps analyze notes and
# analyze notes and text
# notes and text in
# and text in electronic
# text in electronic health
# in electronic health records
# electronic health records that
# health records that would
# records that would otherwise
# that would otherwise be
# would otherwise be inaccessible
# otherwise be inaccessible for
# be inaccessible for study
# inaccessible for study when
# for study when seeking
# study when seeking to
# when seeking to improve
# seeking to improve care
# to improve care .
# improve care . [
# care . [ 12
# . [ 12 ]
# [ 12 ] In
# 12 ] In the
# ] In the early
# In the early days
# the early days ,
# early days , many
# days , many language-processing
# , many language-processing systems
# many language-processing systems were
# language-processing systems were designed
# systems were designed by
# were designed by symbolic
# designed by symbolic methods
# by symbolic methods ,
# symbolic methods , i.e.
# methods , i.e. ,
# , i.e. , the
# i.e. , the hand-coding
# , the hand-coding of
# the hand-coding of a
# hand-coding of a set
# of a set of
# a set of rules
# set of rules ,
# of rules , coupled
# rules , coupled with
# , coupled with a
# coupled with a dictionary
# with a dictionary lookup
# a dictionary lookup :
# dictionary lookup : [
# lookup : [ 13
# : [ 13 ]
# [ 13 ] [
# 13 ] [ 14
# ] [ 14 ]
# [ 14 ] such
# 14 ] such as
# ] such as by
# such as by writing
# as by writing grammars
# by writing grammars or
# writing grammars or devising
# grammars or devising heuristic
# or devising heuristic rules
# devising heuristic rules for
# heuristic rules for stemming
# rules for stemming .
# for stemming . More
# stemming . More recent
# . More recent systems
# More recent systems based
# recent systems based on
# systems based on machine-learning
# based on machine-learning algorithms
# on machine-learning algorithms have
# machine-learning algorithms have many
# algorithms have many advantages
# have many advantages over
# many advantages over hand-produced
# advantages over hand-produced rules
# over hand-produced rules :
# hand-produced rules : Despite
# rules : Despite the
# : Despite the popularity
# Despite the popularity of
# the popularity of machine
# popularity of machine learning
# of machine learning in
# machine learning in NLP
# learning in NLP research
# in NLP research ,
# NLP research , symbolic
# research , symbolic methods
# , symbolic methods are
# symbolic methods are still
# methods are still (
# are still ( 2020
# still ( 2020 )
# ( 2020 ) commonly
# 2020 ) commonly used
# ) commonly used :
# commonly used : Since
# used : Since the
# : Since the so-called
# Since the so-called ``
# the so-called `` statistical
# so-called `` statistical revolution
# `` statistical revolution ''
# statistical revolution '' [
# revolution '' [ 15
# '' [ 15 ]
# [ 15 ] [
# 15 ] [ 16
# ] [ 16 ]
# [ 16 ] in
# 16 ] in the
# ] in the late
# in the late 1980s
# the late 1980s and
# late 1980s and mid-1990s
# 1980s and mid-1990s ,
# and mid-1990s , much
# mid-1990s , much natural
# , much natural language
# much natural language processing
# natural language processing research
# language processing research has
# processing research has relied
# research has relied heavily
# has relied heavily on
# relied heavily on machine
# heavily on machine learning
# on machine learning .
# machine learning . The
# learning . The machine-learning
# . The machine-learning paradigm
# The machine-learning paradigm calls
# machine-learning paradigm calls instead
# paradigm calls instead for
# calls instead for using
# instead for using statistical
# for using statistical inference
# using statistical inference to
# statistical inference to automatically
# inference to automatically learn
# to automatically learn such
# automatically learn such rules
# learn such rules through
# such rules through the
# rules through the analysis
# through the analysis of
# the analysis of large
# analysis of large corpora
# of large corpora (
# large corpora ( the
# corpora ( the plural
# ( the plural form
# the plural form of
# plural form of corpus
# form of corpus ,
# of corpus , is
# corpus , is a
# , is a set
# is a set of
# a set of documents
# set of documents ,
# of documents , possibly
# documents , possibly with
# , possibly with human
# possibly with human or
# with human or computer
# human or computer annotations
# or computer annotations )
# computer annotations ) of
# annotations ) of typical
# ) of typical real-world
# of typical real-world examples
# typical real-world examples .
# real-world examples . Many
# examples . Many different
# . Many different classes
# Many different classes of
# different classes of machine-learning
# classes of machine-learning algorithms
# of machine-learning algorithms have
# machine-learning algorithms have been
# algorithms have been applied
# have been applied to
# been applied to natural-language-processing
# applied to natural-language-processing tasks
# to natural-language-processing tasks .
# natural-language-processing tasks . These
# tasks . These algorithms
# . These algorithms take
# These algorithms take as
# algorithms take as input
# take as input a
# as input a large
# input a large set
# a large set of
# large set of ``
# set of `` features
# of `` features ''
# `` features '' that
# features '' that are
# '' that are generated
# that are generated from
# are generated from the
# generated from the input
# from the input data
# the input data .
# input data . Increasingly
# data . Increasingly ,
# . Increasingly , however
# Increasingly , however ,
# , however , research
# however , research has
# , research has focused
# research has focused on
# has focused on statistical
# focused on statistical models
# on statistical models ,
# statistical models , which
# models , which make
# , which make soft
# which make soft ,
# make soft , probabilistic
# soft , probabilistic decisions
# , probabilistic decisions based
# probabilistic decisions based on
# decisions based on attaching
# based on attaching real-valued
# on attaching real-valued weights
# attaching real-valued weights to
# real-valued weights to each
# weights to each input
# to each input feature
# each input feature (
# input feature ( complex-valued
# feature ( complex-valued embeddings
# ( complex-valued embeddings ,
# complex-valued embeddings , [
# embeddings , [ 17
# , [ 17 ]
# [ 17 ] and
# 17 ] and neural
# ] and neural networks
# and neural networks in
# neural networks in general
# networks in general have
# in general have also
# general have also been
# have also been proposed
# also been proposed ,
# been proposed , for
# proposed , for e.g
# , for e.g .
# for e.g . speech
# e.g . speech [
# . speech [ 18
# speech [ 18 ]
# [ 18 ] )
# 18 ] ) .
# ] ) . Such
# ) . Such models
# . Such models have
# Such models have the
# models have the advantage
# have the advantage that
# the advantage that they
# advantage that they can
# that they can express
# they can express the
# can express the relative
# express the relative certainty
# the relative certainty of
# relative certainty of many
# certainty of many different
# of many different possible
# many different possible answers
# different possible answers rather
# possible answers rather than
# answers rather than only
# rather than only one
# than only one ,
# only one , producing
# one , producing more
# , producing more reliable
# producing more reliable results
# more reliable results when
# reliable results when such
# results when such a
# when such a model
# such a model is
# a model is included
# model is included as
# is included as a
# included as a component
# as a component of
# a component of a
# component of a larger
# of a larger system
# a larger system .
# larger system . Some
# system . Some of
# . Some of the
# Some of the earliest-used
# of the earliest-used machine
# the earliest-used machine learning
# earliest-used machine learning algorithms
# machine learning algorithms ,
# learning algorithms , such
# algorithms , such as
# , such as decision
# such as decision trees
# as decision trees ,
# decision trees , produced
# trees , produced systems
# , produced systems of
# produced systems of hard
# systems of hard if-then
# of hard if-then rules
# hard if-then rules similar
# if-then rules similar to
# rules similar to existing
# similar to existing hand-written
# to existing hand-written rules
# existing hand-written rules .
# hand-written rules . However
# rules . However ,
# . However , part-of-speech
# However , part-of-speech tagging
# , part-of-speech tagging introduced
# part-of-speech tagging introduced the
# tagging introduced the use
# introduced the use of
# the use of hidden
# use of hidden Markov
# of hidden Markov models
# hidden Markov models to
# Markov models to natural
# models to natural language
# to natural language processing
# natural language processing ,
# language processing , and
# processing , and increasingly
# , and increasingly ,
# and increasingly , research
# increasingly , research has
# , research has focused
# research has focused on
# has focused on statistical
# focused on statistical models
# on statistical models ,
# statistical models , which
# models , which make
# , which make soft
# which make soft ,
# make soft , probabilistic
# soft , probabilistic decisions
# , probabilistic decisions based
# probabilistic decisions based on
# decisions based on attaching
# based on attaching real-valued
# on attaching real-valued weights
# attaching real-valued weights to
# real-valued weights to the
# weights to the features
# to the features making
# the features making up
# features making up the
# making up the input
# up the input data
# the input data .
# input data . The
# data . The cache
# . The cache language
# The cache language models
# cache language models upon
# language models upon which
# models upon which many
# upon which many speech
# which many speech recognition
# many speech recognition systems
# speech recognition systems now
# recognition systems now rely
# systems now rely are
# now rely are examples
# rely are examples of
# are examples of such
# examples of such statistical
# of such statistical models
# such statistical models .
# statistical models . Such
# models . Such models
# . Such models are
# Such models are generally
# models are generally more
# are generally more robust
# generally more robust when
# more robust when given
# robust when given unfamiliar
# when given unfamiliar input
# given unfamiliar input ,
# unfamiliar input , especially
# input , especially input
# , especially input that
# especially input that contains
# input that contains errors
# that contains errors (
# contains errors ( as
# errors ( as is
# ( as is very
# as is very common
# is very common for
# very common for real-world
# common for real-world data
# for real-world data )
# real-world data ) ,
# data ) , and
# ) , and produce
# , and produce more
# and produce more reliable
# produce more reliable results
# more reliable results when
# reliable results when integrated
# results when integrated into
# when integrated into a
# integrated into a larger
# into a larger system
# a larger system comprising
# larger system comprising multiple
# system comprising multiple subtasks
# comprising multiple subtasks .
# multiple subtasks . Since
# subtasks . Since the
# . Since the neural
# Since the neural turn
# the neural turn ,
# neural turn , statistical
# turn , statistical methods
# , statistical methods in
# statistical methods in NLP
# methods in NLP research
# in NLP research have
# NLP research have been
# research have been largely
# have been largely replaced
# been largely replaced by
# largely replaced by neural
# replaced by neural networks
# by neural networks .
# neural networks . However
# networks . However ,
# . However , they
# However , they continue
# , they continue to
# they continue to be
# continue to be relevant
# to be relevant for
# be relevant for contexts
# relevant for contexts in
# for contexts in which
# contexts in which statistical
# in which statistical interpretability
# which statistical interpretability and
# statistical interpretability and transparency
# interpretability and transparency is
# and transparency is required
# transparency is required .
# is required . A
# required . A major
# . A major drawback
# A major drawback of
# major drawback of statistical
# drawback of statistical methods
# of statistical methods is
# statistical methods is that
# methods is that they
# is that they require
# that they require elaborate
# they require elaborate feature
# require elaborate feature engineering
# elaborate feature engineering .
# feature engineering . Since
# engineering . Since 2015
# . Since 2015 ,
# Since 2015 , [
# 2015 , [ 19
# , [ 19 ]
# [ 19 ] the
# 19 ] the field
# ] the field has
# the field has thus
# field has thus largely
# has thus largely abandoned
# thus largely abandoned statistical
# largely abandoned statistical methods
# abandoned statistical methods and
# statistical methods and shifted
# methods and shifted to
# and shifted to neural
# shifted to neural networks
# to neural networks for
# neural networks for machine
# networks for machine learning
# for machine learning .
# machine learning . Popular
# learning . Popular techniques
# . Popular techniques include
# Popular techniques include the
# techniques include the use
# include the use of
# the use of word
# use of word embeddings
# of word embeddings to
# word embeddings to capture
# embeddings to capture semantic
# to capture semantic properties
# capture semantic properties of
# semantic properties of words
# properties of words ,
# of words , and
# words , and an
# , and an increase
# and an increase in
# an increase in end-to-end
# increase in end-to-end learning
# in end-to-end learning of
# end-to-end learning of a
# learning of a higher-level
# of a higher-level task
# a higher-level task (
# higher-level task ( e.g.
# task ( e.g. ,
# ( e.g. , question
# e.g. , question answering
# , question answering )
# question answering ) instead
# answering ) instead of
# ) instead of relying
# instead of relying on
# of relying on a
# relying on a pipeline
# on a pipeline of
# a pipeline of separate
# pipeline of separate intermediate
# of separate intermediate tasks
# separate intermediate tasks (
# intermediate tasks ( e.g.
# tasks ( e.g. ,
# ( e.g. , part-of-speech
# e.g. , part-of-speech tagging
# , part-of-speech tagging and
# part-of-speech tagging and dependency
# tagging and dependency parsing
# and dependency parsing )
# dependency parsing ) .
# parsing ) . In
# ) . In some
# . In some areas
# In some areas ,
# some areas , this
# areas , this shift
# , this shift has
# this shift has entailed
# shift has entailed substantial
# has entailed substantial changes
# entailed substantial changes in
# substantial changes in how
# changes in how NLP
# in how NLP systems
# how NLP systems are
# NLP systems are designed
# systems are designed ,
# are designed , such
# designed , such that
# , such that deep
# such that deep neural
# that deep neural network-based
# deep neural network-based approaches
# neural network-based approaches may
# network-based approaches may be
# approaches may be viewed
# may be viewed as
# be viewed as a
# viewed as a new
# as a new paradigm
# a new paradigm distinct
# new paradigm distinct from
# paradigm distinct from statistical
# distinct from statistical natural
# from statistical natural language
# statistical natural language processing
# natural language processing .
# language processing . For
# processing . For instance
# . For instance ,
# For instance , the
# instance , the term
# , the term neural
# the term neural machine
# term neural machine translation
# neural machine translation (
# machine translation ( NMT
# translation ( NMT )
# ( NMT ) emphasizes
# NMT ) emphasizes the
# ) emphasizes the fact
# emphasizes the fact that
# the fact that deep
# fact that deep learning-based
# that deep learning-based approaches
# deep learning-based approaches to
# learning-based approaches to machine
# approaches to machine translation
# to machine translation directly
# machine translation directly learn
# translation directly learn sequence-to-sequence
# directly learn sequence-to-sequence transformations
# learn sequence-to-sequence transformations ,
# sequence-to-sequence transformations , obviating
# transformations , obviating the
# , obviating the need
# obviating the need for
# the need for intermediate
# need for intermediate steps
# for intermediate steps such
# intermediate steps such as
# steps such as word
# such as word alignment
# as word alignment and
# word alignment and language
# alignment and language modeling
# and language modeling that
# language modeling that was
# modeling that was used
# that was used in
# was used in statistical
# used in statistical machine
# in statistical machine translation
# statistical machine translation (
# machine translation ( SMT
# translation ( SMT )
# ( SMT ) .
# SMT ) . Latest
# ) . Latest works
# . Latest works tend
# Latest works tend to
# works tend to use
# tend to use non-technical
# to use non-technical structure
# use non-technical structure of
# non-technical structure of a
# structure of a given
# of a given task
# a given task to
# given task to build
# task to build proper
# to build proper neural
# build proper neural network
# proper neural network .
# neural network . [
# network . [ 20
# . [ 20 ]
# [ 20 ] The
# 20 ] The following
# ] The following is
# The following is a
# following is a list
# is a list of
# a list of some
# list of some of
# of some of the
# some of the most
# of the most commonly
# the most commonly researched
# most commonly researched tasks
# commonly researched tasks in
# researched tasks in natural
# tasks in natural language
# in natural language processing
# natural language processing .
# language processing . Some
# processing . Some of
# . Some of these
# Some of these tasks
# of these tasks have
# these tasks have direct
# tasks have direct real-world
# have direct real-world applications
# direct real-world applications ,
# real-world applications , while
# applications , while others
# , while others more
# while others more commonly
# others more commonly serve
# more commonly serve as
# commonly serve as subtasks
# serve as subtasks that
# as subtasks that are
# subtasks that are used
# that are used to
# are used to aid
# used to aid in
# to aid in solving
# aid in solving larger
# in solving larger tasks
# solving larger tasks .
# larger tasks . Though
# tasks . Though natural
# . Though natural language
# Though natural language processing
# natural language processing tasks
# language processing tasks are
# processing tasks are closely
# tasks are closely intertwined
# are closely intertwined ,
# closely intertwined , they
# intertwined , they can
# , they can be
# they can be subdivided
# can be subdivided into
# be subdivided into categories
# subdivided into categories for
# into categories for convenience
# categories for convenience .
# for convenience . A
# convenience . A coarse
# . A coarse division
# A coarse division is
# coarse division is given
# division is given below
# is given below .
# given below . Based
# below . Based on
# . Based on long-standing
# Based on long-standing trends
# on long-standing trends in
# long-standing trends in the
# trends in the field
# in the field ,
# the field , it
# field , it is
# , it is possible
# it is possible to
# is possible to extrapolate
# possible to extrapolate future
# to extrapolate future directions
# extrapolate future directions of
# future directions of NLP
# directions of NLP .
# of NLP . As
# NLP . As of
# . As of 2020
# As of 2020 ,
# of 2020 , three
# 2020 , three trends
# , three trends among
# three trends among the
# trends among the topics
# among the topics of
# the topics of the
# topics of the long-standing
# of the long-standing series
# the long-standing series of
# long-standing series of CoNLL
# series of CoNLL Shared
# of CoNLL Shared Tasks
# CoNLL Shared Tasks can
# Shared Tasks can be
# Tasks can be observed
# can be observed :
# be observed : [
# observed : [ 36
# : [ 36 ]
# [ 36 ] Most
# 36 ] Most higher-level
# ] Most higher-level NLP
# Most higher-level NLP applications
# higher-level NLP applications involve
# NLP applications involve aspects
# applications involve aspects that
# involve aspects that emulate
# aspects that emulate intelligent
# that emulate intelligent behaviour
# emulate intelligent behaviour and
# intelligent behaviour and apparent
# behaviour and apparent comprehension
# and apparent comprehension of
# apparent comprehension of natural
# comprehension of natural language
# of natural language .
# natural language . More
# language . More broadly
# . More broadly speaking
# More broadly speaking ,
# broadly speaking , the
# speaking , the technical
# , the technical operationalization
# the technical operationalization of
# technical operationalization of increasingly
# operationalization of increasingly advanced
# of increasingly advanced aspects
# increasingly advanced aspects of
# advanced aspects of cognitive
# aspects of cognitive behaviour
# of cognitive behaviour represents
# cognitive behaviour represents one
# behaviour represents one of
# represents one of the
# one of the developmental
# of the developmental trajectories
# the developmental trajectories of
# developmental trajectories of NLP
# trajectories of NLP (
# of NLP ( see
# NLP ( see trends
# ( see trends among
# see trends among CoNLL
# trends among CoNLL shared
# among CoNLL shared tasks
# CoNLL shared tasks above
# shared tasks above )
# tasks above ) .
# above ) . Cognition
# ) . Cognition refers
# . Cognition refers to
# Cognition refers to ``
# refers to `` the
# to `` the mental
# `` the mental action
# the mental action or
# mental action or process
# action or process of
# or process of acquiring
# process of acquiring knowledge
# of acquiring knowledge and
# acquiring knowledge and understanding
# knowledge and understanding through
# and understanding through thought
# understanding through thought ,
# through thought , experience
# thought , experience ,
# , experience , and
# experience , and the
# , and the senses
# and the senses .
# the senses . ``
# senses . `` [
# . `` [ 37
# `` [ 37 ]
# [ 37 ] Cognitive
# 37 ] Cognitive science
# ] Cognitive science is
# Cognitive science is the
# science is the interdisciplinary
# is the interdisciplinary ,
# the interdisciplinary , scientific
# interdisciplinary , scientific study
# , scientific study of
# scientific study of the
# study of the mind
# of the mind and
# the mind and its
# mind and its processes
# and its processes .
# its processes . [
# processes . [ 38
# . [ 38 ]
# [ 38 ] Cognitive
# 38 ] Cognitive linguistics
# ] Cognitive linguistics is
# Cognitive linguistics is an
# linguistics is an interdisciplinary
# is an interdisciplinary branch
# an interdisciplinary branch of
# interdisciplinary branch of linguistics
# branch of linguistics ,
# of linguistics , combining
# linguistics , combining knowledge
# , combining knowledge and
# combining knowledge and research
# knowledge and research from
# and research from both
# research from both psychology
# from both psychology and
# both psychology and linguistics
# psychology and linguistics .
# and linguistics . [
# linguistics . [ 39
# . [ 39 ]
# [ 39 ] Especially
# 39 ] Especially during
# ] Especially during the
# Especially during the age
# during the age of
# the age of symbolic
# age of symbolic NLP
# of symbolic NLP ,
# symbolic NLP , the
# NLP , the area
# , the area of
# the area of computational
# area of computational linguistics
# of computational linguistics maintained
# computational linguistics maintained strong
# linguistics maintained strong ties
# maintained strong ties with
# strong ties with cognitive
# ties with cognitive studies
# with cognitive studies .
# cognitive studies . As
# studies . As an
# . As an example
# As an example ,
# an example , George
# example , George Lakoff
# , George Lakoff offers
# George Lakoff offers a
# Lakoff offers a methodology
# offers a methodology to
# a methodology to build
# methodology to build natural
# to build natural language
# build natural language processing
# natural language processing (
# language processing ( NLP
# processing ( NLP )
# ( NLP ) algorithms
# NLP ) algorithms through
# ) algorithms through the
# algorithms through the perspective
# through the perspective of
# the perspective of cognitive
# perspective of cognitive science
# of cognitive science ,
# cognitive science , along
# science , along with
# , along with the
# along with the findings
# with the findings of
# the findings of cognitive
# findings of cognitive linguistics
# of cognitive linguistics ,
# cognitive linguistics , [
# linguistics , [ 40
# , [ 40 ]
# [ 40 ] with
# 40 ] with two
# ] with two defining
# with two defining aspects
# two defining aspects :
# defining aspects : Ties
# aspects : Ties with
# : Ties with cognitive
# Ties with cognitive linguistics
# with cognitive linguistics are
# cognitive linguistics are part
# linguistics are part of
# are part of the
# part of the historical
# of the historical heritage
# the historical heritage of
# historical heritage of NLP
# heritage of NLP ,
# of NLP , but
# NLP , but they
# , but they have
# but they have been
# they have been less
# have been less frequently
# been less frequently addressed
# less frequently addressed since
# frequently addressed since the
# addressed since the statistical
# since the statistical turn
# the statistical turn during
# statistical turn during the
# turn during the 1990s
# during the 1990s .
# the 1990s . Nevertheless
# 1990s . Nevertheless ,
# . Nevertheless , approaches
# Nevertheless , approaches to
# , approaches to develop
# approaches to develop cognitive
# to develop cognitive models
# develop cognitive models towards
# cognitive models towards technically
# models towards technically operationalizable
# towards technically operationalizable frameworks
# technically operationalizable frameworks have
# operationalizable frameworks have been
# frameworks have been pursued
# have been pursued in
# been pursued in the
# pursued in the context
# in the context of
# the context of various
# context of various frameworks
# of various frameworks ,
# various frameworks , e.g.
# frameworks , e.g. ,
# , e.g. , of
# e.g. , of cognitive
# , of cognitive grammar
# of cognitive grammar ,
# cognitive grammar , [
# grammar , [ 42
# , [ 42 ]
# [ 42 ] functional
# 42 ] functional grammar
# ] functional grammar ,
# functional grammar , [
# grammar , [ 43
# , [ 43 ]
# [ 43 ] construction
# 43 ] construction grammar
# ] construction grammar ,
# construction grammar , [
# grammar , [ 44
# , [ 44 ]
# [ 44 ] computational
# 44 ] computational psycholinguistics
# ] computational psycholinguistics and
# computational psycholinguistics and cognitive
# psycholinguistics and cognitive neuroscience
# and cognitive neuroscience (
# cognitive neuroscience ( e.g.
# neuroscience ( e.g. ,
# ( e.g. , ACT-R
# e.g. , ACT-R )
# , ACT-R ) ,
# ACT-R ) , however
# ) , however ,
# , however , with
# however , with limited
# , with limited uptake
# with limited uptake in
# limited uptake in mainstream
# uptake in mainstream NLP
# in mainstream NLP (
# mainstream NLP ( as
# NLP ( as measured
# ( as measured by
# as measured by presence
# measured by presence on
# by presence on major
# presence on major conferences
# on major conferences [
# major conferences [ 45
# conferences [ 45 ]
# [ 45 ] of
# 45 ] of the
# ] of the ACL
# of the ACL )
# the ACL ) .
# ACL ) . More
# ) . More recently
# . More recently ,
# More recently , ideas
# recently , ideas of
# , ideas of cognitive
# ideas of cognitive NLP
# of cognitive NLP have
# cognitive NLP have been
# NLP have been revived
# have been revived as
# been revived as an
# revived as an approach
# as an approach to
# an approach to achieve
# approach to achieve explainability
# to achieve explainability ,
# achieve explainability , e.g.
# explainability , e.g. ,
# , e.g. , under
# e.g. , under the
# , under the notion
# under the notion of
# the notion of ``
# notion of `` cognitive
# of `` cognitive AI
# `` cognitive AI ''
# cognitive AI '' .
# AI '' . [
# '' . [ 46
# . [ 46 ]
# [ 46 ] Likewise
# 46 ] Likewise ,
# ] Likewise , ideas
# Likewise , ideas of
# , ideas of cognitive
# ideas of cognitive NLP
# of cognitive NLP are
# cognitive NLP are inherent
# NLP are inherent to
# are inherent to neural
# inherent to neural models
# to neural models multimodal
# neural models multimodal NLP
# models multimodal NLP (
# multimodal NLP ( although
# NLP ( although rarely
# ( although rarely made
# although rarely made explicit
# rarely made explicit )
# made explicit ) .
# explicit ) . [
# ) . [ 47
# {'Natural language processing (': ['NLP'],
#  'language processing ( NLP': [')', ')'],
#  'processing ( NLP )': ['is', 'algorithms'],
#  '( NLP ) is': ['a'],
#  'NLP ) is a': ['subfield'],
#  ') is a subfield': ['of'],
#  'is a subfield of': ['linguistics'],
#  'a subfield of linguistics': [','],
#  'subfield of linguistics ,': ['computer'],
#  'of linguistics , computer': ['science'],
#  'linguistics , computer science': [','],
#  ', computer science ,': ['and'],
#  'computer science , and': ['artificial'],
#  'science , and artificial': ['intelligence'],
#  ', and artificial intelligence': ['concerned'],
#  'and artificial intelligence concerned': ['with'],
#  'artificial intelligence concerned with': ['the'],
#  'intelligence concerned with the': ['interactions'],
#  'concerned with the interactions': ['between'],
#  'with the interactions between': ['computers'],
#  'the interactions between computers': ['and'],
#  'interactions between computers and': ['human'],
#  'between computers and human': ['language'],
#  'computers and human language': [','],
#  'and human language ,': ['in'],
#  'human language , in': ['particular'],
#  'language , in particular': ['how'],
#  ', in particular how': ['to'],
#  'in particular how to': ['program'],
#  'particular how to program': ['computers'],
#  'how to program computers': ['to'],
#  'to program computers to': ['process'],
#  'program computers to process': ['and'],
#  'computers to process and': ['analyze'],
#  'to process and analyze': ['large'],
#  'process and analyze large': ['amounts'],
#  'and analyze large amounts': ['of'],
#  'analyze large amounts of': ['natural'],
#  'large amounts of natural': ['language'],
#  'amounts of natural language': ['data'],
#  'of natural language data': ['.'],
#  'natural language data .': ['The'],
#  'language data . The': ['goal'],
#  'data . The goal': ['is'],
#  '. The goal is': ['a'],
#  'The goal is a': ['computer'],
#  'goal is a computer': ['capable'],
#  'is a computer capable': ['of'],
#  'a computer capable of': ['``'],
#  'computer capable of ``': ['understanding'],
#  'capable of `` understanding': ["''"],
#  "of `` understanding ''": ['the'],
#  "`` understanding '' the": ['contents'],
#  "understanding '' the contents": ['of'],
#  "'' the contents of": ['documents'],
#  'the contents of documents': [','],
#  'contents of documents ,': ['including'],
#  'of documents , including': ['the'],
#  'documents , including the': ['contextual'],
#  ', including the contextual': ['nuances'],
#  'including the contextual nuances': ['of'],
#  'the contextual nuances of': ['the'],
#  'contextual nuances of the': ['language'],
#  'nuances of the language': ['within'],
#  'of the language within': ['them'],
#  'the language within them': ['.'],
#  'language within them .': ['The'],
#  'within them . The': ['technology'],
#  'them . The technology': ['can'],
#  '. The technology can': ['then'],
#  'The technology can then': ['accurately'],
#  'technology can then accurately': ['extract'],
#  'can then accurately extract': ['information'],
#  'then accurately extract information': ['and'],
#  'accurately extract information and': ['insights'],
#  'extract information and insights': ['contained'],
#  'information and insights contained': ['in'],
#  'and insights contained in': ['the'],
#  'insights contained in the': ['documents'],
#  'contained in the documents': ['as'],
#  'in the documents as': ['well'],
#  'the documents as well': ['as'],
#  'documents as well as': ['categorize'],
#  'as well as categorize': ['and'],
#  'well as categorize and': ['organize'],
#  'as categorize and organize': ['the'],
#  'categorize and organize the': ['documents'],
#  'and organize the documents': ['themselves'],
#  'organize the documents themselves': ['.'],
#  'the documents themselves .': ['Challenges'],
#  'documents themselves . Challenges': ['in'],
#  'themselves . Challenges in': ['natural'],
#  '. Challenges in natural': ['language'],
#  'Challenges in natural language': ['processing'],
#  'in natural language processing': ['frequently', 'with', '.', '.'],
#  'natural language processing frequently': ['involve'],
#  'language processing frequently involve': ['speech'],
#  'processing frequently involve speech': ['recognition'],
#  'frequently involve speech recognition': [','],
#  'involve speech recognition ,': ['natural'],
#  'speech recognition , natural': ['language'],
#  'recognition , natural language': ['understanding'],
#  ', natural language understanding': [','],
#  'natural language understanding ,': ['and'],
#  'language understanding , and': ['natural'],
#  'understanding , and natural': ['language'],
#  ', and natural language': ['generation'],
#  'and natural language generation': ['.'],
#  'natural language generation .': ['Natural'],
#  'language generation . Natural': ['language'],
#  'generation . Natural language': ['processing'],
#  '. Natural language processing': ['has'],
#  'Natural language processing has': ['its'],
#  'language processing has its': ['roots'],
#  'processing has its roots': ['in'],
#  'has its roots in': ['the'],
#  'its roots in the': ['1950s'],
#  'roots in the 1950s': ['.'],
#  'in the 1950s .': ['Already'],
#  'the 1950s . Already': ['in'],
#  '1950s . Already in': ['1950'],
#  '. Already in 1950': [','],
#  'Already in 1950 ,': ['Alan'],
#  'in 1950 , Alan': ['Turing'],
#  '1950 , Alan Turing': ['published'],
#  ', Alan Turing published': ['an'],
#  'Alan Turing published an': ['article'],
#  'Turing published an article': ['titled'],
#  'published an article titled': ['``'],
#  'an article titled ``': ['Computing'],
#  'article titled `` Computing': ['Machinery'],
#  'titled `` Computing Machinery': ['and'],
#  '`` Computing Machinery and': ['Intelligence'],
#  'Computing Machinery and Intelligence': ["''"],
#  "Machinery and Intelligence ''": ['which'],
#  "and Intelligence '' which": ['proposed'],
#  "Intelligence '' which proposed": ['what'],
#  "'' which proposed what": ['is'],
#  'which proposed what is': ['now'],
#  'proposed what is now': ['called'],
#  'what is now called': ['the'],
#  'is now called the': ['Turing'],
#  'now called the Turing': ['test'],
#  'called the Turing test': ['as'],
#  'the Turing test as': ['a'],
#  'Turing test as a': ['criterion'],
#  'test as a criterion': ['of'],
#  'as a criterion of': ['intelligence'],
#  'a criterion of intelligence': [','],
#  'criterion of intelligence ,': ['though'],
#  'of intelligence , though': ['at'],
#  'intelligence , though at': ['the'],
#  ', though at the': ['time'],
#  'though at the time': ['that'],
#  'at the time that': ['was'],
#  'the time that was': ['not'],
#  'time that was not': ['articulated'],
#  'that was not articulated': ['as'],
#  'was not articulated as': ['a'],
#  'not articulated as a': ['problem'],
#  'articulated as a problem': ['separate'],
#  'as a problem separate': ['from'],
#  'a problem separate from': ['artificial'],
#  'problem separate from artificial': ['intelligence'],
#  'separate from artificial intelligence': ['.'],
#  'from artificial intelligence .': ['The'],
#  'artificial intelligence . The': ['proposed'],
#  'intelligence . The proposed': ['test'],
#  '. The proposed test': ['includes'],
#  'The proposed test includes': ['a'],
#  'proposed test includes a': ['task'],
#  'test includes a task': ['that'],
#  'includes a task that': ['involves'],
#  'a task that involves': ['the'],
#  'task that involves the': ['automated'],
#  'that involves the automated': ['interpretation'],
#  'involves the automated interpretation': ['and'],
#  'the automated interpretation and': ['generation'],
#  'automated interpretation and generation': ['of'],
#  'interpretation and generation of': ['natural'],
#  'and generation of natural': ['language'],
#  'generation of natural language': ['.'],
#  'of natural language .': ['The', 'More'],
#  'natural language . The': ['premise'],
#  'language . The premise': ['of'],
#  '. The premise of': ['symbolic'],
#  'The premise of symbolic': ['NLP'],
#  'premise of symbolic NLP': ['is'],
#  'of symbolic NLP is': ['well-summarized'],
#  'symbolic NLP is well-summarized': ['by'],
#  'NLP is well-summarized by': ['John'],
#  'is well-summarized by John': ['Searle'],
#  'well-summarized by John Searle': ["'s"],
#  "by John Searle 's": ['Chinese'],
#  "John Searle 's Chinese": ['room'],
#  "Searle 's Chinese room": ['experiment'],
#  "'s Chinese room experiment": [':'],
#  'Chinese room experiment :': ['Given'],
#  'room experiment : Given': ['a'],
#  'experiment : Given a': ['collection'],
#  ': Given a collection': ['of'],
#  'Given a collection of': ['rules'],
#  'a collection of rules': ['('],
#  'collection of rules (': ['e.g.'],
#  'of rules ( e.g.': [','],
#  'rules ( e.g. ,': ['a'],
#  '( e.g. , a': ['Chinese'],
#  'e.g. , a Chinese': ['phrasebook'],
#  ', a Chinese phrasebook': [','],
#  'a Chinese phrasebook ,': ['with'],
#  'Chinese phrasebook , with': ['questions'],
#  'phrasebook , with questions': ['and'],
#  ', with questions and': ['matching'],
#  'with questions and matching': ['answers'],
#  'questions and matching answers': [')'],
#  'and matching answers )': [','],
#  'matching answers ) ,': ['the'],
#  'answers ) , the': ['computer'],
#  ') , the computer': ['emulates'],
#  ', the computer emulates': ['natural'],
#  'the computer emulates natural': ['language'],
#  'computer emulates natural language': ['understanding'],
#  'emulates natural language understanding': ['('],
#  'natural language understanding (': ['or'],
#  'language understanding ( or': ['other'],
#  'understanding ( or other': ['NLP'],
#  '( or other NLP': ['tasks'],
#  'or other NLP tasks': [')'],
#  'other NLP tasks )': ['by'],
#  'NLP tasks ) by': ['applying'],
#  'tasks ) by applying': ['those'],
#  ') by applying those': ['rules'],
#  'by applying those rules': ['to'],
#  'applying those rules to': ['the'],
#  'those rules to the': ['data'],
#  'rules to the data': ['it'],
#  'to the data it': ['confronts'],
#  'the data it confronts': ['.'],
#  'data it confronts .': ['Up'],
#  'it confronts . Up': ['to'],
#  'confronts . Up to': ['the'],
#  '. Up to the': ['1980s'],
#  'Up to the 1980s': [','],
#  'to the 1980s ,': ['most'],
#  'the 1980s , most': ['natural'],
#  '1980s , most natural': ['language'],
#  ', most natural language': ['processing'],
#  'most natural language processing': ['systems'],
#  'natural language processing systems': ['were'],
#  'language processing systems were': ['based'],
#  'processing systems were based': ['on'],
#  'systems were based on': ['complex'],
#  'were based on complex': ['sets'],
#  'based on complex sets': ['of'],
#  'on complex sets of': ['hand-written'],
#  'complex sets of hand-written': ['rules'],
#  'sets of hand-written rules': ['.'],
#  'of hand-written rules .': ['Starting'],
#  'hand-written rules . Starting': ['in'],
#  'rules . Starting in': ['the'],
#  '. Starting in the': ['late'],
#  'Starting in the late': ['1980s'],
#  'in the late 1980s': [',', 'and'],
#  'the late 1980s ,': ['however'],
#  'late 1980s , however': [','],
#  '1980s , however ,': ['there'],
#  ', however , there': ['was'],
#  'however , there was': ['a'],
#  ', there was a': ['revolution'],
#  'there was a revolution': ['in'],
#  'was a revolution in': ['natural'],
# ...
#  'real-world examples . Many': ['different'],
#  'examples . Many different': ['classes'],
#  '. Many different classes': ['of'],
#  'Many different classes of': ['machine-learning'],
#  'different classes of machine-learning': ['algorithms'],
#  'classes of machine-learning algorithms': ['have'],
#  'of machine-learning algorithms have': ['been'],
#  'machine-learning algorithms have been': ['applied'],
#  'algorithms have been applied': ['to'],
#  'have been applied to': ['natural-language-processing'],
#  'been applied to natural-language-processing': ['tasks'],
#  'applied to natural-language-processing tasks': ['.'],
#  'to natural-language-processing tasks .': ['These'],
#  'natural-language-processing tasks . These': ['algorithms'],
#  'tasks . These algorithms': ['take'],
#  '. These algorithms take': ['as'],
#  'These algorithms take as': ['input'],
#  'algorithms take as input': ['a'],
#  'take as input a': ['large'],
#  'as input a large': ['set'],
#  'input a large set': ['of'],
#  'a large set of': ['``'],
#  'large set of ``': ['features'],
#  'set of `` features': ["''"],
#  "of `` features ''": ['that'],
#  "`` features '' that": ['are'],
#  "features '' that are": ['generated'],
#  "'' that are generated": ['from'],
#  'that are generated from': ['the'],
#  'are generated from the': ['input'],
#  'generated from the input': ['data'],
#  'from the input data': ['.'],
#  'the input data .': ['Increasingly', 'The'],
#  'input data . Increasingly': [','],
#  'data . Increasingly ,': ['however'],
#  '. Increasingly , however': [','],
#  'Increasingly , however ,': ['research'],
#  ', however , research': ['has'],
#  'however , research has': ['focused'],
#  ', research has focused': ['on', 'on'],
#  'research has focused on': ['statistical', 'statistical'],
#  'has focused on statistical': ['models', 'models'],
#  'focused on statistical models': [',', ','],
#  'on statistical models ,': ['which', 'which'],
#  'statistical models , which': ['make', 'make'],
#  'models , which make': ['soft', 'soft'],
#  ', which make soft': [',', ','],
#  'which make soft ,': ['probabilistic', 'probabilistic'],
#  'make soft , probabilistic': ['decisions', 'decisions'],
#  'soft , probabilistic decisions': ['based', 'based'],
#  ', probabilistic decisions based': ['on', 'on'],
#  'probabilistic decisions based on': ['attaching', 'attaching'],
#  'decisions based on attaching': ['real-valued', 'real-valued'],
#  'based on attaching real-valued': ['weights', 'weights'],
#  'on attaching real-valued weights': ['to', 'to'],
#  'attaching real-valued weights to': ['each', 'the'],
#  'real-valued weights to each': ['input'],
#  'weights to each input': ['feature'],
#  'to each input feature': ['('],
#  'each input feature (': ['complex-valued'],
#  'input feature ( complex-valued': ['embeddings'],
#  'feature ( complex-valued embeddings': [','],
#  '( complex-valued embeddings ,': ['['],
#  'complex-valued embeddings , [': ['17'],
#  'embeddings , [ 17': [']'],
#  ', [ 17 ]': ['and'],
#  '[ 17 ] and': ['neural'],
#  '17 ] and neural': ['networks'],
#  '] and neural networks': ['in'],
#  'and neural networks in': ['general'],
#  'neural networks in general': ['have'],
#  'networks in general have': ['also'],
#  'in general have also': ['been'],
#  'general have also been': ['proposed'],
#  'have also been proposed': [','],
#  'also been proposed ,': ['for'],
#  'been proposed , for': ['e.g'],
#  'proposed , for e.g': ['.'],
#  ', for e.g .': ['speech'],
#  'for e.g . speech': ['['],
#  'e.g . speech [': ['18'],
#  '. speech [ 18': [']'],
#  'speech [ 18 ]': [')'],
#  '[ 18 ] )': ['.'],
#  '18 ] ) .': ['Such'],
#  '] ) . Such': ['models'],
#  ') . Such models': ['have'],
#  '. Such models have': ['the'],
#  'Such models have the': ['advantage'],
#  'models have the advantage': ['that'],
#  'have the advantage that': ['they'],
#  'the advantage that they': ['can'],
#  'advantage that they can': ['express'],
#  'that they can express': ['the'],
#  'they can express the': ['relative'],
#  'can express the relative': ['certainty'],
#  'express the relative certainty': ['of'],
#  'the relative certainty of': ['many'],
#  'relative certainty of many': ['different'],
#  'certainty of many different': ['possible'],
#  'of many different possible': ['answers'],
#  'many different possible answers': ['rather'],
#  'different possible answers rather': ['than'],
#  'possible answers rather than': ['only'],
#  'answers rather than only': ['one'],
#  'rather than only one': [','],
#  'than only one ,': ['producing'],
#  'only one , producing': ['more'],
#  'one , producing more': ['reliable'],
#  ', producing more reliable': ['results'],
#  'producing more reliable results': ['when'],
#  'more reliable results when': ['such', 'integrated'],
#  'reliable results when such': ['a'],
#  'results when such a': ['model'],
#  'when such a model': ['is'],
#  'such a model is': ['included'],
#  'a model is included': ['as'],
#  'model is included as': ['a'],
#  'is included as a': ['component'],
#  'included as a component': ['of'],
#  'as a component of': ['a'],
#  'a component of a': ['larger'],
#  'component of a larger': ['system'],
#  'of a larger system': ['.'],
#  'a larger system .': ['Some'],
#  'larger system . Some': ['of'],
#  'system . Some of': ['the'],
#  '. Some of the': ['earliest-used'],
#  'Some of the earliest-used': ['machine'],
#  'of the earliest-used machine': ['learning'],
#  'the earliest-used machine learning': ['algorithms'],
#  'earliest-used machine learning algorithms': [','],
#  'machine learning algorithms ,': ['such'],
#  'learning algorithms , such': ['as'],
#  'algorithms , such as': ['decision'],
#  ', such as decision': ['trees'],
#  'such as decision trees': [','],
#  'as decision trees ,': ['produced'],
#  'decision trees , produced': ['systems'],
#  'trees , produced systems': ['of'],
#  ', produced systems of': ['hard'],
#  'produced systems of hard': ['if-then'],
#  'systems of hard if-then': ['rules'],
#  'of hard if-then rules': ['similar'],
#  'hard if-then rules similar': ['to'],
#  'if-then rules similar to': ['existing'],
#  'rules similar to existing': ['hand-written'],
#  'similar to existing hand-written': ['rules'],
#  'to existing hand-written rules': ['.'],
#  'existing hand-written rules .': ['However'],
#  'hand-written rules . However': [','],
#  'rules . However ,': ['part-of-speech'],
#  '. However , part-of-speech': ['tagging'],
#  'However , part-of-speech tagging': ['introduced'],
#  ', part-of-speech tagging introduced': ['the'],
#  'part-of-speech tagging introduced the': ['use'],
#  'tagging introduced the use': ['of'],
#  'introduced the use of': ['hidden'],
#  'the use of hidden': ['Markov'],
#  'use of hidden Markov': ['models'],
#  'of hidden Markov models': ['to'],
#  'hidden Markov models to': ['natural'],
#  'Markov models to natural': ['language'],
#  'models to natural language': ['processing'],
#  'to natural language processing': [','],
#  'natural language processing ,': ['and'],
#  'language processing , and': ['increasingly'],
#  'processing , and increasingly': [','],
#  ', and increasingly ,': ['research'],
#  'and increasingly , research': ['has'],
#  'increasingly , research has': ['focused'],
#  'real-valued weights to the': ['features'],
#  'weights to the features': ['making'],
#  'to the features making': ['up'],
#  'the features making up': ['the'],
#  'features making up the': ['input'],
#  'making up the input': ['data'],
#  'up the input data': ['.'],
#  'input data . The': ['cache'],
#  'data . The cache': ['language'],
#  '. The cache language': ['models'],
#  'The cache language models': ['upon'],
#  'cache language models upon': ['which'],
#  'language models upon which': ['many'],
#  'models upon which many': ['speech'],
#  'upon which many speech': ['recognition'],
#  'which many speech recognition': ['systems'],
#  'many speech recognition systems': ['now'],
#  'speech recognition systems now': ['rely'],
#  'recognition systems now rely': ['are'],
#  'systems now rely are': ['examples'],
#  'now rely are examples': ['of'],
#  'rely are examples of': ['such'],
#  'are examples of such': ['statistical'],
#  'examples of such statistical': ['models'],
#  'of such statistical models': ['.'],
#  'such statistical models .': ['Such'],
#  'statistical models . Such': ['models'],
#  'models . Such models': ['are'],
#  '. Such models are': ['generally'],
#  'Such models are generally': ['more'],
#  'models are generally more': ['robust'],
#  'are generally more robust': ['when'],
#  'generally more robust when': ['given'],
#  'more robust when given': ['unfamiliar'],
#  'robust when given unfamiliar': ['input'],
#  'when given unfamiliar input': [','],
#  'given unfamiliar input ,': ['especially'],
#  'unfamiliar input , especially': ['input'],
#  'input , especially input': ['that'],
#  ', especially input that': ['contains'],
#  'especially input that contains': ['errors'],
#  'input that contains errors': ['('],
#  'that contains errors (': ['as'],
#  'contains errors ( as': ['is'],
#  'errors ( as is': ['very'],
#  '( as is very': ['common'],
#  'as is very common': ['for'],
#  'is very common for': ['real-world'],
#  'very common for real-world': ['data'],
#  'common for real-world data': [')'],
#  'for real-world data )': [','],
#  'real-world data ) ,': ['and'],
#  'data ) , and': ['produce'],
#  ') , and produce': ['more'],
#  ', and produce more': ['reliable'],
#  'and produce more reliable': ['results'],
#  'produce more reliable results': ['when'],
#  'reliable results when integrated': ['into'],
#  'results when integrated into': ['a'],
#  'when integrated into a': ['larger'],
#  'integrated into a larger': ['system'],
#  'into a larger system': ['comprising'],
#  'a larger system comprising': ['multiple'],
#  'larger system comprising multiple': ['subtasks'],
#  'system comprising multiple subtasks': ['.'],
#  'comprising multiple subtasks .': ['Since'],
#  'multiple subtasks . Since': ['the'],
#  'subtasks . Since the': ['neural'],
#  '. Since the neural': ['turn'],
#  'Since the neural turn': [','],
#  'the neural turn ,': ['statistical'],
#  'neural turn , statistical': ['methods'],
#  'turn , statistical methods': ['in'],
#  ', statistical methods in': ['NLP'],
#  'statistical methods in NLP': ['research'],
#  'methods in NLP research': ['have'],
#  'in NLP research have': ['been'],
#  'NLP research have been': ['largely'],
#  'research have been largely': ['replaced'],
#  'have been largely replaced': ['by'],
#  'been largely replaced by': ['neural'],
#  'largely replaced by neural': ['networks'],
#  'replaced by neural networks': ['.'],
#  'by neural networks .': ['However'],
#  'neural networks . However': [','],
#  'networks . However ,': ['they'],
#  '. However , they': ['continue'],
#  'However , they continue': ['to'],
#  ', they continue to': ['be'],
#  'they continue to be': ['relevant'],
#  'continue to be relevant': ['for'],
#  'to be relevant for': ['contexts'],
#  'be relevant for contexts': ['in'],
#  'relevant for contexts in': ['which'],
#  'for contexts in which': ['statistical'],
#  'contexts in which statistical': ['interpretability'],
#  'in which statistical interpretability': ['and'],
#  'which statistical interpretability and': ['transparency'],
#  'statistical interpretability and transparency': ['is'],
#  'interpretability and transparency is': ['required'],
#  'and transparency is required': ['.'],
#  'transparency is required .': ['A'],
#  'is required . A': ['major'],
#  'required . A major': ['drawback'],
#  '. A major drawback': ['of'],
#  'A major drawback of': ['statistical'],
#  'major drawback of statistical': ['methods'],
#  'drawback of statistical methods': ['is'],
#  'of statistical methods is': ['that'],
#  'statistical methods is that': ['they'],
#  'methods is that they': ['require'],
#  'is that they require': ['elaborate'],
#  'that they require elaborate': ['feature'],
#  'they require elaborate feature': ['engineering'],
#  'require elaborate feature engineering': ['.'],
#  'elaborate feature engineering .': ['Since'],
#  'feature engineering . Since': ['2015'],
#  'engineering . Since 2015': [','],
#  '. Since 2015 ,': ['['],
#  'Since 2015 , [': ['19'],
#  '2015 , [ 19': [']'],
#  ', [ 19 ]': ['the'],
#  '[ 19 ] the': ['field'],
#  '19 ] the field': ['has'],
#  '] the field has': ['thus'],
#  'the field has thus': ['largely'],
#  'field has thus largely': ['abandoned'],
#  'has thus largely abandoned': ['statistical'],
#  'thus largely abandoned statistical': ['methods'],
#  'largely abandoned statistical methods': ['and'],
#  'abandoned statistical methods and': ['shifted'],
#  'statistical methods and shifted': ['to'],
#  'methods and shifted to': ['neural'],
#  'and shifted to neural': ['networks'],
#  'shifted to neural networks': ['for'],
#  'to neural networks for': ['machine'],
#  'neural networks for machine': ['learning'],
#  'networks for machine learning': ['.'],
#  'for machine learning .': ['Popular'],
#  'machine learning . Popular': ['techniques'],
#  'learning . Popular techniques': ['include'],
#  '. Popular techniques include': ['the'],
#  'Popular techniques include the': ['use'],
#  'techniques include the use': ['of'],
#  'include the use of': ['word'],
#  'the use of word': ['embeddings'],
#  'use of word embeddings': ['to'],
#  'of word embeddings to': ['capture'],
#  'word embeddings to capture': ['semantic'],
#  'embeddings to capture semantic': ['properties'],
#  'to capture semantic properties': ['of'],
#  'capture semantic properties of': ['words'],
#  'semantic properties of words': [','],
#  'properties of words ,': ['and'],
#  'of words , and': ['an'],
#  'words , and an': ['increase'],
#  ', and an increase': ['in'],
#  'and an increase in': ['end-to-end'],
#  'an increase in end-to-end': ['learning'],
#  'increase in end-to-end learning': ['of'],
#  'in end-to-end learning of': ['a'],
#  'end-to-end learning of a': ['higher-level'],
#  'learning of a higher-level': ['task'],
#  'of a higher-level task': ['('],
#  'a higher-level task (': ['e.g.'],
#  'higher-level task ( e.g.': [','],
#  'task ( e.g. ,': ['question'],
#  '( e.g. , question': ['answering'],
#  'e.g. , question answering': [')'],
#  ', question answering )': ['instead'],
#  'question answering ) instead': ['of'],
#  'answering ) instead of': ['relying'],
#  ') instead of relying': ['on'],
#  'instead of relying on': ['a'],
#  'of relying on a': ['pipeline'],
#  'relying on a pipeline': ['of'],
#  'on a pipeline of': ['separate'],
#  'a pipeline of separate': ['intermediate'],
#  'pipeline of separate intermediate': ['tasks'],
#  'of separate intermediate tasks': ['('],
#  'separate intermediate tasks (': ['e.g.'],
#  'intermediate tasks ( e.g.': [','],
#  'tasks ( e.g. ,': ['part-of-speech'],
#  '( e.g. , part-of-speech': ['tagging'],
#  'e.g. , part-of-speech tagging': ['and'],
#  ', part-of-speech tagging and': ['dependency'],
#  'part-of-speech tagging and dependency': ['parsing'],
#  'tagging and dependency parsing': [')'],
#  'and dependency parsing )': ['.'],
#  'dependency parsing ) .': ['In'],
#  'parsing ) . In': ['some'],
#  ') . In some': ['areas'],
#  '. In some areas': [','],
#  'In some areas ,': ['this'],
#  'some areas , this': ['shift'],
#  'areas , this shift': ['has'],
#  ', this shift has': ['entailed'],
#  'this shift has entailed': ['substantial'],
#  'shift has entailed substantial': ['changes'],
#  'has entailed substantial changes': ['in'],
#  'entailed substantial changes in': ['how'],
#  'substantial changes in how': ['NLP'],
#  'changes in how NLP': ['systems'],
#  'in how NLP systems': ['are'],
#  'how NLP systems are': ['designed'],
#  'NLP systems are designed': [','],
#  'systems are designed ,': ['such'],
#  'are designed , such': ['that'],
#  'designed , such that': ['deep'],
#  ', such that deep': ['neural'],
#  'such that deep neural': ['network-based'],
#  'that deep neural network-based': ['approaches'],
#  'deep neural network-based approaches': ['may'],
#  'neural network-based approaches may': ['be'],
#  'network-based approaches may be': ['viewed'],
#  'approaches may be viewed': ['as'],
#  'may be viewed as': ['a'],
#  'be viewed as a': ['new'],
#  'viewed as a new': ['paradigm'],
#  'as a new paradigm': ['distinct'],
#  'a new paradigm distinct': ['from'],
#  'new paradigm distinct from': ['statistical'],
#  'paradigm distinct from statistical': ['natural'],
#  'distinct from statistical natural': ['language'],
#  'from statistical natural language': ['processing'],
#  'statistical natural language processing': ['.'],
#  'language processing . For': ['instance'],
#  'processing . For instance': [','],
#  ...}

# %%
curr_sequence = ' '.join(words_tokens[0:words])
output = curr_sequence
for i in range(50):
    if curr_sequence not in ngrams.keys():
        break
    possible_words = ngrams[curr_sequence]
    next_word = possible_words[random.randrange(len(possible_words))]
    output += ' ' + next_word
    seq_words = nltk.word_tokenize(output)
    curr_sequence = ' '.join(seq_words[len(seq_words)-words:len(seq_words)])

print(output)
# Out:
# Natural language processing ( NLP ) is a subfield of linguistics , computer science , information engineering , and artificial intelligence concerned with the interactions between computers and human ( natural ) languages , in particular how to program computers to process and analyze large amounts of natural language data . Challenges in natural
