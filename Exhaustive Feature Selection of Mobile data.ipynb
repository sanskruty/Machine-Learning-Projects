# %% [markdown]
# # Feature Selection from Mobile data using ExhaustiveFeatureSelector Exhaustive Method
# Dataset: [https://raw.githubusercontent.com/subashgandyer/datasets/main/mobile_price_train.csv]

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/subashgandyer/datasets/main/mobile_price_train.csv"

# %%
df = pd.read_csv(url)
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.price_range.value_counts()
# Out:
# 3    500
# 2    500
# 1    500
# 0    500
# Name: price_range, dtype: int64

# %% [markdown]
# ### Understand the data
# - Find how many features?
# - Find how many samples?
# - What are the data types of each feature column?
# - What do you think could be the most important feature(s)?
# - Run some feature selection methods
# - Is your intuition right?

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Read the mobile data

# %%
data = pd.read_csv("data/mobile_price_train.csv")

# %% [markdown]
# ### Split the dataset into X and y

# %%
X = data.iloc[:,0:20]
y = data.iloc[:,-1]

# %% [markdown]
# ### Sanity check

# %%
X.shape, y.shape
# Out:
# ((2000, 20), (2000,))

# %% [markdown]
# ### How many features

# %%
X.shape[1]
# Out:
# 20

# %%
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %% [markdown]
# ### Import the ExhaustiveFeatureSelector from mlxtend library

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector

# %% [markdown]
# ### Import the Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Build a Logistic Regression model with lbfgs as solver and iterations = 500

# %%
lr = LogisticRegression(class_weight='balanced',
                        solver='lbfgs', 
                        random_state=42, 
                        n_jobs=-1, 
                        max_iter=500
)

# %% [markdown]
# ### Build ExhaustiveFeatureSelector with Logistic Regression model and min and max features as 1 to 2

# %%
efs_lr = ExhaustiveFeatureSelector(lr, 
                                min_features=1, 
                                max_features=2,
                                scoring='accuracy',
                                print_progress=True,
                                cv=2
)

# %% [markdown]
# ### Train the ExhaustiveFeatureSelector model

# %%
efs_lr = efs_lr.fit(X, y)
# Out:
# Features: 210/210

# %% [markdown]
# ### Explore the best feature names from the model

# %%
efs_lr.best_feature_names_
# Out:
# ('battery_power', 'ram')

# %% [markdown]
# ### Best Score feature subset

# %%
efs_lr.best_score_
# Out:
# 0.823

# %% [markdown]
# ### All subsets

# %%
efs_lr.subsets_
# Out:
# {0: {'feature_idx': (0,),
#   'cv_scores': array([0.25 , 0.317]),
#   'avg_score': 0.2835,
#   'feature_names': ('battery_power',)},
#  1: {'feature_idx': (1,),
#   'cv_scores': array([0.243, 0.249]),
#   'avg_score': 0.246,
#   'feature_names': ('blue',)},
#  2: {'feature_idx': (2,),
#   'cv_scores': array([0.229, 0.243]),
#   'avg_score': 0.236,
#   'feature_names': ('clock_speed',)},
#  3: {'feature_idx': (3,),
#   'cv_scores': array([0.24 , 0.246]),
#   'avg_score': 0.243,
#   'feature_names': ('dual_sim',)},
#  4: {'feature_idx': (4,),
#   'cv_scores': array([0.259, 0.24 ]),
#   'avg_score': 0.2495,
#   'feature_names': ('fc',)},
#  5: {'feature_idx': (5,),
#   'cv_scores': array([0.251, 0.26 ]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g',)},
#  6: {'feature_idx': (6,),
#   'cv_scores': array([0.272, 0.271]),
#   'avg_score': 0.2715,
#   'feature_names': ('int_memory',)},
#  7: {'feature_idx': (7,),
#   'cv_scores': array([0.246, 0.26 ]),
#   'avg_score': 0.253,
#   'feature_names': ('m_dep',)},
#  8: {'feature_idx': (8,),
#   'cv_scores': array([0.263, 0.273]),
#   'avg_score': 0.268,
#   'feature_names': ('mobile_wt',)},
#  9: {'feature_idx': (9,),
#   'cv_scores': array([0.266, 0.276]),
#   'avg_score': 0.271,
#   'feature_names': ('n_cores',)},
#  10: {'feature_idx': (10,),
#   'cv_scores': array([0.254, 0.269]),
#   'avg_score': 0.2615,
#   'feature_names': ('pc',)},
#  11: {'feature_idx': (11,),
#   'cv_scores': array([0.297, 0.304]),
#   'avg_score': 0.3005,
#   'feature_names': ('px_height',)},
#  12: {'feature_idx': (12,),
#   'cv_scores': array([0.25, 0.25]),
#   'avg_score': 0.25,
#   'feature_names': ('px_width',)},
#  13: {'feature_idx': (13,),
#   'cv_scores': array([0.749, 0.752]),
#   'avg_score': 0.7505,
#   'feature_names': ('ram',)},
#  14: {'feature_idx': (14,),
#   'cv_scores': array([0.263, 0.27 ]),
#   'avg_score': 0.2665,
#   'feature_names': ('sc_h',)},
#  15: {'feature_idx': (15,),
#   'cv_scores': array([0.276, 0.255]),
#   'avg_score': 0.2655,
#   'feature_names': ('sc_w',)},
#  16: {'feature_idx': (16,),
#   'cv_scores': array([0.268, 0.266]),
#   'avg_score': 0.267,
#   'feature_names': ('talk_time',)},
#  17: {'feature_idx': (17,),
#   'cv_scores': array([0.237, 0.249]),
#   'avg_score': 0.243,
#   'feature_names': ('three_g',)},
#  18: {'feature_idx': (18,),
#   'cv_scores': array([0.256, 0.252]),
#   'avg_score': 0.254,
#   'feature_names': ('touch_screen',)},
#  19: {'feature_idx': (19,),
#   'cv_scores': array([0.242, 0.239]),
#   'avg_score': 0.2405,
#   'feature_names': ('wifi',)},
#  20: {'feature_idx': (0, 1),
#   'cv_scores': array([0.306, 0.328]),
#   'avg_score': 0.317,
#   'feature_names': ('battery_power', 'blue')},
#  21: {'feature_idx': (0, 2),
#   'cv_scores': array([0.319, 0.32 ]),
#   'avg_score': 0.3195,
#   'feature_names': ('battery_power', 'clock_speed')},
#  22: {'feature_idx': (0, 3),
#   'cv_scores': array([0.298, 0.309]),
#   'avg_score': 0.3035,
#   'feature_names': ('battery_power', 'dual_sim')},
#  23: {'feature_idx': (0, 4),
#   'cv_scores': array([0.268, 0.322]),
#   'avg_score': 0.29500000000000004,
#   'feature_names': ('battery_power', 'fc')},
#  24: {'feature_idx': (0, 5),
#   'cv_scores': array([0.306, 0.319]),
#   'avg_score': 0.3125,
#   'feature_names': ('battery_power', 'four_g')},
#  25: {'feature_idx': (0, 6),
#   'cv_scores': array([0.322, 0.32 ]),
#   'avg_score': 0.321,
#   'feature_names': ('battery_power', 'int_memory')},
#  26: {'feature_idx': (0, 7),
#   'cv_scores': array([0.309, 0.323]),
#   'avg_score': 0.316,
#   'feature_names': ('battery_power', 'm_dep')},
#  27: {'feature_idx': (0, 8),
#   'cv_scores': array([0.308, 0.313]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'mobile_wt')},
#  28: {'feature_idx': (0, 9),
#   'cv_scores': array([0.301, 0.305]),
#   'avg_score': 0.303,
#   'feature_names': ('battery_power', 'n_cores')},
#  29: {'feature_idx': (0, 10),
#   'cv_scores': array([0.313, 0.308]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'pc')},
#  30: {'feature_idx': (0, 11),
#   'cv_scores': array([0.316, 0.335]),
#   'avg_score': 0.3255,
#   'feature_names': ('battery_power', 'px_height')},
#  31: {'feature_idx': (0, 12),
#   'cv_scores': array([0.342, 0.32 ]),
#   'avg_score': 0.331,
#   'feature_names': ('battery_power', 'px_width')},
#  32: {'feature_idx': (0, 13),
#   'cv_scores': array([0.824, 0.822]),
#   'avg_score': 0.823,
#   'feature_names': ('battery_power', 'ram')},
#  33: {'feature_idx': (0, 14),
#   'cv_scores': array([0.296, 0.302]),
#   'avg_score': 0.299,
#   'feature_names': ('battery_power', 'sc_h')},
#  34: {'feature_idx': (0, 15),
#   'cv_scores': array([0.272, 0.313]),
#   'avg_score': 0.2925,
#   'feature_names': ('battery_power', 'sc_w')},
#  35: {'feature_idx': (0, 16),
#   'cv_scores': array([0.33 , 0.322]),
#   'avg_score': 0.326,
#   'feature_names': ('battery_power', 'talk_time')},
#  36: {'feature_idx': (0, 17),
#   'cv_scores': array([0.309, 0.312]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'three_g')},
#  37: {'feature_idx': (0, 18),
#   'cv_scores': array([0.312, 0.321]),
#   'avg_score': 0.3165,
#   'feature_names': ('battery_power', 'touch_screen')},
#  38: {'feature_idx': (0, 19),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('battery_power', 'wifi')},
#  39: {'feature_idx': (1, 2),
#   'cv_scores': array([0.23 , 0.266]),
#   'avg_score': 0.248,
#   'feature_names': ('blue', 'clock_speed')},
#  40: {'feature_idx': (1, 3),
#   'cv_scores': array([0.24 , 0.258]),
#   'avg_score': 0.249,
#   'feature_names': ('blue', 'dual_sim')},
#  41: {'feature_idx': (1, 4),
#   'cv_scores': array([0.25, 0.24]),
#   'avg_score': 0.245,
#   'feature_names': ('blue', 'fc')},
#  42: {'feature_idx': (1, 5),
#   'cv_scores': array([0.236, 0.263]),
#   'avg_score': 0.2495,
#   'feature_names': ('blue', 'four_g')},
#  43: {'feature_idx': (1, 6),
#   'cv_scores': array([0.264, 0.255]),
#   'avg_score': 0.2595,
#   'feature_names': ('blue', 'int_memory')},
#  44: {'feature_idx': (1, 7),
#   'cv_scores': array([0.263, 0.262]),
#   'avg_score': 0.2625,
#   'feature_names': ('blue', 'm_dep')},
#  45: {'feature_idx': (1, 8),
#   'cv_scores': array([0.258, 0.257]),
#   'avg_score': 0.2575,
#   'feature_names': ('blue', 'mobile_wt')},
#  46: {'feature_idx': (1, 9),
#   'cv_scores': array([0.256, 0.266]),
#   'avg_score': 0.261,
#   'feature_names': ('blue', 'n_cores')},
#  47: {'feature_idx': (1, 10),
#   'cv_scores': array([0.255, 0.246]),
#   'avg_score': 0.2505,
#   'feature_names': ('blue', 'pc')},
#  48: {'feature_idx': (1, 11),
#   'cv_scores': array([0.288, 0.297]),
#   'avg_score': 0.2925,
#   'feature_names': ('blue', 'px_height')},
#  49: {'feature_idx': (1, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('blue', 'px_width')},
#  50: {'feature_idx': (1, 13),
#   'cv_scores': array([0.761, 0.748]),
#   'avg_score': 0.7545,
#   'feature_names': ('blue', 'ram')},
#  51: {'feature_idx': (1, 14),
#   'cv_scores': array([0.26 , 0.263]),
#   'avg_score': 0.2615,
#   'feature_names': ('blue', 'sc_h')},
#  52: {'feature_idx': (1, 15),
#   'cv_scores': array([0.261, 0.241]),
#   'avg_score': 0.251,
#   'feature_names': ('blue', 'sc_w')},
#  53: {'feature_idx': (1, 16),
#   'cv_scores': array([0.264, 0.253]),
#   'avg_score': 0.2585,
#   'feature_names': ('blue', 'talk_time')},
#  54: {'feature_idx': (1, 17),
#   'cv_scores': array([0.226, 0.253]),
#   'avg_score': 0.2395,
#   'feature_names': ('blue', 'three_g')},
#  55: {'feature_idx': (1, 18),
#   'cv_scores': array([0.253, 0.261]),
#   'avg_score': 0.257,
#   'feature_names': ('blue', 'touch_screen')},
#  56: {'feature_idx': (1, 19),
#   'cv_scores': array([0.241, 0.25 ]),
#   'avg_score': 0.2455,
#   'feature_names': ('blue', 'wifi')},
#  57: {'feature_idx': (2, 3),
#   'cv_scores': array([0.24 , 0.267]),
#   'avg_score': 0.2535,
#   'feature_names': ('clock_speed', 'dual_sim')},
#  58: {'feature_idx': (2, 4),
#   'cv_scores': array([0.257, 0.256]),
#   'avg_score': 0.2565,
#   'feature_names': ('clock_speed', 'fc')},
#  59: {'feature_idx': (2, 5),
#   'cv_scores': array([0.248, 0.258]),
#   'avg_score': 0.253,
#   'feature_names': ('clock_speed', 'four_g')},
#  60: {'feature_idx': (2, 6),
#   'cv_scores': array([0.271, 0.27 ]),
#   'avg_score': 0.2705,
#   'feature_names': ('clock_speed', 'int_memory')},
#  61: {'feature_idx': (2, 7),
#   'cv_scores': array([0.239, 0.262]),
#   'avg_score': 0.2505,
#   'feature_names': ('clock_speed', 'm_dep')},
#  62: {'feature_idx': (2, 8),
#   'cv_scores': array([0.245, 0.246]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'mobile_wt')},
#  63: {'feature_idx': (2, 9),
#   'cv_scores': array([0.258, 0.265]),
#   'avg_score': 0.2615,
#   'feature_names': ('clock_speed', 'n_cores')},
#  64: {'feature_idx': (2, 10),
#   'cv_scores': array([0.239, 0.252]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'pc')},
#  65: {'feature_idx': (2, 11),
#   'cv_scores': array([0.291, 0.301]),
#   'avg_score': 0.296,
#   'feature_names': ('clock_speed', 'px_height')},
#  66: {'feature_idx': (2, 12),
#   'cv_scores': array([0.294, 0.303]),
#   'avg_score': 0.2985,
#   'feature_names': ('clock_speed', 'px_width')},
#  67: {'feature_idx': (2, 13),
#   'cv_scores': array([0.751, 0.743]),
#   'avg_score': 0.747,
#   'feature_names': ('clock_speed', 'ram')},
#  68: {'feature_idx': (2, 14),
#   'cv_scores': array([0.255, 0.25 ]),
#   'avg_score': 0.2525,
#   'feature_names': ('clock_speed', 'sc_h')},
#  69: {'feature_idx': (2, 15),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('clock_speed', 'sc_w')},
#  70: {'feature_idx': (2, 16),
#   'cv_scores': array([0.272, 0.247]),
#   'avg_score': 0.2595,
#   'feature_names': ('clock_speed', 'talk_time')},
#  71: {'feature_idx': (2, 17),
#   'cv_scores': array([0.221, 0.253]),
#   'avg_score': 0.237,
#   'feature_names': ('clock_speed', 'three_g')},
#  72: {'feature_idx': (2, 18),
#   'cv_scores': array([0.256, 0.255]),
#   'avg_score': 0.2555,
#   'feature_names': ('clock_speed', 'touch_screen')},
#  73: {'feature_idx': (2, 19),
#   'cv_scores': array([0.242, 0.241]),
#   'avg_score': 0.2415,
#   'feature_names': ('clock_speed', 'wifi')},
#  74: {'feature_idx': (3, 4),
#   'cv_scores': array([0.253, 0.243]),
#   'avg_score': 0.248,
#   'feature_names': ('dual_sim', 'fc')},
#  75: {'feature_idx': (3, 5),
#   'cv_scores': array([0.228, 0.245]),
#   'avg_score': 0.2365,
#   'feature_names': ('dual_sim', 'four_g')},
#  76: {'feature_idx': (3, 6),
#   'cv_scores': array([0.255, 0.251]),
#   'avg_score': 0.253,
#   'feature_names': ('dual_sim', 'int_memory')},
#  77: {'feature_idx': (3, 7),
#   'cv_scores': array([0.24 , 0.242]),
#   'avg_score': 0.241,
#   'feature_names': ('dual_sim', 'm_dep')},
#  78: {'feature_idx': (3, 8),
#   'cv_scores': array([0.254, 0.255]),
#   'avg_score': 0.2545,
#   'feature_names': ('dual_sim', 'mobile_wt')},
#  79: {'feature_idx': (3, 9),
#   'cv_scores': array([0.263, 0.265]),
#   'avg_score': 0.264,
#   'feature_names': ('dual_sim', 'n_cores')},
#  80: {'feature_idx': (3, 10),
#   'cv_scores': array([0.247, 0.241]),
#   'avg_score': 0.244,
#   'feature_names': ('dual_sim', 'pc')},
#  81: {'feature_idx': (3, 11),
#   'cv_scores': array([0.29 , 0.307]),
#   'avg_score': 0.2985,
#   'feature_names': ('dual_sim', 'px_height')},
#  82: {'feature_idx': (3, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('dual_sim', 'px_width')},
#  83: {'feature_idx': (3, 13),
#   'cv_scores': array([0.752, 0.75 ]),
#   'avg_score': 0.751,
#   'feature_names': ('dual_sim', 'ram')},
#  84: {'feature_idx': (3, 14),
#   'cv_scores': array([0.242, 0.259]),
#   'avg_score': 0.2505,
#   'feature_names': ('dual_sim', 'sc_h')},
#  85: {'feature_idx': (3, 15),
#   'cv_scores': array([0.26 , 0.242]),
#   'avg_score': 0.251,
#   'feature_names': ('dual_sim', 'sc_w')},
#  86: {'feature_idx': (3, 16),
#   'cv_scores': array([0.251, 0.253]),
#   'avg_score': 0.252,
#   'feature_names': ('dual_sim', 'talk_time')},
#  87: {'feature_idx': (3, 17),
#   'cv_scores': array([0.245, 0.244]),
#   'avg_score': 0.2445,
#   'feature_names': ('dual_sim', 'three_g')},
#  88: {'feature_idx': (3, 18),
#   'cv_scores': array([0.259, 0.246]),
#   'avg_score': 0.2525,
#   'feature_names': ('dual_sim', 'touch_screen')},
#  89: {'feature_idx': (3, 19),
#   'cv_scores': array([0.246, 0.239]),
#   'avg_score': 0.2425,
#   'feature_names': ('dual_sim', 'wifi')},
#  90: {'feature_idx': (4, 5),
#   'cv_scores': array([0.254, 0.24 ]),
#   'avg_score': 0.247,
#   'feature_names': ('fc', 'four_g')},
#  91: {'feature_idx': (4, 6),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('fc', 'int_memory')},
#  92: {'feature_idx': (4, 7),
#   'cv_scores': array([0.255, 0.237]),
#   'avg_score': 0.246,
#   'feature_names': ('fc', 'm_dep')},
#  93: {'feature_idx': (4, 8),
#   'cv_scores': array([0.25 , 0.269]),
#   'avg_score': 0.2595,
#   'feature_names': ('fc', 'mobile_wt')},
#  94: {'feature_idx': (4, 9),
#   'cv_scores': array([0.267, 0.26 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('fc', 'n_cores')},
#  95: {'feature_idx': (4, 10),
#   'cv_scores': array([0.268, 0.255]),
#   'avg_score': 0.2615,
#   'feature_names': ('fc', 'pc')},
#  96: {'feature_idx': (4, 11),
#   'cv_scores': array([0.3  , 0.303]),
#   'avg_score': 0.3015,
#   'feature_names': ('fc', 'px_height')},
#  97: {'feature_idx': (4, 12),
#   'cv_scores': array([0.298, 0.304]),
#   'avg_score': 0.301,
#   'feature_names': ('fc', 'px_width')},
#  98: {'feature_idx': (4, 13),
#   'cv_scores': array([0.749, 0.749]),
#   'avg_score': 0.749,
#   'feature_names': ('fc', 'ram')},
#  99: {'feature_idx': (4, 14),
#   'cv_scores': array([0.26 , 0.255]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'sc_h')},
#  100: {'feature_idx': (4, 15),
#   'cv_scores': array([0.257, 0.269]),
#   'avg_score': 0.263,
#   'feature_names': ('fc', 'sc_w')},
#  101: {'feature_idx': (4, 16),
#   'cv_scores': array([0.258, 0.253]),
#   'avg_score': 0.2555,
#   'feature_names': ('fc', 'talk_time')},
#  102: {'feature_idx': (4, 17),
#   'cv_scores': array([0.26 , 0.243]),
#   'avg_score': 0.2515,
#   'feature_names': ('fc', 'three_g')},
#  103: {'feature_idx': (4, 18),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'touch_screen')},
#  104: {'feature_idx': (4, 19),
#   'cv_scores': array([0.254, 0.236]),
#   'avg_score': 0.245,
#   'feature_names': ('fc', 'wifi')},
#  105: {'feature_idx': (5, 6),
#   'cv_scores': array([0.27 , 0.272]),
#   'avg_score': 0.271,
#   'feature_names': ('four_g', 'int_memory')},
#  106: {'feature_idx': (5, 7),
#   'cv_scores': array([0.244, 0.265]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'm_dep')},
#  107: {'feature_idx': (5, 8),
#   'cv_scores': array([0.249, 0.26 ]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'mobile_wt')},
#  108: {'feature_idx': (5, 9),
#   'cv_scores': array([0.261, 0.245]),
#   'avg_score': 0.253,
#   'feature_names': ('four_g', 'n_cores')},
#  109: {'feature_idx': (5, 10),
#   'cv_scores': array([0.257, 0.255]),
#   'avg_score': 0.256,
#   'feature_names': ('four_g', 'pc')},
#  110: {'feature_idx': (5, 11),
#   'cv_scores': array([0.291, 0.3  ]),
#   'avg_score': 0.2955,
#   'feature_names': ('four_g', 'px_height')},
#  111: {'feature_idx': (5, 12),
#   'cv_scores': array([0.291, 0.292]),
#   'avg_score': 0.2915,
#   'feature_names': ('four_g', 'px_width')},
#  112: {'feature_idx': (5, 13),
#   'cv_scores': array([0.754, 0.753]),
#   'avg_score': 0.7535000000000001,
#   'feature_names': ('four_g', 'ram')},
#  113: {'feature_idx': (5, 14),
#   'cv_scores': array([0.247, 0.264]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g', 'sc_h')},
#  114: {'feature_idx': (5, 15),
#   'cv_scores': array([0.266, 0.252]),
#   'avg_score': 0.259,
#   'feature_names': ('four_g', 'sc_w')},
#  115: {'feature_idx': (5, 16),
#   'cv_scores': array([0.259, 0.239]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'talk_time')},
#  116: {'feature_idx': (5, 17),
#   'cv_scores': array([0.236, 0.259]),
#   'avg_score': 0.2475,
#   'feature_names': ('four_g', 'three_g')},
#  117: {'feature_idx': (5, 18),
#   'cv_scores': array([0.246, 0.252]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'touch_screen')},
#  118: {'feature_idx': (5, 19),
#   'cv_scores': array([0.26 , 0.253]),
#   'avg_score': 0.2565,
#   'feature_names': ('four_g', 'wifi')},
#  119: {'feature_idx': (6, 7),
#   'cv_scores': array([0.274, 0.26 ]),
#   'avg_score': 0.267,
#   'feature_names': ('int_memory', 'm_dep')},
#  120: {'feature_idx': (6, 8),
#   'cv_scores': array([0.268, 0.256]),
#   'avg_score': 0.262,
#   'feature_names': ('int_memory', 'mobile_wt')},
#  121: {'feature_idx': (6, 9),
#   'cv_scores': array([0.28 , 0.272]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'n_cores')},
#  122: {'feature_idx': (6, 10),
#   'cv_scores': array([0.282, 0.278]),
#   'avg_score': 0.28,
#   'feature_names': ('int_memory', 'pc')},
#  123: {'feature_idx': (6, 11),
#   'cv_scores': array([0.289, 0.302]),
#   'avg_score': 0.2955,
#   'feature_names': ('int_memory', 'px_height')},
#  124: {'feature_idx': (6, 12),
#   'cv_scores': array([0.299, 0.302]),
#   'avg_score': 0.3005,
#   'feature_names': ('int_memory', 'px_width')},
#  125: {'feature_idx': (6, 13),
#   'cv_scores': array([0.758, 0.745]),
#   'avg_score': 0.7515000000000001,
#   'feature_names': ('int_memory', 'ram')},
#  126: {'feature_idx': (6, 14),
#   'cv_scores': array([0.252, 0.268]),
#   'avg_score': 0.26,
#   'feature_names': ('int_memory', 'sc_h')},
#  127: {'feature_idx': (6, 15),
#   'cv_scores': array([0.273, 0.267]),
#   'avg_score': 0.27,
#   'feature_names': ('int_memory', 'sc_w')},
#  128: {'feature_idx': (6, 16),
#   'cv_scores': array([0.282, 0.267]),
#   'avg_score': 0.27449999999999997,
#   'feature_names': ('int_memory', 'talk_time')},
#  129: {'feature_idx': (6, 17),
#   'cv_scores': array([0.269, 0.26 ]),
#   'avg_score': 0.2645,
#   'feature_names': ('int_memory', 'three_g')},
#  130: {'feature_idx': (6, 18),
#   'cv_scores': array([0.277, 0.275]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'touch_screen')},
#  131: {'feature_idx': (6, 19),
#   'cv_scores': array([0.255, 0.257]),
#   'avg_score': 0.256,
#   'feature_names': ('int_memory', 'wifi')},
#  132: {'feature_idx': (7, 8),
#   'cv_scores': array([0.254, 0.262]),
#   'avg_score': 0.258,
#   'feature_names': ('m_dep', 'mobile_wt')},
#  133: {'feature_idx': (7, 9),
#   'cv_scores': array([0.255, 0.273]),
#   'avg_score': 0.264,
#   'feature_names': ('m_dep', 'n_cores')},
#  134: {'feature_idx': (7, 10),
#   'cv_scores': array([0.25 , 0.258]),
#   'avg_score': 0.254,
#   'feature_names': ('m_dep', 'pc')},
#  135: {'feature_idx': (7, 11),
#   'cv_scores': array([0.301, 0.301]),
#   'avg_score': 0.301,
#   'feature_names': ('m_dep', 'px_height')},
#  136: {'feature_idx': (7, 12),
#   'cv_scores': array([0.298, 0.25 ]),
#   'avg_score': 0.274,
#   'feature_names': ('m_dep', 'px_width')},
#  137: {'feature_idx': (7, 13),
#   'cv_scores': array([0.765, 0.748]),
#   'avg_score': 0.7565,
#   'feature_names': ('m_dep', 'ram')},
#  138: {'feature_idx': (7, 14),
#   'cv_scores': array([0.251, 0.264]),
#   'avg_score': 0.2575,
#   'feature_names': ('m_dep', 'sc_h')},
#  139: {'feature_idx': (7, 15),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('m_dep', 'sc_w')},
#  140: {'feature_idx': (7, 16),
#   'cv_scores': array([0.271, 0.276]),
#   'avg_score': 0.2735,
#   'feature_names': ('m_dep', 'talk_time')},
#  141: {'feature_idx': (7, 17),
#   'cv_scores': array([0.248, 0.253]),
#   'avg_score': 0.2505,
#   'feature_names': ('m_dep', 'three_g')},
#  142: {'feature_idx': (7, 18),
#   'cv_scores': array([0.249, 0.243]),
#   'avg_score': 0.246,
#   'feature_names': ('m_dep', 'touch_screen')},
#  143: {'feature_idx': (7, 19),
#   'cv_scores': array([0.254, 0.248]),
#   'avg_score': 0.251,
#   'feature_names': ('m_dep', 'wifi')},
#  144: {'feature_idx': (8, 9),
#   'cv_scores': array([0.276, 0.281]),
#   'avg_score': 0.2785,
#   'feature_names': ('mobile_wt', 'n_cores')},
#  145: {'feature_idx': (8, 10),
#   'cv_scores': array([0.289, 0.27 ]),
#   'avg_score': 0.27949999999999997,
#   'feature_names': ('mobile_wt', 'pc')},
#  146: {'feature_idx': (8, 11),
#   'cv_scores': array([0.296, 0.285]),
#   'avg_score': 0.2905,
#   'feature_names': ('mobile_wt', 'px_height')},
#  147: {'feature_idx': (8, 12),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('mobile_wt', 'px_width')},
#  148: {'feature_idx': (8, 13),
#   'cv_scores': array([0.756, 0.746]),
#   'avg_score': 0.751,
#   'feature_names': ('mobile_wt', 'ram')},
#  149: {'feature_idx': (8, 14),
#   'cv_scores': array([0.253, 0.252]),
#   'avg_score': 0.2525,
#   'feature_names': ('mobile_wt', 'sc_h')},
#  150: {'feature_idx': (8, 15),
#   'cv_scores': array([0.263, 0.269]),
#   'avg_score': 0.266,
#   'feature_names': ('mobile_wt', 'sc_w')},
#  151: {'feature_idx': (8, 16),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('mobile_wt', 'talk_time')},
#  152: {'feature_idx': (8, 17),
#   'cv_scores': array([0.261, 0.266]),
#   'avg_score': 0.2635,
#   'feature_names': ('mobile_wt', 'three_g')},
#  153: {'feature_idx': (8, 18),
#   'cv_scores': array([0.288, 0.263]),
#   'avg_score': 0.27549999999999997,
#   'feature_names': ('mobile_wt', 'touch_screen')},
#  154: {'feature_idx': (8, 19),
#   'cv_scores': array([0.252, 0.27 ]),
#   'avg_score': 0.261,
#   'feature_names': ('mobile_wt', 'wifi')},
#  155: {'feature_idx': (9, 10),
#   'cv_scores': array([0.27 , 0.253]),
#   'avg_score': 0.2615,
#   'feature_names': ('n_cores', 'pc')},
#  156: {'feature_idx': (9, 11),
#   'cv_scores': array([0.29 , 0.291]),
#   'avg_score': 0.2905,
#   'feature_names': ('n_cores', 'px_height')},
#  157: {'feature_idx': (9, 12),
#   'cv_scores': array([0.276, 0.273]),
#   'avg_score': 0.2745,
#   'feature_names': ('n_cores', 'px_width')},
#  158: {'feature_idx': (9, 13),
#   'cv_scores': array([0.764, 0.754]),
#   'avg_score': 0.759,
#   'feature_names': ('n_cores', 'ram')},
#  159: {'feature_idx': (9, 14),
#   'cv_scores': array([0.264, 0.266]),
#   'avg_score': 0.265,
#   'feature_names': ('n_cores', 'sc_h')},
#  160: {'feature_idx': (9, 15),
#   'cv_scores': array([0.277, 0.274]),
#   'avg_score': 0.2755,
#   'feature_names': ('n_cores', 'sc_w')},
#  161: {'feature_idx': (9, 16),
#   'cv_scores': array([0.275, 0.277]),
#   'avg_score': 0.276,
#   'feature_names': ('n_cores', 'talk_time')},
#  162: {'feature_idx': (9, 17),
#   'cv_scores': array([0.265, 0.235]),
#   'avg_score': 0.25,
#   'feature_names': ('n_cores', 'three_g')},
#  163: {'feature_idx': (9, 18),
#   'cv_scores': array([0.27 , 0.258]),
#   'avg_score': 0.264,
#   'feature_names': ('n_cores', 'touch_screen')},
#  164: {'feature_idx': (9, 19),
#   'cv_scores': array([0.253, 0.254]),
#   'avg_score': 0.2535,
#   'feature_names': ('n_cores', 'wifi')},
#  165: {'feature_idx': (10, 11),
#   'cv_scores': array([0.291, 0.296]),
#   'avg_score': 0.2935,
#   'feature_names': ('pc', 'px_height')},
#  166: {'feature_idx': (10, 12),
#   'cv_scores': array([0.298, 0.308]),
#   'avg_score': 0.303,
#   'feature_names': ('pc', 'px_width')},
#  167: {'feature_idx': (10, 13),
#   'cv_scores': array([0.761, 0.752]),
#   'avg_score': 0.7565,
#   'feature_names': ('pc', 'ram')},
#  168: {'feature_idx': (10, 14),
#   'cv_scores': array([0.267, 0.262]),
#   'avg_score': 0.2645,
#   'feature_names': ('pc', 'sc_h')},
#  169: {'feature_idx': (10, 15),
#   'cv_scores': array([0.281, 0.263]),
#   'avg_score': 0.272,
#   'feature_names': ('pc', 'sc_w')},
#  170: {'feature_idx': (10, 16),
#   'cv_scores': array([0.269, 0.273]),
#   'avg_score': 0.271,
#   'feature_names': ('pc', 'talk_time')},
#  171: {'feature_idx': (10, 17),
#   'cv_scores': array([0.259, 0.247]),
#   'avg_score': 0.253,
#   'feature_names': ('pc', 'three_g')},
#  172: {'feature_idx': (10, 18),
#   'cv_scores': array([0.256, 0.269]),
#   'avg_score': 0.2625,
#   'feature_names': ('pc', 'touch_screen')},
#  173: {'feature_idx': (10, 19),
#   'cv_scores': array([0.252, 0.248]),
#   'avg_score': 0.25,
#   'feature_names': ('pc', 'wifi')},
#  174: {'feature_idx': (11, 12),
#   'cv_scores': array([0.295, 0.325]),
#   'avg_score': 0.31,
#   'feature_names': ('px_height', 'px_width')},
#  175: {'feature_idx': (11, 13),
#   'cv_scores': array([0.787, 0.804]),
#   'avg_score': 0.7955000000000001,
#   'feature_names': ('px_height', 'ram')},
#  176: {'feature_idx': (11, 14),
#   'cv_scores': array([0.293, 0.281]),
#   'avg_score': 0.28700000000000003,
#   'feature_names': ('px_height', 'sc_h')},
#  177: {'feature_idx': (11, 15),
#   'cv_scores': array([0.295, 0.294]),
#   'avg_score': 0.2945,
#   'feature_names': ('px_height', 'sc_w')},
#  178: {'feature_idx': (11, 16),
#   'cv_scores': array([0.281, 0.307]),
#   'avg_score': 0.29400000000000004,
#   'feature_names': ('px_height', 'talk_time')},
#  179: {'feature_idx': (11, 17),
#   'cv_scores': array([0.276, 0.293]),
#   'avg_score': 0.2845,
#   'feature_names': ('px_height', 'three_g')},
#  180: {'feature_idx': (11, 18),
#   'cv_scores': array([0.29, 0.29]),
#   'avg_score': 0.29,
#   'feature_names': ('px_height', 'touch_screen')},
#  181: {'feature_idx': (11, 19),
#   'cv_scores': array([0.292, 0.294]),
#   'avg_score': 0.293,
#   'feature_names': ('px_height', 'wifi')},
#  182: {'feature_idx': (12, 13),
#   'cv_scores': array([0.777, 0.785]),
#   'avg_score': 0.781,
#   'feature_names': ('px_width', 'ram')},
#  183: {'feature_idx': (12, 14),
#   'cv_scores': array([0.294, 0.29 ]),
#   'avg_score': 0.292,
#   'feature_names': ('px_width', 'sc_h')},
#  184: {'feature_idx': (12, 15),
#   'cv_scores': array([0.305, 0.297]),
#   'avg_score': 0.301,
#   'feature_names': ('px_width', 'sc_w')},
#  185: {'feature_idx': (12, 16),
#   'cv_scores': array([0.307, 0.287]),
#   'avg_score': 0.297,
#   'feature_names': ('px_width', 'talk_time')},
#  186: {'feature_idx': (12, 17),
#   'cv_scores': array([0.281, 0.25 ]),
#   'avg_score': 0.2655,
#   'feature_names': ('px_width', 'three_g')},
#  187: {'feature_idx': (12, 18),
#   'cv_scores': array([0.299, 0.293]),
#   'avg_score': 0.296,
#   'feature_names': ('px_width', 'touch_screen')},
#  188: {'feature_idx': (12, 19),
#   'cv_scores': array([0.277, 0.25 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('px_width', 'wifi')},
#  189: {'feature_idx': (13, 14),
#   'cv_scores': array([0.758, 0.748]),
#   'avg_score': 0.753,
#   'feature_names': ('ram', 'sc_h')},
#  190: {'feature_idx': (13, 15),
#   'cv_scores': array([0.76 , 0.751]),
#   'avg_score': 0.7555000000000001,
#   'feature_names': ('ram', 'sc_w')},
#  191: {'feature_idx': (13, 16),
#   'cv_scores': array([0.768, 0.748]),
#   'avg_score': 0.758,
#   'feature_names': ('ram', 'talk_time')},
#  192: {'feature_idx': (13, 17),
#   'cv_scores': array([0.762, 0.752]),
#   'avg_score': 0.757,
#   'feature_names': ('ram', 'three_g')},
#  193: {'feature_idx': (13, 18),
#   'cv_scores': array([0.753, 0.749]),
#   'avg_score': 0.751,
#   'feature_names': ('ram', 'touch_screen')},
#  194: {'feature_idx': (13, 19),
#   'cv_scores': array([0.762, 0.748]),
#   'avg_score': 0.755,
#   'feature_names': ('ram', 'wifi')},
#  195: {'feature_idx': (14, 15),
#   'cv_scores': array([0.259, 0.251]),
#   'avg_score': 0.255,
#   'feature_names': ('sc_h', 'sc_w')},
#  196: {'feature_idx': (14, 16),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('sc_h', 'talk_time')},
#  197: {'feature_idx': (14, 17),
#   'cv_scores': array([0.246, 0.248]),
#   'avg_score': 0.247,
#   'feature_names': ('sc_h', 'three_g')},
#  198: {'feature_idx': (14, 18),
#   'cv_scores': array([0.246, 0.257]),
#   'avg_score': 0.2515,
#   'feature_names': ('sc_h', 'touch_screen')},
#  199: {'feature_idx': (14, 19),
#   'cv_scores': array([0.241, 0.255]),
#   'avg_score': 0.248,
#   'feature_names': ('sc_h', 'wifi')},
#  200: {'feature_idx': (15, 16),
#   'cv_scores': array([0.284, 0.279]),
#   'avg_score': 0.2815,
#   'feature_names': ('sc_w', 'talk_time')},
#  201: {'feature_idx': (15, 17),
#   'cv_scores': array([0.258, 0.254]),
#   'avg_score': 0.256,
#   'feature_names': ('sc_w', 'three_g')},
#  202: {'feature_idx': (15, 18),
#   'cv_scores': array([0.256, 0.267]),
#   'avg_score': 0.2615,
#   'feature_names': ('sc_w', 'touch_screen')},
#  203: {'feature_idx': (15, 19),
#   'cv_scores': array([0.233, 0.258]),
#   'avg_score': 0.2455,
#   'feature_names': ('sc_w', 'wifi')},
#  204: {'feature_idx': (16, 17),
#   'cv_scores': array([0.263, 0.248]),
#   'avg_score': 0.2555,
#   'feature_names': ('talk_time', 'three_g')},
#  205: {'feature_idx': (16, 18),
#   'cv_scores': array([0.269, 0.277]),
#   'avg_score': 0.273,
#   'feature_names': ('talk_time', 'touch_screen')},
#  206: {'feature_idx': (16, 19),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('talk_time', 'wifi')},
#  207: {'feature_idx': (17, 18),
#   'cv_scores': array([0.256, 0.262]),
#   'avg_score': 0.259,
#   'feature_names': ('three_g', 'touch_screen')},
#  208: {'feature_idx': (17, 19),
#   'cv_scores': array([0.242, 0.233]),
#   'avg_score': 0.2375,
#   'feature_names': ('three_g', 'wifi')},
#  209: {'feature_idx': (18, 19),
#   'cv_scores': array([0.248, 0.251]),
#   'avg_score': 0.2495,
#   'feature_names': ('touch_screen', 'wifi')}}

# %% [markdown]
# ### Getting Metric dict

# %%
metric_dict = efs_lr.get_metric_dict()
metric_dict
# Out:
# {0: {'feature_idx': (0,),
#   'cv_scores': array([0.25 , 0.317]),
#   'avg_score': 0.2835,
#   'feature_names': ('battery_power',),
#   'ci_bound': 0.14413886645202767,
#   'std_dev': 0.0335,
#   'std_err': 0.033499999999999995},
#  1: {'feature_idx': (1,),
#   'cv_scores': array([0.243, 0.249]),
#   'avg_score': 0.246,
#   'feature_names': ('blue',),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  2: {'feature_idx': (2,),
#   'cv_scores': array([0.229, 0.243]),
#   'avg_score': 0.236,
#   'feature_names': ('clock_speed',),
#   'ci_bound': 0.030118569109378886,
#   'std_dev': 0.006999999999999992,
#   'std_err': 0.0069999999999999915},
#  3: {'feature_idx': (3,),
#   'cv_scores': array([0.24 , 0.246]),
#   'avg_score': 0.243,
#   'feature_names': ('dual_sim',),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  4: {'feature_idx': (4,),
#   'cv_scores': array([0.259, 0.24 ]),
#   'avg_score': 0.2495,
#   'feature_names': ('fc',),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  5: {'feature_idx': (5,),
#   'cv_scores': array([0.251, 0.26 ]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g',),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  6: {'feature_idx': (6,),
#   'cv_scores': array([0.272, 0.271]),
#   'avg_score': 0.2715,
#   'feature_names': ('int_memory',),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  7: {'feature_idx': (7,),
#   'cv_scores': array([0.246, 0.26 ]),
#   'avg_score': 0.253,
#   'feature_names': ('m_dep',),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  8: {'feature_idx': (8,),
#   'cv_scores': array([0.263, 0.273]),
#   'avg_score': 0.268,
#   'feature_names': ('mobile_wt',),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  9: {'feature_idx': (9,),
#   'cv_scores': array([0.266, 0.276]),
#   'avg_score': 0.271,
#   'feature_names': ('n_cores',),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  10: {'feature_idx': (10,),
#   'cv_scores': array([0.254, 0.269]),
#   'avg_score': 0.2615,
#   'feature_names': ('pc',),
#   'ci_bound': 0.032269895474334585,
#   'std_dev': 0.007500000000000007,
#   'std_err': 0.007500000000000006},
#  11: {'feature_idx': (11,),
#   'cv_scores': array([0.297, 0.304]),
#   'avg_score': 0.3005,
#   'feature_names': ('px_height',),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  12: {'feature_idx': (12,),
#   'cv_scores': array([0.25, 0.25]),
#   'avg_score': 0.25,
#   'feature_names': ('px_width',),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  13: {'feature_idx': (13,),
#   'cv_scores': array([0.749, 0.752]),
#   'avg_score': 0.7505,
#   'feature_names': ('ram',),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  14: {'feature_idx': (14,),
#   'cv_scores': array([0.263, 0.27 ]),
#   'avg_score': 0.2665,
#   'feature_names': ('sc_h',),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  15: {'feature_idx': (15,),
#   'cv_scores': array([0.276, 0.255]),
#   'avg_score': 0.2655,
#   'feature_names': ('sc_w',),
#   'ci_bound': 0.04517785366406842,
#   'std_dev': 0.01050000000000001,
#   'std_err': 0.01050000000000001},
#  16: {'feature_idx': (16,),
#   'cv_scores': array([0.268, 0.266]),
#   'avg_score': 0.267,
#   'feature_names': ('talk_time',),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  17: {'feature_idx': (17,),
#   'cv_scores': array([0.237, 0.249]),
#   'avg_score': 0.243,
#   'feature_names': ('three_g',),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  18: {'feature_idx': (18,),
#   'cv_scores': array([0.256, 0.252]),
#   'avg_score': 0.254,
#   'feature_names': ('touch_screen',),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  19: {'feature_idx': (19,),
#   'cv_scores': array([0.242, 0.239]),
#   'avg_score': 0.2405,
#   'feature_names': ('wifi',),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  20: {'feature_idx': (0, 1),
#   'cv_scores': array([0.306, 0.328]),
#   'avg_score': 0.317,
#   'feature_names': ('battery_power', 'blue'),
#   'ci_bound': 0.047329180029024066,
#   'std_dev': 0.01100000000000001,
#   'std_err': 0.01100000000000001},
#  21: {'feature_idx': (0, 2),
#   'cv_scores': array([0.319, 0.32 ]),
#   'avg_score': 0.3195,
#   'feature_names': ('battery_power', 'clock_speed'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  22: {'feature_idx': (0, 3),
#   'cv_scores': array([0.298, 0.309]),
#   'avg_score': 0.3035,
#   'feature_names': ('battery_power', 'dual_sim'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  23: {'feature_idx': (0, 4),
#   'cv_scores': array([0.268, 0.322]),
#   'avg_score': 0.29500000000000004,
#   'feature_names': ('battery_power', 'fc'),
#   'ci_bound': 0.1161716237076044,
#   'std_dev': 0.026999999999999996,
#   'std_err': 0.026999999999999996},
#  24: {'feature_idx': (0, 5),
#   'cv_scores': array([0.306, 0.319]),
#   'avg_score': 0.3125,
#   'feature_names': ('battery_power', 'four_g'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  25: {'feature_idx': (0, 6),
#   'cv_scores': array([0.322, 0.32 ]),
#   'avg_score': 0.321,
#   'feature_names': ('battery_power', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  26: {'feature_idx': (0, 7),
#   'cv_scores': array([0.309, 0.323]),
#   'avg_score': 0.316,
#   'feature_names': ('battery_power', 'm_dep'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  27: {'feature_idx': (0, 8),
#   'cv_scores': array([0.308, 0.313]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'mobile_wt'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  28: {'feature_idx': (0, 9),
#   'cv_scores': array([0.301, 0.305]),
#   'avg_score': 0.303,
#   'feature_names': ('battery_power', 'n_cores'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  29: {'feature_idx': (0, 10),
#   'cv_scores': array([0.313, 0.308]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'pc'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  30: {'feature_idx': (0, 11),
#   'cv_scores': array([0.316, 0.335]),
#   'avg_score': 0.3255,
#   'feature_names': ('battery_power', 'px_height'),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  31: {'feature_idx': (0, 12),
#   'cv_scores': array([0.342, 0.32 ]),
#   'avg_score': 0.331,
#   'feature_names': ('battery_power', 'px_width'),
#   'ci_bound': 0.047329180029024066,
#   'std_dev': 0.01100000000000001,
#   'std_err': 0.01100000000000001},
#  32: {'feature_idx': (0, 13),
#   'cv_scores': array([0.824, 0.822]),
#   'avg_score': 0.823,
#   'feature_names': ('battery_power', 'ram'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  33: {'feature_idx': (0, 14),
#   'cv_scores': array([0.296, 0.302]),
#   'avg_score': 0.299,
#   'feature_names': ('battery_power', 'sc_h'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  34: {'feature_idx': (0, 15),
#   'cv_scores': array([0.272, 0.313]),
#   'avg_score': 0.2925,
#   'feature_names': ('battery_power', 'sc_w'),
#   'ci_bound': 0.08820438096318109,
#   'std_dev': 0.02049999999999999,
#   'std_err': 0.02049999999999999},
#  35: {'feature_idx': (0, 16),
#   'cv_scores': array([0.33 , 0.322]),
#   'avg_score': 0.326,
#   'feature_names': ('battery_power', 'talk_time'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  36: {'feature_idx': (0, 17),
#   'cv_scores': array([0.309, 0.312]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'three_g'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  37: {'feature_idx': (0, 18),
#   'cv_scores': array([0.312, 0.321]),
#   'avg_score': 0.3165,
#   'feature_names': ('battery_power', 'touch_screen'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  38: {'feature_idx': (0, 19),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('battery_power', 'wifi'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  39: {'feature_idx': (1, 2),
#   'cv_scores': array([0.23 , 0.266]),
#   'avg_score': 0.248,
#   'feature_names': ('blue', 'clock_speed'),
#   'ci_bound': 0.07744774913840295,
#   'std_dev': 0.018000000000000002,
#   'std_err': 0.018000000000000002},
#  40: {'feature_idx': (1, 3),
#   'cv_scores': array([0.24 , 0.258]),
#   'avg_score': 0.249,
#   'feature_names': ('blue', 'dual_sim'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  41: {'feature_idx': (1, 4),
#   'cv_scores': array([0.25, 0.24]),
#   'avg_score': 0.245,
#   'feature_names': ('blue', 'fc'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  42: {'feature_idx': (1, 5),
#   'cv_scores': array([0.236, 0.263]),
#   'avg_score': 0.2495,
#   'feature_names': ('blue', 'four_g'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  43: {'feature_idx': (1, 6),
#   'cv_scores': array([0.264, 0.255]),
#   'avg_score': 0.2595,
#   'feature_names': ('blue', 'int_memory'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  44: {'feature_idx': (1, 7),
#   'cv_scores': array([0.263, 0.262]),
#   'avg_score': 0.2625,
#   'feature_names': ('blue', 'm_dep'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  45: {'feature_idx': (1, 8),
#   'cv_scores': array([0.258, 0.257]),
#   'avg_score': 0.2575,
#   'feature_names': ('blue', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  46: {'feature_idx': (1, 9),
#   'cv_scores': array([0.256, 0.266]),
#   'avg_score': 0.261,
#   'feature_names': ('blue', 'n_cores'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  47: {'feature_idx': (1, 10),
#   'cv_scores': array([0.255, 0.246]),
#   'avg_score': 0.2505,
#   'feature_names': ('blue', 'pc'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  48: {'feature_idx': (1, 11),
#   'cv_scores': array([0.288, 0.297]),
#   'avg_score': 0.2925,
#   'feature_names': ('blue', 'px_height'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  49: {'feature_idx': (1, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('blue', 'px_width'),
#   'ci_bound': 0.10756631824778184,
#   'std_dev': 0.024999999999999994,
#   'std_err': 0.024999999999999994},
#  50: {'feature_idx': (1, 13),
#   'cv_scores': array([0.761, 0.748]),
#   'avg_score': 0.7545,
#   'feature_names': ('blue', 'ram'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  51: {'feature_idx': (1, 14),
#   'cv_scores': array([0.26 , 0.263]),
#   'avg_score': 0.2615,
#   'feature_names': ('blue', 'sc_h'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  52: {'feature_idx': (1, 15),
#   'cv_scores': array([0.261, 0.241]),
#   'avg_score': 0.251,
#   'feature_names': ('blue', 'sc_w'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  53: {'feature_idx': (1, 16),
#   'cv_scores': array([0.264, 0.253]),
#   'avg_score': 0.2585,
#   'feature_names': ('blue', 'talk_time'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  54: {'feature_idx': (1, 17),
#   'cv_scores': array([0.226, 0.253]),
#   'avg_score': 0.2395,
#   'feature_names': ('blue', 'three_g'),
#   'ci_bound': 0.0580858118538022,
#   'std_dev': 0.013499999999999998,
#   'std_err': 0.013499999999999998},
#  55: {'feature_idx': (1, 18),
#   'cv_scores': array([0.253, 0.261]),
#   'avg_score': 0.257,
#   'feature_names': ('blue', 'touch_screen'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  56: {'feature_idx': (1, 19),
#   'cv_scores': array([0.241, 0.25 ]),
#   'avg_score': 0.2455,
#   'feature_names': ('blue', 'wifi'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  57: {'feature_idx': (2, 3),
#   'cv_scores': array([0.24 , 0.267]),
#   'avg_score': 0.2535,
#   'feature_names': ('clock_speed', 'dual_sim'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  58: {'feature_idx': (2, 4),
#   'cv_scores': array([0.257, 0.256]),
#   'avg_score': 0.2565,
#   'feature_names': ('clock_speed', 'fc'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  59: {'feature_idx': (2, 5),
#   'cv_scores': array([0.248, 0.258]),
#   'avg_score': 0.253,
#   'feature_names': ('clock_speed', 'four_g'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  60: {'feature_idx': (2, 6),
#   'cv_scores': array([0.271, 0.27 ]),
#   'avg_score': 0.2705,
#   'feature_names': ('clock_speed', 'int_memory'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  61: {'feature_idx': (2, 7),
#   'cv_scores': array([0.239, 0.262]),
#   'avg_score': 0.2505,
#   'feature_names': ('clock_speed', 'm_dep'),
#   'ci_bound': 0.049480506393979704,
#   'std_dev': 0.01150000000000001,
#   'std_err': 0.01150000000000001},
#  62: {'feature_idx': (2, 8),
#   'cv_scores': array([0.245, 0.246]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  63: {'feature_idx': (2, 9),
#   'cv_scores': array([0.258, 0.265]),
#   'avg_score': 0.2615,
#   'feature_names': ('clock_speed', 'n_cores'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  64: {'feature_idx': (2, 10),
#   'cv_scores': array([0.239, 0.252]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'pc'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  65: {'feature_idx': (2, 11),
#   'cv_scores': array([0.291, 0.301]),
#   'avg_score': 0.296,
#   'feature_names': ('clock_speed', 'px_height'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  66: {'feature_idx': (2, 12),
#   'cv_scores': array([0.294, 0.303]),
#   'avg_score': 0.2985,
#   'feature_names': ('clock_speed', 'px_width'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  67: {'feature_idx': (2, 13),
#   'cv_scores': array([0.751, 0.743]),
#   'avg_score': 0.747,
#   'feature_names': ('clock_speed', 'ram'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  68: {'feature_idx': (2, 14),
#   'cv_scores': array([0.255, 0.25 ]),
#   'avg_score': 0.2525,
#   'feature_names': ('clock_speed', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  69: {'feature_idx': (2, 15),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('clock_speed', 'sc_w'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  70: {'feature_idx': (2, 16),
#   'cv_scores': array([0.272, 0.247]),
#   'avg_score': 0.2595,
#   'feature_names': ('clock_speed', 'talk_time'),
#   'ci_bound': 0.05378315912389098,
#   'std_dev': 0.012500000000000011,
#   'std_err': 0.012500000000000011},
#  71: {'feature_idx': (2, 17),
#   'cv_scores': array([0.221, 0.253]),
#   'avg_score': 0.237,
#   'feature_names': ('clock_speed', 'three_g'),
#   'ci_bound': 0.06884244367858039,
#   'std_dev': 0.016,
#   'std_err': 0.016},
#  72: {'feature_idx': (2, 18),
#   'cv_scores': array([0.256, 0.255]),
#   'avg_score': 0.2555,
#   'feature_names': ('clock_speed', 'touch_screen'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  73: {'feature_idx': (2, 19),
#   'cv_scores': array([0.242, 0.241]),
#   'avg_score': 0.2415,
#   'feature_names': ('clock_speed', 'wifi'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  74: {'feature_idx': (3, 4),
#   'cv_scores': array([0.253, 0.243]),
#   'avg_score': 0.248,
#   'feature_names': ('dual_sim', 'fc'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  75: {'feature_idx': (3, 5),
#   'cv_scores': array([0.228, 0.245]),
#   'avg_score': 0.2365,
#   'feature_names': ('dual_sim', 'four_g'),
#   'ci_bound': 0.0365725482042458,
#   'std_dev': 0.008499999999999994,
#   'std_err': 0.008499999999999992},
#  76: {'feature_idx': (3, 6),
#   'cv_scores': array([0.255, 0.251]),
#   'avg_score': 0.253,
#   'feature_names': ('dual_sim', 'int_memory'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  77: {'feature_idx': (3, 7),
#   'cv_scores': array([0.24 , 0.242]),
#   'avg_score': 0.241,
#   'feature_names': ('dual_sim', 'm_dep'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  78: {'feature_idx': (3, 8),
#   'cv_scores': array([0.254, 0.255]),
#   'avg_score': 0.2545,
#   'feature_names': ('dual_sim', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  79: {'feature_idx': (3, 9),
#   'cv_scores': array([0.263, 0.265]),
#   'avg_score': 0.264,
#   'feature_names': ('dual_sim', 'n_cores'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  80: {'feature_idx': (3, 10),
#   'cv_scores': array([0.247, 0.241]),
#   'avg_score': 0.244,
#   'feature_names': ('dual_sim', 'pc'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  81: {'feature_idx': (3, 11),
#   'cv_scores': array([0.29 , 0.307]),
#   'avg_score': 0.2985,
#   'feature_names': ('dual_sim', 'px_height'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  82: {'feature_idx': (3, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('dual_sim', 'px_width'),
#   'ci_bound': 0.10756631824778184,
#   'std_dev': 0.024999999999999994,
#   'std_err': 0.024999999999999994},
#  83: {'feature_idx': (3, 13),
#   'cv_scores': array([0.752, 0.75 ]),
#   'avg_score': 0.751,
#   'feature_names': ('dual_sim', 'ram'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  84: {'feature_idx': (3, 14),
#   'cv_scores': array([0.242, 0.259]),
#   'avg_score': 0.2505,
#   'feature_names': ('dual_sim', 'sc_h'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  85: {'feature_idx': (3, 15),
#   'cv_scores': array([0.26 , 0.242]),
#   'avg_score': 0.251,
#   'feature_names': ('dual_sim', 'sc_w'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  86: {'feature_idx': (3, 16),
#   'cv_scores': array([0.251, 0.253]),
#   'avg_score': 0.252,
#   'feature_names': ('dual_sim', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  87: {'feature_idx': (3, 17),
#   'cv_scores': array([0.245, 0.244]),
#   'avg_score': 0.2445,
#   'feature_names': ('dual_sim', 'three_g'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  88: {'feature_idx': (3, 18),
#   'cv_scores': array([0.259, 0.246]),
#   'avg_score': 0.2525,
#   'feature_names': ('dual_sim', 'touch_screen'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  89: {'feature_idx': (3, 19),
#   'cv_scores': array([0.246, 0.239]),
#   'avg_score': 0.2425,
#   'feature_names': ('dual_sim', 'wifi'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  90: {'feature_idx': (4, 5),
#   'cv_scores': array([0.254, 0.24 ]),
#   'avg_score': 0.247,
#   'feature_names': ('fc', 'four_g'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  91: {'feature_idx': (4, 6),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('fc', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  92: {'feature_idx': (4, 7),
#   'cv_scores': array([0.255, 0.237]),
#   'avg_score': 0.246,
#   'feature_names': ('fc', 'm_dep'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  93: {'feature_idx': (4, 8),
#   'cv_scores': array([0.25 , 0.269]),
#   'avg_score': 0.2595,
#   'feature_names': ('fc', 'mobile_wt'),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  94: {'feature_idx': (4, 9),
#   'cv_scores': array([0.267, 0.26 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('fc', 'n_cores'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  95: {'feature_idx': (4, 10),
#   'cv_scores': array([0.268, 0.255]),
#   'avg_score': 0.2615,
#   'feature_names': ('fc', 'pc'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  96: {'feature_idx': (4, 11),
#   'cv_scores': array([0.3  , 0.303]),
#   'avg_score': 0.3015,
#   'feature_names': ('fc', 'px_height'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  97: {'feature_idx': (4, 12),
#   'cv_scores': array([0.298, 0.304]),
#   'avg_score': 0.301,
#   'feature_names': ('fc', 'px_width'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  98: {'feature_idx': (4, 13),
#   'cv_scores': array([0.749, 0.749]),
#   'avg_score': 0.749,
#   'feature_names': ('fc', 'ram'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  99: {'feature_idx': (4, 14),
#   'cv_scores': array([0.26 , 0.255]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  100: {'feature_idx': (4, 15),
#   'cv_scores': array([0.257, 0.269]),
#   'avg_score': 0.263,
#   'feature_names': ('fc', 'sc_w'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  101: {'feature_idx': (4, 16),
#   'cv_scores': array([0.258, 0.253]),
#   'avg_score': 0.2555,
#   'feature_names': ('fc', 'talk_time'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  102: {'feature_idx': (4, 17),
#   'cv_scores': array([0.26 , 0.243]),
#   'avg_score': 0.2515,
#   'feature_names': ('fc', 'three_g'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  103: {'feature_idx': (4, 18),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  104: {'feature_idx': (4, 19),
#   'cv_scores': array([0.254, 0.236]),
#   'avg_score': 0.245,
#   'feature_names': ('fc', 'wifi'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  105: {'feature_idx': (5, 6),
#   'cv_scores': array([0.27 , 0.272]),
#   'avg_score': 0.271,
#   'feature_names': ('four_g', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  106: {'feature_idx': (5, 7),
#   'cv_scores': array([0.244, 0.265]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'm_dep'),
#   'ci_bound': 0.04517785366406842,
#   'std_dev': 0.01050000000000001,
#   'std_err': 0.01050000000000001},
#  107: {'feature_idx': (5, 8),
#   'cv_scores': array([0.249, 0.26 ]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'mobile_wt'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  108: {'feature_idx': (5, 9),
#   'cv_scores': array([0.261, 0.245]),
#   'avg_score': 0.253,
#   'feature_names': ('four_g', 'n_cores'),
#   'ci_bound': 0.03442122183929023,
#   'std_dev': 0.008000000000000007,
#   'std_err': 0.008000000000000007},
#  109: {'feature_idx': (5, 10),
#   'cv_scores': array([0.257, 0.255]),
#   'avg_score': 0.256,
#   'feature_names': ('four_g', 'pc'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  110: {'feature_idx': (5, 11),
#   'cv_scores': array([0.291, 0.3  ]),
#   'avg_score': 0.2955,
#   'feature_names': ('four_g', 'px_height'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  111: {'feature_idx': (5, 12),
#   'cv_scores': array([0.291, 0.292]),
#   'avg_score': 0.2915,
#   'feature_names': ('four_g', 'px_width'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  112: {'feature_idx': (5, 13),
#   'cv_scores': array([0.754, 0.753]),
#   'avg_score': 0.7535000000000001,
#   'feature_names': ('four_g', 'ram'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  113: {'feature_idx': (5, 14),
#   'cv_scores': array([0.247, 0.264]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g', 'sc_h'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  114: {'feature_idx': (5, 15),
#   'cv_scores': array([0.266, 0.252]),
#   'avg_score': 0.259,
#   'feature_names': ('four_g', 'sc_w'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  115: {'feature_idx': (5, 16),
#   'cv_scores': array([0.259, 0.239]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  116: {'feature_idx': (5, 17),
#   'cv_scores': array([0.236, 0.259]),
#   'avg_score': 0.2475,
#   'feature_names': ('four_g', 'three_g'),
#   'ci_bound': 0.049480506393979704,
#   'std_dev': 0.01150000000000001,
#   'std_err': 0.01150000000000001},
#  117: {'feature_idx': (5, 18),
#   'cv_scores': array([0.246, 0.252]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  118: {'feature_idx': (5, 19),
#   'cv_scores': array([0.26 , 0.253]),
#   'avg_score': 0.2565,
#   'feature_names': ('four_g', 'wifi'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  119: {'feature_idx': (6, 7),
#   'cv_scores': array([0.274, 0.26 ]),
#   'avg_score': 0.267,
#   'feature_names': ('int_memory', 'm_dep'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  120: {'feature_idx': (6, 8),
#   'cv_scores': array([0.268, 0.256]),
#   'avg_score': 0.262,
#   'feature_names': ('int_memory', 'mobile_wt'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  121: {'feature_idx': (6, 9),
#   'cv_scores': array([0.28 , 0.272]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'n_cores'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  122: {'feature_idx': (6, 10),
#   'cv_scores': array([0.282, 0.278]),
#   'avg_score': 0.28,
#   'feature_names': ('int_memory', 'pc'),
#   'ci_bound': 0.008605305459822436,
#   'std_dev': 0.001999999999999974,
#   'std_err': 0.0019999999999999736},
#  123: {'feature_idx': (6, 11),
#   'cv_scores': array([0.289, 0.302]),
#   'avg_score': 0.2955,
#   'feature_names': ('int_memory', 'px_height'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  124: {'feature_idx': (6, 12),
#   'cv_scores': array([0.299, 0.302]),
#   'avg_score': 0.3005,
#   'feature_names': ('int_memory', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  125: {'feature_idx': (6, 13),
#   'cv_scores': array([0.758, 0.745]),
#   'avg_score': 0.7515000000000001,
#   'feature_names': ('int_memory', 'ram'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  126: {'feature_idx': (6, 14),
#   'cv_scores': array([0.252, 0.268]),
#   'avg_score': 0.26,
#   'feature_names': ('int_memory', 'sc_h'),
#   'ci_bound': 0.03442122183929023,
#   'std_dev': 0.008000000000000007,
#   'std_err': 0.008000000000000007},
#  127: {'feature_idx': (6, 15),
#   'cv_scores': array([0.273, 0.267]),
#   'avg_score': 0.27,
#   'feature_names': ('int_memory', 'sc_w'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  128: {'feature_idx': (6, 16),
#   'cv_scores': array([0.282, 0.267]),
#   'avg_score': 0.27449999999999997,
#   'feature_names': ('int_memory', 'talk_time'),
#   'ci_bound': 0.03226989547433447,
#   'std_dev': 0.007499999999999979,
#   'std_err': 0.007499999999999979},
#  129: {'feature_idx': (6, 17),
#   'cv_scores': array([0.269, 0.26 ]),
#   'avg_score': 0.2645,
#   'feature_names': ('int_memory', 'three_g'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  130: {'feature_idx': (6, 18),
#   'cv_scores': array([0.277, 0.275]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'touch_screen'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  131: {'feature_idx': (6, 19),
#   'cv_scores': array([0.255, 0.257]),
#   'avg_score': 0.256,
#   'feature_names': ('int_memory', 'wifi'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  132: {'feature_idx': (7, 8),
#   'cv_scores': array([0.254, 0.262]),
#   'avg_score': 0.258,
#   'feature_names': ('m_dep', 'mobile_wt'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  133: {'feature_idx': (7, 9),
#   'cv_scores': array([0.255, 0.273]),
#   'avg_score': 0.264,
#   'feature_names': ('m_dep', 'n_cores'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  134: {'feature_idx': (7, 10),
#   'cv_scores': array([0.25 , 0.258]),
#   'avg_score': 0.254,
#   'feature_names': ('m_dep', 'pc'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  135: {'feature_idx': (7, 11),
#   'cv_scores': array([0.301, 0.301]),
#   'avg_score': 0.301,
#   'feature_names': ('m_dep', 'px_height'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  136: {'feature_idx': (7, 12),
#   'cv_scores': array([0.298, 0.25 ]),
#   'avg_score': 0.274,
#   'feature_names': ('m_dep', 'px_width'),
#   'ci_bound': 0.10326366551787057,
#   'std_dev': 0.023999999999999994,
#   'std_err': 0.023999999999999994},
#  137: {'feature_idx': (7, 13),
#   'cv_scores': array([0.765, 0.748]),
#   'avg_score': 0.7565,
#   'feature_names': ('m_dep', 'ram'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  138: {'feature_idx': (7, 14),
#   'cv_scores': array([0.251, 0.264]),
#   'avg_score': 0.2575,
#   'feature_names': ('m_dep', 'sc_h'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  139: {'feature_idx': (7, 15),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('m_dep', 'sc_w'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  140: {'feature_idx': (7, 16),
#   'cv_scores': array([0.271, 0.276]),
#   'avg_score': 0.2735,
#   'feature_names': ('m_dep', 'talk_time'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  141: {'feature_idx': (7, 17),
#   'cv_scores': array([0.248, 0.253]),
#   'avg_score': 0.2505,
#   'feature_names': ('m_dep', 'three_g'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  142: {'feature_idx': (7, 18),
#   'cv_scores': array([0.249, 0.243]),
#   'avg_score': 0.246,
#   'feature_names': ('m_dep', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  143: {'feature_idx': (7, 19),
#   'cv_scores': array([0.254, 0.248]),
#   'avg_score': 0.251,
#   'feature_names': ('m_dep', 'wifi'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  144: {'feature_idx': (8, 9),
#   'cv_scores': array([0.276, 0.281]),
#   'avg_score': 0.2785,
#   'feature_names': ('mobile_wt', 'n_cores'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  145: {'feature_idx': (8, 10),
#   'cv_scores': array([0.289, 0.27 ]),
#   'avg_score': 0.27949999999999997,
#   'feature_names': ('mobile_wt', 'pc'),
#   'ci_bound': 0.04087520093415702,
#   'std_dev': 0.00949999999999998,
#   'std_err': 0.00949999999999998},
#  146: {'feature_idx': (8, 11),
#   'cv_scores': array([0.296, 0.285]),
#   'avg_score': 0.2905,
#   'feature_names': ('mobile_wt', 'px_height'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  147: {'feature_idx': (8, 12),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('mobile_wt', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  148: {'feature_idx': (8, 13),
#   'cv_scores': array([0.756, 0.746]),
#   'avg_score': 0.751,
#   'feature_names': ('mobile_wt', 'ram'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  149: {'feature_idx': (8, 14),
#   'cv_scores': array([0.253, 0.252]),
#   'avg_score': 0.2525,
#   'feature_names': ('mobile_wt', 'sc_h'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  150: {'feature_idx': (8, 15),
#   'cv_scores': array([0.263, 0.269]),
#   'avg_score': 0.266,
#   'feature_names': ('mobile_wt', 'sc_w'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  151: {'feature_idx': (8, 16),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('mobile_wt', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  152: {'feature_idx': (8, 17),
#   'cv_scores': array([0.261, 0.266]),
#   'avg_score': 0.2635,
#   'feature_names': ('mobile_wt', 'three_g'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  153: {'feature_idx': (8, 18),
#   'cv_scores': array([0.288, 0.263]),
#   'avg_score': 0.27549999999999997,
#   'feature_names': ('mobile_wt', 'touch_screen'),
#   'ci_bound': 0.05378315912389085,
#   'std_dev': 0.012499999999999983,
#   'std_err': 0.012499999999999982},
#  154: {'feature_idx': (8, 19),
#   'cv_scores': array([0.252, 0.27 ]),
#   'avg_score': 0.261,
#   'feature_names': ('mobile_wt', 'wifi'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  155: {'feature_idx': (9, 10),
#   'cv_scores': array([0.27 , 0.253]),
#   'avg_score': 0.2615,
#   'feature_names': ('n_cores', 'pc'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  156: {'feature_idx': (9, 11),
#   'cv_scores': array([0.29 , 0.291]),
#   'avg_score': 0.2905,
#   'feature_names': ('n_cores', 'px_height'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  157: {'feature_idx': (9, 12),
#   'cv_scores': array([0.276, 0.273]),
#   'avg_score': 0.2745,
#   'feature_names': ('n_cores', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  158: {'feature_idx': (9, 13),
#   'cv_scores': array([0.764, 0.754]),
#   'avg_score': 0.759,
#   'feature_names': ('n_cores', 'ram'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  159: {'feature_idx': (9, 14),
#   'cv_scores': array([0.264, 0.266]),
#   'avg_score': 0.265,
#   'feature_names': ('n_cores', 'sc_h'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  160: {'feature_idx': (9, 15),
#   'cv_scores': array([0.277, 0.274]),
#   'avg_score': 0.2755,
#   'feature_names': ('n_cores', 'sc_w'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  161: {'feature_idx': (9, 16),
#   'cv_scores': array([0.275, 0.277]),
#   'avg_score': 0.276,
#   'feature_names': ('n_cores', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  162: {'feature_idx': (9, 17),
#   'cv_scores': array([0.265, 0.235]),
#   'avg_score': 0.25,
#   'feature_names': ('n_cores', 'three_g'),
#   'ci_bound': 0.06453979094866917,
#   'std_dev': 0.015000000000000013,
#   'std_err': 0.015000000000000012},
#  163: {'feature_idx': (9, 18),
#   'cv_scores': array([0.27 , 0.258]),
#   'avg_score': 0.264,
#   'feature_names': ('n_cores', 'touch_screen'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  164: {'feature_idx': (9, 19),
#   'cv_scores': array([0.253, 0.254]),
#   'avg_score': 0.2535,
#   'feature_names': ('n_cores', 'wifi'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  165: {'feature_idx': (10, 11),
#   'cv_scores': array([0.291, 0.296]),
#   'avg_score': 0.2935,
#   'feature_names': ('pc', 'px_height'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  166: {'feature_idx': (10, 12),
#   'cv_scores': array([0.298, 0.308]),
#   'avg_score': 0.303,
#   'feature_names': ('pc', 'px_width'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  167: {'feature_idx': (10, 13),
#   'cv_scores': array([0.761, 0.752]),
#   'avg_score': 0.7565,
#   'feature_names': ('pc', 'ram'),
#   'ci_bound': 0.019361937284600752,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000004},
#  168: {'feature_idx': (10, 14),
#   'cv_scores': array([0.267, 0.262]),
#   'avg_score': 0.2645,
#   'feature_names': ('pc', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  169: {'feature_idx': (10, 15),
#   'cv_scores': array([0.281, 0.263]),
#   'avg_score': 0.272,
#   'feature_names': ('pc', 'sc_w'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  170: {'feature_idx': (10, 16),
#   'cv_scores': array([0.269, 0.273]),
#   'avg_score': 0.271,
#   'feature_names': ('pc', 'talk_time'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  171: {'feature_idx': (10, 17),
#   'cv_scores': array([0.259, 0.247]),
#   'avg_score': 0.253,
#   'feature_names': ('pc', 'three_g'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  172: {'feature_idx': (10, 18),
#   'cv_scores': array([0.256, 0.269]),
#   'avg_score': 0.2625,
#   'feature_names': ('pc', 'touch_screen'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  173: {'feature_idx': (10, 19),
#   'cv_scores': array([0.252, 0.248]),
#   'avg_score': 0.25,
#   'feature_names': ('pc', 'wifi'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  174: {'feature_idx': (11, 12),
#   'cv_scores': array([0.295, 0.325]),
#   'avg_score': 0.31,
#   'feature_names': ('px_height', 'px_width'),
#   'ci_bound': 0.06453979094866917,
#   'std_dev': 0.015000000000000013,
#   'std_err': 0.015000000000000012},
#  175: {'feature_idx': (11, 13),
#   'cv_scores': array([0.787, 0.804]),
#   'avg_score': 0.7955000000000001,
#   'feature_names': ('px_height', 'ram'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  176: {'feature_idx': (11, 14),
#   'cv_scores': array([0.293, 0.281]),
#   'avg_score': 0.28700000000000003,
#   'feature_names': ('px_height', 'sc_h'),
#   'ci_bound': 0.02581591637946755,
#   'std_dev': 0.005999999999999978,
#   'std_err': 0.005999999999999977},
#  177: {'feature_idx': (11, 15),
#   'cv_scores': array([0.295, 0.294]),
#   'avg_score': 0.2945,
#   'feature_names': ('px_height', 'sc_w'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  178: {'feature_idx': (11, 16),
#   'cv_scores': array([0.281, 0.307]),
#   'avg_score': 0.29400000000000004,
#   'feature_names': ('px_height', 'talk_time'),
#   'ci_bound': 0.05593448548884649,
#   'std_dev': 0.012999999999999984,
#   'std_err': 0.012999999999999982},
#  179: {'feature_idx': (11, 17),
#   'cv_scores': array([0.276, 0.293]),
#   'avg_score': 0.2845,
#   'feature_names': ('px_height', 'three_g'),
#   'ci_bound': 0.03657254820424575,
#   'std_dev': 0.00849999999999998,
#   'std_err': 0.00849999999999998},
#  180: {'feature_idx': (11, 18),
#   'cv_scores': array([0.29, 0.29]),
#   'avg_score': 0.29,
#   'feature_names': ('px_height', 'touch_screen'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  181: {'feature_idx': (11, 19),
#   'cv_scores': array([0.292, 0.294]),
#   'avg_score': 0.293,
#   'feature_names': ('px_height', 'wifi'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  182: {'feature_idx': (12, 13),
#   'cv_scores': array([0.777, 0.785]),
#   'avg_score': 0.781,
#   'feature_names': ('px_width', 'ram'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  183: {'feature_idx': (12, 14),
#   'cv_scores': array([0.294, 0.29 ]),
#   'avg_score': 0.292,
#   'feature_names': ('px_width', 'sc_h'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  184: {'feature_idx': (12, 15),
#   'cv_scores': array([0.305, 0.297]),
#   'avg_score': 0.301,
#   'feature_names': ('px_width', 'sc_w'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  185: {'feature_idx': (12, 16),
#   'cv_scores': array([0.307, 0.287]),
#   'avg_score': 0.297,
#   'feature_names': ('px_width', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  186: {'feature_idx': (12, 17),
#   'cv_scores': array([0.281, 0.25 ]),
#   'avg_score': 0.2655,
#   'feature_names': ('px_width', 'three_g'),
#   'ci_bound': 0.06669111731362481,
#   'std_dev': 0.015500000000000014,
#   'std_err': 0.015500000000000012},
#  187: {'feature_idx': (12, 18),
#   'cv_scores': array([0.299, 0.293]),
#   'avg_score': 0.296,
#   'feature_names': ('px_width', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  188: {'feature_idx': (12, 19),
#   'cv_scores': array([0.277, 0.25 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('px_width', 'wifi'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  189: {'feature_idx': (13, 14),
#   'cv_scores': array([0.758, 0.748]),
#   'avg_score': 0.753,
#   'feature_names': ('ram', 'sc_h'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  190: {'feature_idx': (13, 15),
#   'cv_scores': array([0.76 , 0.751]),
#   'avg_score': 0.7555000000000001,
#   'feature_names': ('ram', 'sc_w'),
#   'ci_bound': 0.019361937284600752,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000004},
#  191: {'feature_idx': (13, 16),
#   'cv_scores': array([0.768, 0.748]),
#   'avg_score': 0.758,
#   'feature_names': ('ram', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  192: {'feature_idx': (13, 17),
#   'cv_scores': array([0.762, 0.752]),
#   'avg_score': 0.757,
#   'feature_names': ('ram', 'three_g'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  193: {'feature_idx': (13, 18),
#   'cv_scores': array([0.753, 0.749]),
#   'avg_score': 0.751,
#   'feature_names': ('ram', 'touch_screen'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  194: {'feature_idx': (13, 19),
#   'cv_scores': array([0.762, 0.748]),
#   'avg_score': 0.755,
#   'feature_names': ('ram', 'wifi'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  195: {'feature_idx': (14, 15),
#   'cv_scores': array([0.259, 0.251]),
#   'avg_score': 0.255,
#   'feature_names': ('sc_h', 'sc_w'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  196: {'feature_idx': (14, 16),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('sc_h', 'talk_time'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  197: {'feature_idx': (14, 17),
#   'cv_scores': array([0.246, 0.248]),
#   'avg_score': 0.247,
#   'feature_names': ('sc_h', 'three_g'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  198: {'feature_idx': (14, 18),
#   'cv_scores': array([0.246, 0.257]),
#   'avg_score': 0.2515,
#   'feature_names': ('sc_h', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  199: {'feature_idx': (14, 19),
#   'cv_scores': array([0.241, 0.255]),
#   'avg_score': 0.248,
#   'feature_names': ('sc_h', 'wifi'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  200: {'feature_idx': (15, 16),
#   'cv_scores': array([0.284, 0.279]),
#   'avg_score': 0.2815,
#   'feature_names': ('sc_w', 'talk_time'),
#   'ci_bound': 0.010756631824778077,
#   'std_dev': 0.0024999999999999745,
#   'std_err': 0.0024999999999999745},
#  201: {'feature_idx': (15, 17),
#   'cv_scores': array([0.258, 0.254]),
#   'avg_score': 0.256,
#   'feature_names': ('sc_w', 'three_g'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  202: {'feature_idx': (15, 18),
#   'cv_scores': array([0.256, 0.267]),
#   'avg_score': 0.2615,
#   'feature_names': ('sc_w', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  203: {'feature_idx': (15, 19),
#   'cv_scores': array([0.233, 0.258]),
#   'avg_score': 0.2455,
#   'feature_names': ('sc_w', 'wifi'),
#   'ci_bound': 0.05378315912389092,
#   'std_dev': 0.012499999999999997,
#   'std_err': 0.012499999999999997},
#  204: {'feature_idx': (16, 17),
#   'cv_scores': array([0.263, 0.248]),
#   'avg_score': 0.2555,
#   'feature_names': ('talk_time', 'three_g'),
#   'ci_bound': 0.032269895474334585,
#   'std_dev': 0.007500000000000007,
#   'std_err': 0.007500000000000006},
#  205: {'feature_idx': (16, 18),
#   'cv_scores': array([0.269, 0.277]),
#   'avg_score': 0.273,
#   'feature_names': ('talk_time', 'touch_screen'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  206: {'feature_idx': (16, 19),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('talk_time', 'wifi'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  207: {'feature_idx': (17, 18),
#   'cv_scores': array([0.256, 0.262]),
#   'avg_score': 0.259,
#   'feature_names': ('three_g', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  208: {'feature_idx': (17, 19),
#   'cv_scores': array([0.242, 0.233]),
#   'avg_score': 0.2375,
#   'feature_names': ('three_g', 'wifi'),
#   'ci_bound': 0.019361937284600693,
#   'std_dev': 0.00449999999999999,
#   'std_err': 0.00449999999999999},
#  209: {'feature_idx': (18, 19),
#   'cv_scores': array([0.248, 0.251]),
#   'avg_score': 0.2495,
#   'feature_names': ('touch_screen', 'wifi'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013}}

# %% [markdown]
# ### Plotting metric_dict

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(50,50))

k_feat = sorted(metric_dict.keys())
avg = [metric_dict[k]['avg_score'] for k in k_feat]

upper, lower = [], []
for k in k_feat:
    upper.append(metric_dict[k]['avg_score'] +
                 metric_dict[k]['std_dev'])
    lower.append(metric_dict[k]['avg_score'] -
                 metric_dict[k]['std_dev'])

plt.fill_between(k_feat,
                 upper,
                 lower,
                 alpha=0.2,
                 color='blue',
                 lw=1)

plt.plot(k_feat, avg, color='blue', marker='o')
plt.ylabel('Accuracy +/- Standard Deviation')
plt.xlabel('Number of Features')
feature_min = len(metric_dict[k_feat[0]]['feature_idx'])
feature_max = len(metric_dict[k_feat[-1]]['feature_idx'])
plt.xticks(k_feat, 
           [str(metric_dict[k]['feature_names']) for k in k_feat], 
           rotation=90)
plt.show()

# %% [markdown]
# ## Random Forest Classifier

# %% [markdown]
# ### Import RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Build the Random Forest model

# %%
rf = RandomForestClassifier()

# %% [markdown]
# ### Build the Exhaustive Feature Selector with Random Forest as the Learning Algorithm

# %%
efs_rf = ExhaustiveFeatureSelector(rf, 
                                min_features=1, 
                                max_features=2, 
                                scoring='accuracy', 
                                print_progress=True, 
                                cv=2
)

# %% [markdown]
# ### Train the model

# %%
efs_rf = efs_rf.fit(X, y)
# Out:
# Features: 210/210

# %% [markdown]
# ### Best features

# %%
efs_rf.best_feature_names_
# Out:
# ('battery_power', 'ram')

# %% [markdown]
# ### Best Score

# %%
efs_rf.best_score_
# Out:
# 0.8045

# %% [markdown]
# ### Collect all Metric dict with all the feature subsets

# %%
metric_dict = efs_lr.get_metric_dict()
metric_dict
# Out:
# {0: {'feature_idx': (0,),
#   'cv_scores': array([0.25 , 0.317]),
#   'avg_score': 0.2835,
#   'feature_names': ('battery_power',),
#   'ci_bound': 0.14413886645202767,
#   'std_dev': 0.0335,
#   'std_err': 0.033499999999999995},
#  1: {'feature_idx': (1,),
#   'cv_scores': array([0.243, 0.249]),
#   'avg_score': 0.246,
#   'feature_names': ('blue',),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  2: {'feature_idx': (2,),
#   'cv_scores': array([0.229, 0.243]),
#   'avg_score': 0.236,
#   'feature_names': ('clock_speed',),
#   'ci_bound': 0.030118569109378886,
#   'std_dev': 0.006999999999999992,
#   'std_err': 0.0069999999999999915},
#  3: {'feature_idx': (3,),
#   'cv_scores': array([0.24 , 0.246]),
#   'avg_score': 0.243,
#   'feature_names': ('dual_sim',),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  4: {'feature_idx': (4,),
#   'cv_scores': array([0.259, 0.24 ]),
#   'avg_score': 0.2495,
#   'feature_names': ('fc',),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  5: {'feature_idx': (5,),
#   'cv_scores': array([0.251, 0.26 ]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g',),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  6: {'feature_idx': (6,),
#   'cv_scores': array([0.272, 0.271]),
#   'avg_score': 0.2715,
#   'feature_names': ('int_memory',),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  7: {'feature_idx': (7,),
#   'cv_scores': array([0.246, 0.26 ]),
#   'avg_score': 0.253,
#   'feature_names': ('m_dep',),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  8: {'feature_idx': (8,),
#   'cv_scores': array([0.263, 0.273]),
#   'avg_score': 0.268,
#   'feature_names': ('mobile_wt',),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  9: {'feature_idx': (9,),
#   'cv_scores': array([0.266, 0.276]),
#   'avg_score': 0.271,
#   'feature_names': ('n_cores',),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  10: {'feature_idx': (10,),
#   'cv_scores': array([0.254, 0.269]),
#   'avg_score': 0.2615,
#   'feature_names': ('pc',),
#   'ci_bound': 0.032269895474334585,
#   'std_dev': 0.007500000000000007,
#   'std_err': 0.007500000000000006},
#  11: {'feature_idx': (11,),
#   'cv_scores': array([0.297, 0.304]),
#   'avg_score': 0.3005,
#   'feature_names': ('px_height',),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  12: {'feature_idx': (12,),
#   'cv_scores': array([0.25, 0.25]),
#   'avg_score': 0.25,
#   'feature_names': ('px_width',),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  13: {'feature_idx': (13,),
#   'cv_scores': array([0.749, 0.752]),
#   'avg_score': 0.7505,
#   'feature_names': ('ram',),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  14: {'feature_idx': (14,),
#   'cv_scores': array([0.263, 0.27 ]),
#   'avg_score': 0.2665,
#   'feature_names': ('sc_h',),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  15: {'feature_idx': (15,),
#   'cv_scores': array([0.276, 0.255]),
#   'avg_score': 0.2655,
#   'feature_names': ('sc_w',),
#   'ci_bound': 0.04517785366406842,
#   'std_dev': 0.01050000000000001,
#   'std_err': 0.01050000000000001},
#  16: {'feature_idx': (16,),
#   'cv_scores': array([0.268, 0.266]),
#   'avg_score': 0.267,
#   'feature_names': ('talk_time',),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  17: {'feature_idx': (17,),
#   'cv_scores': array([0.237, 0.249]),
#   'avg_score': 0.243,
#   'feature_names': ('three_g',),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  18: {'feature_idx': (18,),
#   'cv_scores': array([0.256, 0.252]),
#   'avg_score': 0.254,
#   'feature_names': ('touch_screen',),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  19: {'feature_idx': (19,),
#   'cv_scores': array([0.242, 0.239]),
#   'avg_score': 0.2405,
#   'feature_names': ('wifi',),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  20: {'feature_idx': (0, 1),
#   'cv_scores': array([0.306, 0.328]),
#   'avg_score': 0.317,
#   'feature_names': ('battery_power', 'blue'),
#   'ci_bound': 0.047329180029024066,
#   'std_dev': 0.01100000000000001,
#   'std_err': 0.01100000000000001},
#  21: {'feature_idx': (0, 2),
#   'cv_scores': array([0.319, 0.32 ]),
#   'avg_score': 0.3195,
#   'feature_names': ('battery_power', 'clock_speed'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  22: {'feature_idx': (0, 3),
#   'cv_scores': array([0.298, 0.309]),
#   'avg_score': 0.3035,
#   'feature_names': ('battery_power', 'dual_sim'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  23: {'feature_idx': (0, 4),
#   'cv_scores': array([0.268, 0.322]),
#   'avg_score': 0.29500000000000004,
#   'feature_names': ('battery_power', 'fc'),
#   'ci_bound': 0.1161716237076044,
#   'std_dev': 0.026999999999999996,
#   'std_err': 0.026999999999999996},
#  24: {'feature_idx': (0, 5),
#   'cv_scores': array([0.306, 0.319]),
#   'avg_score': 0.3125,
#   'feature_names': ('battery_power', 'four_g'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  25: {'feature_idx': (0, 6),
#   'cv_scores': array([0.322, 0.32 ]),
#   'avg_score': 0.321,
#   'feature_names': ('battery_power', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  26: {'feature_idx': (0, 7),
#   'cv_scores': array([0.309, 0.323]),
#   'avg_score': 0.316,
#   'feature_names': ('battery_power', 'm_dep'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  27: {'feature_idx': (0, 8),
#   'cv_scores': array([0.308, 0.313]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'mobile_wt'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  28: {'feature_idx': (0, 9),
#   'cv_scores': array([0.301, 0.305]),
#   'avg_score': 0.303,
#   'feature_names': ('battery_power', 'n_cores'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  29: {'feature_idx': (0, 10),
#   'cv_scores': array([0.313, 0.308]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'pc'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  30: {'feature_idx': (0, 11),
#   'cv_scores': array([0.316, 0.335]),
#   'avg_score': 0.3255,
#   'feature_names': ('battery_power', 'px_height'),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  31: {'feature_idx': (0, 12),
#   'cv_scores': array([0.342, 0.32 ]),
#   'avg_score': 0.331,
#   'feature_names': ('battery_power', 'px_width'),
#   'ci_bound': 0.047329180029024066,
#   'std_dev': 0.01100000000000001,
#   'std_err': 0.01100000000000001},
#  32: {'feature_idx': (0, 13),
#   'cv_scores': array([0.824, 0.822]),
#   'avg_score': 0.823,
#   'feature_names': ('battery_power', 'ram'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  33: {'feature_idx': (0, 14),
#   'cv_scores': array([0.296, 0.302]),
#   'avg_score': 0.299,
#   'feature_names': ('battery_power', 'sc_h'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  34: {'feature_idx': (0, 15),
#   'cv_scores': array([0.272, 0.313]),
#   'avg_score': 0.2925,
#   'feature_names': ('battery_power', 'sc_w'),
#   'ci_bound': 0.08820438096318109,
#   'std_dev': 0.02049999999999999,
#   'std_err': 0.02049999999999999},
#  35: {'feature_idx': (0, 16),
#   'cv_scores': array([0.33 , 0.322]),
#   'avg_score': 0.326,
#   'feature_names': ('battery_power', 'talk_time'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  36: {'feature_idx': (0, 17),
#   'cv_scores': array([0.309, 0.312]),
#   'avg_score': 0.3105,
#   'feature_names': ('battery_power', 'three_g'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  37: {'feature_idx': (0, 18),
#   'cv_scores': array([0.312, 0.321]),
#   'avg_score': 0.3165,
#   'feature_names': ('battery_power', 'touch_screen'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  38: {'feature_idx': (0, 19),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('battery_power', 'wifi'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  39: {'feature_idx': (1, 2),
#   'cv_scores': array([0.23 , 0.266]),
#   'avg_score': 0.248,
#   'feature_names': ('blue', 'clock_speed'),
#   'ci_bound': 0.07744774913840295,
#   'std_dev': 0.018000000000000002,
#   'std_err': 0.018000000000000002},
#  40: {'feature_idx': (1, 3),
#   'cv_scores': array([0.24 , 0.258]),
#   'avg_score': 0.249,
#   'feature_names': ('blue', 'dual_sim'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  41: {'feature_idx': (1, 4),
#   'cv_scores': array([0.25, 0.24]),
#   'avg_score': 0.245,
#   'feature_names': ('blue', 'fc'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  42: {'feature_idx': (1, 5),
#   'cv_scores': array([0.236, 0.263]),
#   'avg_score': 0.2495,
#   'feature_names': ('blue', 'four_g'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  43: {'feature_idx': (1, 6),
#   'cv_scores': array([0.264, 0.255]),
#   'avg_score': 0.2595,
#   'feature_names': ('blue', 'int_memory'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  44: {'feature_idx': (1, 7),
#   'cv_scores': array([0.263, 0.262]),
#   'avg_score': 0.2625,
#   'feature_names': ('blue', 'm_dep'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  45: {'feature_idx': (1, 8),
#   'cv_scores': array([0.258, 0.257]),
#   'avg_score': 0.2575,
#   'feature_names': ('blue', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  46: {'feature_idx': (1, 9),
#   'cv_scores': array([0.256, 0.266]),
#   'avg_score': 0.261,
#   'feature_names': ('blue', 'n_cores'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  47: {'feature_idx': (1, 10),
#   'cv_scores': array([0.255, 0.246]),
#   'avg_score': 0.2505,
#   'feature_names': ('blue', 'pc'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  48: {'feature_idx': (1, 11),
#   'cv_scores': array([0.288, 0.297]),
#   'avg_score': 0.2925,
#   'feature_names': ('blue', 'px_height'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  49: {'feature_idx': (1, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('blue', 'px_width'),
#   'ci_bound': 0.10756631824778184,
#   'std_dev': 0.024999999999999994,
#   'std_err': 0.024999999999999994},
#  50: {'feature_idx': (1, 13),
#   'cv_scores': array([0.761, 0.748]),
#   'avg_score': 0.7545,
#   'feature_names': ('blue', 'ram'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  51: {'feature_idx': (1, 14),
#   'cv_scores': array([0.26 , 0.263]),
#   'avg_score': 0.2615,
#   'feature_names': ('blue', 'sc_h'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  52: {'feature_idx': (1, 15),
#   'cv_scores': array([0.261, 0.241]),
#   'avg_score': 0.251,
#   'feature_names': ('blue', 'sc_w'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  53: {'feature_idx': (1, 16),
#   'cv_scores': array([0.264, 0.253]),
#   'avg_score': 0.2585,
#   'feature_names': ('blue', 'talk_time'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  54: {'feature_idx': (1, 17),
#   'cv_scores': array([0.226, 0.253]),
#   'avg_score': 0.2395,
#   'feature_names': ('blue', 'three_g'),
#   'ci_bound': 0.0580858118538022,
#   'std_dev': 0.013499999999999998,
#   'std_err': 0.013499999999999998},
#  55: {'feature_idx': (1, 18),
#   'cv_scores': array([0.253, 0.261]),
#   'avg_score': 0.257,
#   'feature_names': ('blue', 'touch_screen'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  56: {'feature_idx': (1, 19),
#   'cv_scores': array([0.241, 0.25 ]),
#   'avg_score': 0.2455,
#   'feature_names': ('blue', 'wifi'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  57: {'feature_idx': (2, 3),
#   'cv_scores': array([0.24 , 0.267]),
#   'avg_score': 0.2535,
#   'feature_names': ('clock_speed', 'dual_sim'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  58: {'feature_idx': (2, 4),
#   'cv_scores': array([0.257, 0.256]),
#   'avg_score': 0.2565,
#   'feature_names': ('clock_speed', 'fc'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  59: {'feature_idx': (2, 5),
#   'cv_scores': array([0.248, 0.258]),
#   'avg_score': 0.253,
#   'feature_names': ('clock_speed', 'four_g'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  60: {'feature_idx': (2, 6),
#   'cv_scores': array([0.271, 0.27 ]),
#   'avg_score': 0.2705,
#   'feature_names': ('clock_speed', 'int_memory'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  61: {'feature_idx': (2, 7),
#   'cv_scores': array([0.239, 0.262]),
#   'avg_score': 0.2505,
#   'feature_names': ('clock_speed', 'm_dep'),
#   'ci_bound': 0.049480506393979704,
#   'std_dev': 0.01150000000000001,
#   'std_err': 0.01150000000000001},
#  62: {'feature_idx': (2, 8),
#   'cv_scores': array([0.245, 0.246]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  63: {'feature_idx': (2, 9),
#   'cv_scores': array([0.258, 0.265]),
#   'avg_score': 0.2615,
#   'feature_names': ('clock_speed', 'n_cores'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  64: {'feature_idx': (2, 10),
#   'cv_scores': array([0.239, 0.252]),
#   'avg_score': 0.2455,
#   'feature_names': ('clock_speed', 'pc'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  65: {'feature_idx': (2, 11),
#   'cv_scores': array([0.291, 0.301]),
#   'avg_score': 0.296,
#   'feature_names': ('clock_speed', 'px_height'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  66: {'feature_idx': (2, 12),
#   'cv_scores': array([0.294, 0.303]),
#   'avg_score': 0.2985,
#   'feature_names': ('clock_speed', 'px_width'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  67: {'feature_idx': (2, 13),
#   'cv_scores': array([0.751, 0.743]),
#   'avg_score': 0.747,
#   'feature_names': ('clock_speed', 'ram'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  68: {'feature_idx': (2, 14),
#   'cv_scores': array([0.255, 0.25 ]),
#   'avg_score': 0.2525,
#   'feature_names': ('clock_speed', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  69: {'feature_idx': (2, 15),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('clock_speed', 'sc_w'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  70: {'feature_idx': (2, 16),
#   'cv_scores': array([0.272, 0.247]),
#   'avg_score': 0.2595,
#   'feature_names': ('clock_speed', 'talk_time'),
#   'ci_bound': 0.05378315912389098,
#   'std_dev': 0.012500000000000011,
#   'std_err': 0.012500000000000011},
#  71: {'feature_idx': (2, 17),
#   'cv_scores': array([0.221, 0.253]),
#   'avg_score': 0.237,
#   'feature_names': ('clock_speed', 'three_g'),
#   'ci_bound': 0.06884244367858039,
#   'std_dev': 0.016,
#   'std_err': 0.016},
#  72: {'feature_idx': (2, 18),
#   'cv_scores': array([0.256, 0.255]),
#   'avg_score': 0.2555,
#   'feature_names': ('clock_speed', 'touch_screen'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  73: {'feature_idx': (2, 19),
#   'cv_scores': array([0.242, 0.241]),
#   'avg_score': 0.2415,
#   'feature_names': ('clock_speed', 'wifi'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  74: {'feature_idx': (3, 4),
#   'cv_scores': array([0.253, 0.243]),
#   'avg_score': 0.248,
#   'feature_names': ('dual_sim', 'fc'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  75: {'feature_idx': (3, 5),
#   'cv_scores': array([0.228, 0.245]),
#   'avg_score': 0.2365,
#   'feature_names': ('dual_sim', 'four_g'),
#   'ci_bound': 0.0365725482042458,
#   'std_dev': 0.008499999999999994,
#   'std_err': 0.008499999999999992},
#  76: {'feature_idx': (3, 6),
#   'cv_scores': array([0.255, 0.251]),
#   'avg_score': 0.253,
#   'feature_names': ('dual_sim', 'int_memory'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  77: {'feature_idx': (3, 7),
#   'cv_scores': array([0.24 , 0.242]),
#   'avg_score': 0.241,
#   'feature_names': ('dual_sim', 'm_dep'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  78: {'feature_idx': (3, 8),
#   'cv_scores': array([0.254, 0.255]),
#   'avg_score': 0.2545,
#   'feature_names': ('dual_sim', 'mobile_wt'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  79: {'feature_idx': (3, 9),
#   'cv_scores': array([0.263, 0.265]),
#   'avg_score': 0.264,
#   'feature_names': ('dual_sim', 'n_cores'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  80: {'feature_idx': (3, 10),
#   'cv_scores': array([0.247, 0.241]),
#   'avg_score': 0.244,
#   'feature_names': ('dual_sim', 'pc'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  81: {'feature_idx': (3, 11),
#   'cv_scores': array([0.29 , 0.307]),
#   'avg_score': 0.2985,
#   'feature_names': ('dual_sim', 'px_height'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  82: {'feature_idx': (3, 12),
#   'cv_scores': array([0.3 , 0.25]),
#   'avg_score': 0.275,
#   'feature_names': ('dual_sim', 'px_width'),
#   'ci_bound': 0.10756631824778184,
#   'std_dev': 0.024999999999999994,
#   'std_err': 0.024999999999999994},
#  83: {'feature_idx': (3, 13),
#   'cv_scores': array([0.752, 0.75 ]),
#   'avg_score': 0.751,
#   'feature_names': ('dual_sim', 'ram'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  84: {'feature_idx': (3, 14),
#   'cv_scores': array([0.242, 0.259]),
#   'avg_score': 0.2505,
#   'feature_names': ('dual_sim', 'sc_h'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  85: {'feature_idx': (3, 15),
#   'cv_scores': array([0.26 , 0.242]),
#   'avg_score': 0.251,
#   'feature_names': ('dual_sim', 'sc_w'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  86: {'feature_idx': (3, 16),
#   'cv_scores': array([0.251, 0.253]),
#   'avg_score': 0.252,
#   'feature_names': ('dual_sim', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  87: {'feature_idx': (3, 17),
#   'cv_scores': array([0.245, 0.244]),
#   'avg_score': 0.2445,
#   'feature_names': ('dual_sim', 'three_g'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  88: {'feature_idx': (3, 18),
#   'cv_scores': array([0.259, 0.246]),
#   'avg_score': 0.2525,
#   'feature_names': ('dual_sim', 'touch_screen'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  89: {'feature_idx': (3, 19),
#   'cv_scores': array([0.246, 0.239]),
#   'avg_score': 0.2425,
#   'feature_names': ('dual_sim', 'wifi'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  90: {'feature_idx': (4, 5),
#   'cv_scores': array([0.254, 0.24 ]),
#   'avg_score': 0.247,
#   'feature_names': ('fc', 'four_g'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  91: {'feature_idx': (4, 6),
#   'cv_scores': array([0.265, 0.267]),
#   'avg_score': 0.266,
#   'feature_names': ('fc', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  92: {'feature_idx': (4, 7),
#   'cv_scores': array([0.255, 0.237]),
#   'avg_score': 0.246,
#   'feature_names': ('fc', 'm_dep'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  93: {'feature_idx': (4, 8),
#   'cv_scores': array([0.25 , 0.269]),
#   'avg_score': 0.2595,
#   'feature_names': ('fc', 'mobile_wt'),
#   'ci_bound': 0.04087520093415714,
#   'std_dev': 0.009500000000000008,
#   'std_err': 0.009500000000000007},
#  94: {'feature_idx': (4, 9),
#   'cv_scores': array([0.267, 0.26 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('fc', 'n_cores'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  95: {'feature_idx': (4, 10),
#   'cv_scores': array([0.268, 0.255]),
#   'avg_score': 0.2615,
#   'feature_names': ('fc', 'pc'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  96: {'feature_idx': (4, 11),
#   'cv_scores': array([0.3  , 0.303]),
#   'avg_score': 0.3015,
#   'feature_names': ('fc', 'px_height'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  97: {'feature_idx': (4, 12),
#   'cv_scores': array([0.298, 0.304]),
#   'avg_score': 0.301,
#   'feature_names': ('fc', 'px_width'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  98: {'feature_idx': (4, 13),
#   'cv_scores': array([0.749, 0.749]),
#   'avg_score': 0.749,
#   'feature_names': ('fc', 'ram'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  99: {'feature_idx': (4, 14),
#   'cv_scores': array([0.26 , 0.255]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  100: {'feature_idx': (4, 15),
#   'cv_scores': array([0.257, 0.269]),
#   'avg_score': 0.263,
#   'feature_names': ('fc', 'sc_w'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  101: {'feature_idx': (4, 16),
#   'cv_scores': array([0.258, 0.253]),
#   'avg_score': 0.2555,
#   'feature_names': ('fc', 'talk_time'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  102: {'feature_idx': (4, 17),
#   'cv_scores': array([0.26 , 0.243]),
#   'avg_score': 0.2515,
#   'feature_names': ('fc', 'three_g'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  103: {'feature_idx': (4, 18),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('fc', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  104: {'feature_idx': (4, 19),
#   'cv_scores': array([0.254, 0.236]),
#   'avg_score': 0.245,
#   'feature_names': ('fc', 'wifi'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  105: {'feature_idx': (5, 6),
#   'cv_scores': array([0.27 , 0.272]),
#   'avg_score': 0.271,
#   'feature_names': ('four_g', 'int_memory'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  106: {'feature_idx': (5, 7),
#   'cv_scores': array([0.244, 0.265]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'm_dep'),
#   'ci_bound': 0.04517785366406842,
#   'std_dev': 0.01050000000000001,
#   'std_err': 0.01050000000000001},
#  107: {'feature_idx': (5, 8),
#   'cv_scores': array([0.249, 0.26 ]),
#   'avg_score': 0.2545,
#   'feature_names': ('four_g', 'mobile_wt'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  108: {'feature_idx': (5, 9),
#   'cv_scores': array([0.261, 0.245]),
#   'avg_score': 0.253,
#   'feature_names': ('four_g', 'n_cores'),
#   'ci_bound': 0.03442122183929023,
#   'std_dev': 0.008000000000000007,
#   'std_err': 0.008000000000000007},
#  109: {'feature_idx': (5, 10),
#   'cv_scores': array([0.257, 0.255]),
#   'avg_score': 0.256,
#   'feature_names': ('four_g', 'pc'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  110: {'feature_idx': (5, 11),
#   'cv_scores': array([0.291, 0.3  ]),
#   'avg_score': 0.2955,
#   'feature_names': ('four_g', 'px_height'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  111: {'feature_idx': (5, 12),
#   'cv_scores': array([0.291, 0.292]),
#   'avg_score': 0.2915,
#   'feature_names': ('four_g', 'px_width'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  112: {'feature_idx': (5, 13),
#   'cv_scores': array([0.754, 0.753]),
#   'avg_score': 0.7535000000000001,
#   'feature_names': ('four_g', 'ram'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  113: {'feature_idx': (5, 14),
#   'cv_scores': array([0.247, 0.264]),
#   'avg_score': 0.2555,
#   'feature_names': ('four_g', 'sc_h'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  114: {'feature_idx': (5, 15),
#   'cv_scores': array([0.266, 0.252]),
#   'avg_score': 0.259,
#   'feature_names': ('four_g', 'sc_w'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  115: {'feature_idx': (5, 16),
#   'cv_scores': array([0.259, 0.239]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  116: {'feature_idx': (5, 17),
#   'cv_scores': array([0.236, 0.259]),
#   'avg_score': 0.2475,
#   'feature_names': ('four_g', 'three_g'),
#   'ci_bound': 0.049480506393979704,
#   'std_dev': 0.01150000000000001,
#   'std_err': 0.01150000000000001},
#  117: {'feature_idx': (5, 18),
#   'cv_scores': array([0.246, 0.252]),
#   'avg_score': 0.249,
#   'feature_names': ('four_g', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  118: {'feature_idx': (5, 19),
#   'cv_scores': array([0.26 , 0.253]),
#   'avg_score': 0.2565,
#   'feature_names': ('four_g', 'wifi'),
#   'ci_bound': 0.015059284554689472,
#   'std_dev': 0.003500000000000003,
#   'std_err': 0.0035000000000000027},
#  119: {'feature_idx': (6, 7),
#   'cv_scores': array([0.274, 0.26 ]),
#   'avg_score': 0.267,
#   'feature_names': ('int_memory', 'm_dep'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  120: {'feature_idx': (6, 8),
#   'cv_scores': array([0.268, 0.256]),
#   'avg_score': 0.262,
#   'feature_names': ('int_memory', 'mobile_wt'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  121: {'feature_idx': (6, 9),
#   'cv_scores': array([0.28 , 0.272]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'n_cores'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  122: {'feature_idx': (6, 10),
#   'cv_scores': array([0.282, 0.278]),
#   'avg_score': 0.28,
#   'feature_names': ('int_memory', 'pc'),
#   'ci_bound': 0.008605305459822436,
#   'std_dev': 0.001999999999999974,
#   'std_err': 0.0019999999999999736},
#  123: {'feature_idx': (6, 11),
#   'cv_scores': array([0.289, 0.302]),
#   'avg_score': 0.2955,
#   'feature_names': ('int_memory', 'px_height'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  124: {'feature_idx': (6, 12),
#   'cv_scores': array([0.299, 0.302]),
#   'avg_score': 0.3005,
#   'feature_names': ('int_memory', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  125: {'feature_idx': (6, 13),
#   'cv_scores': array([0.758, 0.745]),
#   'avg_score': 0.7515000000000001,
#   'feature_names': ('int_memory', 'ram'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  126: {'feature_idx': (6, 14),
#   'cv_scores': array([0.252, 0.268]),
#   'avg_score': 0.26,
#   'feature_names': ('int_memory', 'sc_h'),
#   'ci_bound': 0.03442122183929023,
#   'std_dev': 0.008000000000000007,
#   'std_err': 0.008000000000000007},
#  127: {'feature_idx': (6, 15),
#   'cv_scores': array([0.273, 0.267]),
#   'avg_score': 0.27,
#   'feature_names': ('int_memory', 'sc_w'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  128: {'feature_idx': (6, 16),
#   'cv_scores': array([0.282, 0.267]),
#   'avg_score': 0.27449999999999997,
#   'feature_names': ('int_memory', 'talk_time'),
#   'ci_bound': 0.03226989547433447,
#   'std_dev': 0.007499999999999979,
#   'std_err': 0.007499999999999979},
#  129: {'feature_idx': (6, 17),
#   'cv_scores': array([0.269, 0.26 ]),
#   'avg_score': 0.2645,
#   'feature_names': ('int_memory', 'three_g'),
#   'ci_bound': 0.01936193728460075,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000003},
#  130: {'feature_idx': (6, 18),
#   'cv_scores': array([0.277, 0.275]),
#   'avg_score': 0.276,
#   'feature_names': ('int_memory', 'touch_screen'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  131: {'feature_idx': (6, 19),
#   'cv_scores': array([0.255, 0.257]),
#   'avg_score': 0.256,
#   'feature_names': ('int_memory', 'wifi'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  132: {'feature_idx': (7, 8),
#   'cv_scores': array([0.254, 0.262]),
#   'avg_score': 0.258,
#   'feature_names': ('m_dep', 'mobile_wt'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  133: {'feature_idx': (7, 9),
#   'cv_scores': array([0.255, 0.273]),
#   'avg_score': 0.264,
#   'feature_names': ('m_dep', 'n_cores'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  134: {'feature_idx': (7, 10),
#   'cv_scores': array([0.25 , 0.258]),
#   'avg_score': 0.254,
#   'feature_names': ('m_dep', 'pc'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  135: {'feature_idx': (7, 11),
#   'cv_scores': array([0.301, 0.301]),
#   'avg_score': 0.301,
#   'feature_names': ('m_dep', 'px_height'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  136: {'feature_idx': (7, 12),
#   'cv_scores': array([0.298, 0.25 ]),
#   'avg_score': 0.274,
#   'feature_names': ('m_dep', 'px_width'),
#   'ci_bound': 0.10326366551787057,
#   'std_dev': 0.023999999999999994,
#   'std_err': 0.023999999999999994},
#  137: {'feature_idx': (7, 13),
#   'cv_scores': array([0.765, 0.748]),
#   'avg_score': 0.7565,
#   'feature_names': ('m_dep', 'ram'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  138: {'feature_idx': (7, 14),
#   'cv_scores': array([0.251, 0.264]),
#   'avg_score': 0.2575,
#   'feature_names': ('m_dep', 'sc_h'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  139: {'feature_idx': (7, 15),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('m_dep', 'sc_w'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  140: {'feature_idx': (7, 16),
#   'cv_scores': array([0.271, 0.276]),
#   'avg_score': 0.2735,
#   'feature_names': ('m_dep', 'talk_time'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  141: {'feature_idx': (7, 17),
#   'cv_scores': array([0.248, 0.253]),
#   'avg_score': 0.2505,
#   'feature_names': ('m_dep', 'three_g'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  142: {'feature_idx': (7, 18),
#   'cv_scores': array([0.249, 0.243]),
#   'avg_score': 0.246,
#   'feature_names': ('m_dep', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  143: {'feature_idx': (7, 19),
#   'cv_scores': array([0.254, 0.248]),
#   'avg_score': 0.251,
#   'feature_names': ('m_dep', 'wifi'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  144: {'feature_idx': (8, 9),
#   'cv_scores': array([0.276, 0.281]),
#   'avg_score': 0.2785,
#   'feature_names': ('mobile_wt', 'n_cores'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  145: {'feature_idx': (8, 10),
#   'cv_scores': array([0.289, 0.27 ]),
#   'avg_score': 0.27949999999999997,
#   'feature_names': ('mobile_wt', 'pc'),
#   'ci_bound': 0.04087520093415702,
#   'std_dev': 0.00949999999999998,
#   'std_err': 0.00949999999999998},
#  146: {'feature_idx': (8, 11),
#   'cv_scores': array([0.296, 0.285]),
#   'avg_score': 0.2905,
#   'feature_names': ('mobile_wt', 'px_height'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  147: {'feature_idx': (8, 12),
#   'cv_scores': array([0.301, 0.298]),
#   'avg_score': 0.2995,
#   'feature_names': ('mobile_wt', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  148: {'feature_idx': (8, 13),
#   'cv_scores': array([0.756, 0.746]),
#   'avg_score': 0.751,
#   'feature_names': ('mobile_wt', 'ram'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  149: {'feature_idx': (8, 14),
#   'cv_scores': array([0.253, 0.252]),
#   'avg_score': 0.2525,
#   'feature_names': ('mobile_wt', 'sc_h'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  150: {'feature_idx': (8, 15),
#   'cv_scores': array([0.263, 0.269]),
#   'avg_score': 0.266,
#   'feature_names': ('mobile_wt', 'sc_w'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  151: {'feature_idx': (8, 16),
#   'cv_scores': array([0.273, 0.271]),
#   'avg_score': 0.272,
#   'feature_names': ('mobile_wt', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  152: {'feature_idx': (8, 17),
#   'cv_scores': array([0.261, 0.266]),
#   'avg_score': 0.2635,
#   'feature_names': ('mobile_wt', 'three_g'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  153: {'feature_idx': (8, 18),
#   'cv_scores': array([0.288, 0.263]),
#   'avg_score': 0.27549999999999997,
#   'feature_names': ('mobile_wt', 'touch_screen'),
#   'ci_bound': 0.05378315912389085,
#   'std_dev': 0.012499999999999983,
#   'std_err': 0.012499999999999982},
#  154: {'feature_idx': (8, 19),
#   'cv_scores': array([0.252, 0.27 ]),
#   'avg_score': 0.261,
#   'feature_names': ('mobile_wt', 'wifi'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  155: {'feature_idx': (9, 10),
#   'cv_scores': array([0.27 , 0.253]),
#   'avg_score': 0.2615,
#   'feature_names': ('n_cores', 'pc'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  156: {'feature_idx': (9, 11),
#   'cv_scores': array([0.29 , 0.291]),
#   'avg_score': 0.2905,
#   'feature_names': ('n_cores', 'px_height'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  157: {'feature_idx': (9, 12),
#   'cv_scores': array([0.276, 0.273]),
#   'avg_score': 0.2745,
#   'feature_names': ('n_cores', 'px_width'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  158: {'feature_idx': (9, 13),
#   'cv_scores': array([0.764, 0.754]),
#   'avg_score': 0.759,
#   'feature_names': ('n_cores', 'ram'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  159: {'feature_idx': (9, 14),
#   'cv_scores': array([0.264, 0.266]),
#   'avg_score': 0.265,
#   'feature_names': ('n_cores', 'sc_h'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  160: {'feature_idx': (9, 15),
#   'cv_scores': array([0.277, 0.274]),
#   'avg_score': 0.2755,
#   'feature_names': ('n_cores', 'sc_w'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013},
#  161: {'feature_idx': (9, 16),
#   'cv_scores': array([0.275, 0.277]),
#   'avg_score': 0.276,
#   'feature_names': ('n_cores', 'talk_time'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  162: {'feature_idx': (9, 17),
#   'cv_scores': array([0.265, 0.235]),
#   'avg_score': 0.25,
#   'feature_names': ('n_cores', 'three_g'),
#   'ci_bound': 0.06453979094866917,
#   'std_dev': 0.015000000000000013,
#   'std_err': 0.015000000000000012},
#  163: {'feature_idx': (9, 18),
#   'cv_scores': array([0.27 , 0.258]),
#   'avg_score': 0.264,
#   'feature_names': ('n_cores', 'touch_screen'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  164: {'feature_idx': (9, 19),
#   'cv_scores': array([0.253, 0.254]),
#   'avg_score': 0.2535,
#   'feature_names': ('n_cores', 'wifi'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  165: {'feature_idx': (10, 11),
#   'cv_scores': array([0.291, 0.296]),
#   'avg_score': 0.2935,
#   'feature_names': ('pc', 'px_height'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  166: {'feature_idx': (10, 12),
#   'cv_scores': array([0.298, 0.308]),
#   'avg_score': 0.303,
#   'feature_names': ('pc', 'px_width'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  167: {'feature_idx': (10, 13),
#   'cv_scores': array([0.761, 0.752]),
#   'avg_score': 0.7565,
#   'feature_names': ('pc', 'ram'),
#   'ci_bound': 0.019361937284600752,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000004},
#  168: {'feature_idx': (10, 14),
#   'cv_scores': array([0.267, 0.262]),
#   'avg_score': 0.2645,
#   'feature_names': ('pc', 'sc_h'),
#   'ci_bound': 0.010756631824778196,
#   'std_dev': 0.0025000000000000022,
#   'std_err': 0.0025000000000000022},
#  169: {'feature_idx': (10, 15),
#   'cv_scores': array([0.281, 0.263]),
#   'avg_score': 0.272,
#   'feature_names': ('pc', 'sc_w'),
#   'ci_bound': 0.0387238745692015,
#   'std_dev': 0.009000000000000008,
#   'std_err': 0.009000000000000006},
#  170: {'feature_idx': (10, 16),
#   'cv_scores': array([0.269, 0.273]),
#   'avg_score': 0.271,
#   'feature_names': ('pc', 'talk_time'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  171: {'feature_idx': (10, 17),
#   'cv_scores': array([0.259, 0.247]),
#   'avg_score': 0.253,
#   'feature_names': ('pc', 'three_g'),
#   'ci_bound': 0.02581591637946767,
#   'std_dev': 0.006000000000000005,
#   'std_err': 0.006000000000000005},
#  172: {'feature_idx': (10, 18),
#   'cv_scores': array([0.256, 0.269]),
#   'avg_score': 0.2625,
#   'feature_names': ('pc', 'touch_screen'),
#   'ci_bound': 0.02796724274442331,
#   'std_dev': 0.006500000000000006,
#   'std_err': 0.006500000000000006},
#  173: {'feature_idx': (10, 19),
#   'cv_scores': array([0.252, 0.248]),
#   'avg_score': 0.25,
#   'feature_names': ('pc', 'wifi'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  174: {'feature_idx': (11, 12),
#   'cv_scores': array([0.295, 0.325]),
#   'avg_score': 0.31,
#   'feature_names': ('px_height', 'px_width'),
#   'ci_bound': 0.06453979094866917,
#   'std_dev': 0.015000000000000013,
#   'std_err': 0.015000000000000012},
#  175: {'feature_idx': (11, 13),
#   'cv_scores': array([0.787, 0.804]),
#   'avg_score': 0.7955000000000001,
#   'feature_names': ('px_height', 'ram'),
#   'ci_bound': 0.03657254820424587,
#   'std_dev': 0.008500000000000008,
#   'std_err': 0.008500000000000008},
#  176: {'feature_idx': (11, 14),
#   'cv_scores': array([0.293, 0.281]),
#   'avg_score': 0.28700000000000003,
#   'feature_names': ('px_height', 'sc_h'),
#   'ci_bound': 0.02581591637946755,
#   'std_dev': 0.005999999999999978,
#   'std_err': 0.005999999999999977},
#  177: {'feature_idx': (11, 15),
#   'cv_scores': array([0.295, 0.294]),
#   'avg_score': 0.2945,
#   'feature_names': ('px_height', 'sc_w'),
#   'ci_bound': 0.0021513263649556393,
#   'std_dev': 0.0005000000000000004,
#   'std_err': 0.0005000000000000004},
#  178: {'feature_idx': (11, 16),
#   'cv_scores': array([0.281, 0.307]),
#   'avg_score': 0.29400000000000004,
#   'feature_names': ('px_height', 'talk_time'),
#   'ci_bound': 0.05593448548884649,
#   'std_dev': 0.012999999999999984,
#   'std_err': 0.012999999999999982},
#  179: {'feature_idx': (11, 17),
#   'cv_scores': array([0.276, 0.293]),
#   'avg_score': 0.2845,
#   'feature_names': ('px_height', 'three_g'),
#   'ci_bound': 0.03657254820424575,
#   'std_dev': 0.00849999999999998,
#   'std_err': 0.00849999999999998},
#  180: {'feature_idx': (11, 18),
#   'cv_scores': array([0.29, 0.29]),
#   'avg_score': 0.29,
#   'feature_names': ('px_height', 'touch_screen'),
#   'ci_bound': 0.0,
#   'std_dev': 0.0,
#   'std_err': 0.0},
#  181: {'feature_idx': (11, 19),
#   'cv_scores': array([0.292, 0.294]),
#   'avg_score': 0.293,
#   'feature_names': ('px_height', 'wifi'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  182: {'feature_idx': (12, 13),
#   'cv_scores': array([0.777, 0.785]),
#   'avg_score': 0.781,
#   'feature_names': ('px_width', 'ram'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  183: {'feature_idx': (12, 14),
#   'cv_scores': array([0.294, 0.29 ]),
#   'avg_score': 0.292,
#   'feature_names': ('px_width', 'sc_h'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  184: {'feature_idx': (12, 15),
#   'cv_scores': array([0.305, 0.297]),
#   'avg_score': 0.301,
#   'feature_names': ('px_width', 'sc_w'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  185: {'feature_idx': (12, 16),
#   'cv_scores': array([0.307, 0.287]),
#   'avg_score': 0.297,
#   'feature_names': ('px_width', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  186: {'feature_idx': (12, 17),
#   'cv_scores': array([0.281, 0.25 ]),
#   'avg_score': 0.2655,
#   'feature_names': ('px_width', 'three_g'),
#   'ci_bound': 0.06669111731362481,
#   'std_dev': 0.015500000000000014,
#   'std_err': 0.015500000000000012},
#  187: {'feature_idx': (12, 18),
#   'cv_scores': array([0.299, 0.293]),
#   'avg_score': 0.296,
#   'feature_names': ('px_width', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  188: {'feature_idx': (12, 19),
#   'cv_scores': array([0.277, 0.25 ]),
#   'avg_score': 0.2635,
#   'feature_names': ('px_width', 'wifi'),
#   'ci_bound': 0.05808581185380226,
#   'std_dev': 0.013500000000000012,
#   'std_err': 0.013500000000000012},
#  189: {'feature_idx': (13, 14),
#   'cv_scores': array([0.758, 0.748]),
#   'avg_score': 0.753,
#   'feature_names': ('ram', 'sc_h'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  190: {'feature_idx': (13, 15),
#   'cv_scores': array([0.76 , 0.751]),
#   'avg_score': 0.7555000000000001,
#   'feature_names': ('ram', 'sc_w'),
#   'ci_bound': 0.019361937284600752,
#   'std_dev': 0.004500000000000004,
#   'std_err': 0.004500000000000004},
#  191: {'feature_idx': (13, 16),
#   'cv_scores': array([0.768, 0.748]),
#   'avg_score': 0.758,
#   'feature_names': ('ram', 'talk_time'),
#   'ci_bound': 0.043026527299112785,
#   'std_dev': 0.010000000000000009,
#   'std_err': 0.010000000000000009},
#  192: {'feature_idx': (13, 17),
#   'cv_scores': array([0.762, 0.752]),
#   'avg_score': 0.757,
#   'feature_names': ('ram', 'three_g'),
#   'ci_bound': 0.021513263649556393,
#   'std_dev': 0.0050000000000000044,
#   'std_err': 0.0050000000000000044},
#  193: {'feature_idx': (13, 18),
#   'cv_scores': array([0.753, 0.749]),
#   'avg_score': 0.751,
#   'feature_names': ('ram', 'touch_screen'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  194: {'feature_idx': (13, 19),
#   'cv_scores': array([0.762, 0.748]),
#   'avg_score': 0.755,
#   'feature_names': ('ram', 'wifi'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  195: {'feature_idx': (14, 15),
#   'cv_scores': array([0.259, 0.251]),
#   'avg_score': 0.255,
#   'feature_names': ('sc_h', 'sc_w'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  196: {'feature_idx': (14, 16),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('sc_h', 'talk_time'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  197: {'feature_idx': (14, 17),
#   'cv_scores': array([0.246, 0.248]),
#   'avg_score': 0.247,
#   'feature_names': ('sc_h', 'three_g'),
#   'ci_bound': 0.004302652729911279,
#   'std_dev': 0.0010000000000000009,
#   'std_err': 0.0010000000000000009},
#  198: {'feature_idx': (14, 18),
#   'cv_scores': array([0.246, 0.257]),
#   'avg_score': 0.2515,
#   'feature_names': ('sc_h', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  199: {'feature_idx': (14, 19),
#   'cv_scores': array([0.241, 0.255]),
#   'avg_score': 0.248,
#   'feature_names': ('sc_h', 'wifi'),
#   'ci_bound': 0.030118569109378945,
#   'std_dev': 0.007000000000000006,
#   'std_err': 0.007000000000000005},
#  200: {'feature_idx': (15, 16),
#   'cv_scores': array([0.284, 0.279]),
#   'avg_score': 0.2815,
#   'feature_names': ('sc_w', 'talk_time'),
#   'ci_bound': 0.010756631824778077,
#   'std_dev': 0.0024999999999999745,
#   'std_err': 0.0024999999999999745},
#  201: {'feature_idx': (15, 17),
#   'cv_scores': array([0.258, 0.254]),
#   'avg_score': 0.256,
#   'feature_names': ('sc_w', 'three_g'),
#   'ci_bound': 0.008605305459822557,
#   'std_dev': 0.0020000000000000018,
#   'std_err': 0.0020000000000000018},
#  202: {'feature_idx': (15, 18),
#   'cv_scores': array([0.256, 0.267]),
#   'avg_score': 0.2615,
#   'feature_names': ('sc_w', 'touch_screen'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  203: {'feature_idx': (15, 19),
#   'cv_scores': array([0.233, 0.258]),
#   'avg_score': 0.2455,
#   'feature_names': ('sc_w', 'wifi'),
#   'ci_bound': 0.05378315912389092,
#   'std_dev': 0.012499999999999997,
#   'std_err': 0.012499999999999997},
#  204: {'feature_idx': (16, 17),
#   'cv_scores': array([0.263, 0.248]),
#   'avg_score': 0.2555,
#   'feature_names': ('talk_time', 'three_g'),
#   'ci_bound': 0.032269895474334585,
#   'std_dev': 0.007500000000000007,
#   'std_err': 0.007500000000000006},
#  205: {'feature_idx': (16, 18),
#   'cv_scores': array([0.269, 0.277]),
#   'avg_score': 0.273,
#   'feature_names': ('talk_time', 'touch_screen'),
#   'ci_bound': 0.017210610919645115,
#   'std_dev': 0.0040000000000000036,
#   'std_err': 0.0040000000000000036},
#  206: {'feature_idx': (16, 19),
#   'cv_scores': array([0.263, 0.252]),
#   'avg_score': 0.2575,
#   'feature_names': ('talk_time', 'wifi'),
#   'ci_bound': 0.023664590014512033,
#   'std_dev': 0.005500000000000005,
#   'std_err': 0.005500000000000005},
#  207: {'feature_idx': (17, 18),
#   'cv_scores': array([0.256, 0.262]),
#   'avg_score': 0.259,
#   'feature_names': ('three_g', 'touch_screen'),
#   'ci_bound': 0.012907958189733835,
#   'std_dev': 0.0030000000000000027,
#   'std_err': 0.0030000000000000027},
#  208: {'feature_idx': (17, 19),
#   'cv_scores': array([0.242, 0.233]),
#   'avg_score': 0.2375,
#   'feature_names': ('three_g', 'wifi'),
#   'ci_bound': 0.019361937284600693,
#   'std_dev': 0.00449999999999999,
#   'std_err': 0.00449999999999999},
#  209: {'feature_idx': (18, 19),
#   'cv_scores': array([0.248, 0.251]),
#   'avg_score': 0.2495,
#   'feature_names': ('touch_screen', 'wifi'),
#   'ci_bound': 0.006453979094866918,
#   'std_dev': 0.0015000000000000013,
#   'std_err': 0.0015000000000000013}}

# %% [markdown]
# ### Plot metric dict with all subsets

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(50,50))

k_feat = sorted(metric_dict.keys())
avg = [metric_dict[k]['avg_score'] for k in k_feat]

upper, lower = [], []
for k in k_feat:
    upper.append(metric_dict[k]['avg_score'] +
                 metric_dict[k]['std_dev'])
    lower.append(metric_dict[k]['avg_score'] -
                 metric_dict[k]['std_dev'])

plt.fill_between(k_feat,
                 upper,
                 lower,
                 alpha=0.2,
                 color='blue',
                 lw=1)

plt.plot(k_feat, avg, color='blue', marker='o')
plt.ylabel('Accuracy +/- Standard Deviation')
plt.xlabel('Number of Features')
feature_min = len(metric_dict[k_feat[0]]['feature_idx'])
feature_max = len(metric_dict[k_feat[-1]]['feature_idx'])
plt.xticks(k_feat, 
           [str(metric_dict[k]['feature_names']) for k in k_feat], 
           rotation=90)
plt.show()

# %% [markdown]
# ### Try KNN as the Learning algorithm

# %%
from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Choose KNN as your learning algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ### Build a ExhaustiveFeatureSelector model with KNN as learning algorithm

# %%
efs_knn = EFS(knn, 
           min_features=1,
           max_features=2,
           scoring='accuracy',
           print_progress=True,
           cv=5
)

# %% [markdown]
# ### Train the model

# %%
efs_knn.fit(X, y)
# Out:
# Features: 210/210
# ExhaustiveFeatureSelector(estimator=KNeighborsClassifier(n_neighbors=3),
#                           max_features=2)

# %% [markdown]
# ### Get the feature names

# %%
efs_knn.best_feature_names_
# Out:
# ('battery_power', 'ram')

# %%
efs_knn.best_score_
# Out:
# 0.7815

# %% [markdown]
# ### Try some other learning algorithms you know of
# - SVM
# - Anything of your choice

# %% [markdown]
# ### Summarize the list of features chosen by different algorithms
# - Algorithm | Best Features | Best Accuracy
#
# Example:
#
# - Logistic Regression | ['battery_power', 'ram']  | 0.823
# - KNN | ???? | ????
# - RF | ???? | ????
# - Algorithms of your choice | ????? | ????
